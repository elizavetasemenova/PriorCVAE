# %%
# general
import os
import sys
import time
import numpy as np 
import matplotlib.pyplot as plt 

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F 
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# Numpyro
import numpyro
import numpyro.distributions as npdist
import random as rnd
from numpyro.infer import Predictive, init_to_median, MCMC, NUTS
from numpyro.diagnostics import hpdi

numpyro.set_host_device_count(4)

#JAX
import jax
from jax import random
import jax.numpy as jnp

# check versions
print(numpyro.__version__)
print(jax.__version__)
print(torch.__version__)
from platform import python_version
print(python_version())
# Out:
# 0.10.1
# 0.3.25
# 1.12.1
# 3.8.16

# %%
# set device
torch.manual_seed(0)
if torch.cuda.is_available():
    torch.cuda.manual_seed(0)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
#args = {"seed": 0,
#        "conditional": False,
#        "input_dim": 80,
#        "hidden_dim": 60,
#        "z_dim": 40,
#        "new_data": False,  # set to True to generate new data. Otherwise read from file
#        "save_data": False, # set to True to save generated training and test datasets
#        "batch_size": 500,
#        "samples": 100000,
#        "vae_sd": 1, 
#        "n_epochs": 400,
#        #"n_epochs": 1500,
#        "learning_rate": 1e-3,
#        "train_vae": True,     # set to True to train VAE
#        "save_vae": False,
#        "load_vae": False,      # set to True to load read trained CVAE
#        #"gp_kernel": exp_sq_kernel,
#        "num_warmup": 1000,
#        "num_samples": 1000,
#        "num_chains": 4,
#        "thinning": 1,
#        "true_ls": 0.2
#       }

# %%
args = {"seed": 0,
        
        # architecture
        "conditional": False,   # CVAE if True, VAE otherwise
        "input_dim": 80,
        "hidden_dim": 60,
        "z_dim": 40,
        
        # data generation
        "new_data": False,      # set to True to generate new data. Otherwise read from file
        "save_data": False,     # set to True to save generated training and test datasets
        "samples": 100000,
        
        # VAE setup
        "vae_sd": 1, 
        "n_epochs": 400,      
        "batch_size": 1000,
        "learning_rate": 1e-3,
        "train_vae": True,      # set to True to train VAE
        "save_vae": True,
        "load_vae": False,      # set to True to load trained CVAE
        "print_loss": True,
        
        # MCMC setup
        "num_warmup": 5000,
        "num_samples": 50000,
        "num_chains": 3,
        "thinning": 1,
        "true_ls": 0.2
       }

# %% [markdown]
# ## GP priors

# %%
def dist_euclid(x, z):
    x = jnp.array(x) 
    z = jnp.array(z)
    if len(x.shape)==1:
        x = x.reshape(x.shape[0], 1)
    if len(z.shape)==1:
        z = z.reshape(z.shape[0], 1)
    n_x, m = x.shape
    n_z, m_z = z.shape
    assert m == m_z
    delta = jnp.zeros((n_x,n_z))
    for d in jnp.arange(m):
        x_d = x[:,d]
        z_d = z[:,d]
        delta += (x_d[:,jnp.newaxis] - z_d)**2
    return jnp.sqrt(delta)

def exp_sq_kernel(x, z, var, length, noise=0, jitter=1.0e-5):
    dist = dist_euclid(x, z)
    deltaXsq = jnp.power(dist/ length, 2.0)
    k = var * jnp.exp(-0.5 * deltaXsq)
    k += (noise + jitter) * jnp.eye(x.shape[0])
    return k

def GP(x, jitter=1e-5, var=1.0, length=None, y=None, noise=False, gp_kernel=exp_sq_kernel):

    if length==None:  
        length = numpyro.sample("length", npdist.Uniform(0.01,0.99)) 
            
    k = gp_kernel(x, x, var, length, jitter)
    
    if noise==False:
        y = numpyro.sample("y",  npdist.MultivariateNormal(loc=jnp.zeros(x.shape[0]), covariance_matrix=k), obs=y)
    else:
        sigma = numpyro.sample("noise", npdist.HalfNormal(0.1))
        f = numpyro.sample("f", npdist.MultivariateNormal(loc=jnp.zeros(x.shape[0]), covariance_matrix=k))
        y = numpyro.sample("y", npdist.Normal(f, sigma), obs=y)
        
    ls = numpyro.deterministic("ls", jnp.array([length]))

# %% [markdown]
# ## Generate data - 1d GP

# %%
class GP1D(Dataset):
    def __init__(self, n_dataPoints=400, 
                       n_samples=10000, 
                       x_lim_low = 0, 
                       x_lim_high = 1,
                       ls = None
                 ): 
        self.n_dataPoints = n_dataPoints
        self.n_samples = n_samples
        self.x_lim_low = x_lim_low
        self.x_lim_high = x_lim_high
        self.ls = ls
        self.x, self.y, self.ls = self.__simulatedata__()
    
    def __len__(self):
        return self.n_samples
    
    def __getitem__(self, idx=0):
        return(self.x[idx], self.y[idx], self.ls[idx])

    def __simulatedata__(self):
        rng_key = rnd.randint(0, 912393890428)
        rng_key, _ = random.split(random.PRNGKey(rng_key))
        x = np.linspace(self.x_lim_low, self.x_lim_high, self.n_dataPoints)   
        gp_predictive = Predictive(GP, num_samples=self.n_samples)  
        all_draws = gp_predictive(rng_key, x=x, gp_kernel = exp_sq_kernel, jitter=1e-6, length=self.ls)

        ls_draws = np.array(all_draws['ls'])
        gp_draws = np.array(all_draws['y'])
        
        return (x.repeat(self.n_samples).reshape(x.shape[0], self.n_samples).transpose(), gp_draws, ls_draws)

# %%
# what lengthscales are we generating?
dataset = GP1D(n_dataPoints=args["input_dim"])
ls_dataset = dataset.ls
plt.hist(ls_dataset) 
plt.xlim(0,1)
# Out:
# (0.0, 1.0)

# %%
# what trajectories are we getting?
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)

fig, ax = plt.subplots()
for no, dt in enumerate(dataloader):
    if dt[2] <= 0.2:
        col = 'orange'  
    elif dt[2] <= 0.6:
        col = 'green'
    else: 
        col = 'blue'
    ax.plot(dt[0].reshape(-1,1), dt[1].reshape(-1,1), color=col)
    if no > 15: break
ax.set_xlabel('$x$')
ax.set_ylabel('$y=f(x)$')
ax.set_title('realizations of a Gaussian process')

plt.show()

# %%
# create or read training and test data

cwd = os.getcwd()

train_ds_name = 'gp1d_n' + str(args["input_dim"]) + '_train.pt'
test_ds_name = 'gp1d_n' + str(args["input_dim"]) + '_test.pt'
PATH_train = cwd+ F"/data/gp1d/{train_ds_name}"
PATH_test =  cwd+ F"/data/gp1d/{test_ds_name}" 
    
if args["new_data"] == True:
    print("Generating new data")
    train_ds = GP1D(n_dataPoints=args["input_dim"], n_samples=args["samples"])
    test_ds = GP1D(n_dataPoints=args["input_dim"], n_samples=args["samples"])
    torch.save(train_ds, PATH_train)
    torch.save(test_ds, PATH_test)
    
else:
    print("Loading data")
    train_ds = torch.load(PATH_train)
    test_ds = torch.load(PATH_test)
    
test_dl = DataLoader(test_ds, batch_size=args["batch_size"], shuffle=True)
train_dl = DataLoader(train_ds, batch_size=args["batch_size"], shuffle=True)

# check distribution of lengthscales in training and test data
ls_train = train_ds.ls
plt.hist(ls_train, density=True) 
plt.xlim(0,1)
plt.show()

ls_test = test_ds.ls
plt.hist(ls_test, density=True) 
plt.xlim(0,1)
plt.show()
# Out:
# Loading data

# %% [markdown]
# ## CVAE architecture

# %%
class Encoder(nn.Module):
    ''' This the encoder part of CVAE
    '''
    def __init__(self, input_dim, hidden_dim, z_dim, conditional):
        super().__init__()
        self.conditional = conditional
        if self.conditional:
            input_dim = input_dim + 1
        
        self.linear = nn.Linear(input_dim, hidden_dim)
        self.mu = nn.Linear(hidden_dim, z_dim)
        self.sd = nn.Linear(hidden_dim, z_dim)
        
    def forward(self, x, c=None):
        if self.conditional:
            #c = c[:, None]
            x = torch.cat((x, c), dim=-1)

        #hidden = torch.tanh(self.linear(x))
        hidden = torch.relu(self.linear(x))
        z_mu = self.mu(hidden)
        z_sd = self.sd(hidden)
        return z_mu, z_sd

# %%
class Decoder(nn.Module):
    ''' This the decoder part of VAE
    '''
    def __init__(self,z_dim, hidden_dim, input_dim,  conditional):
        super().__init__()
        
        self.conditional = conditional
        if self.conditional:
            z_dim = z_dim + 1
            
        self.linear = nn.Linear(z_dim, hidden_dim)
        self.out = nn.Linear(hidden_dim, input_dim)
    
    def forward(self, z, c):
        
        if self.conditional:
            z = torch.cat((z, c), dim=-1)

        hidden = torch.relu(self.linear(z))
        pred = self.out(hidden)
        return pred

# %%
class VAE(nn.Module):
    ''' This the VAE, which takes a encoder and decoder.
    '''
    def __init__(self, input_dim, hidden_dim, latent_dim,
                 conditional=False):
        
        super().__init__()        
        self.encoder = Encoder(input_dim, hidden_dim, latent_dim, conditional) 
        self.decoder = Decoder(latent_dim, hidden_dim, input_dim, conditional)

    def reparameterize(self, z_mu, z_sd):
        '''During training random sample from the learned ZDIMS-dimensional
           normal distribution; during inference its mean.
        '''
        if self.training:
            std = torch.exp(z_sd / 2)
            eps = torch.randn_like(std)
            return (eps.mul(std).add_(z_mu))
        else:
            return z_mu

    def forward(self, x, c=None):
        z_mu, z_sd = self.encoder(x, c)
        x_sample = self.reparameterize(z_mu, z_sd)
        generated_x = self.decoder(x_sample, c)
        return generated_x, z_mu,z_sd

# %%
def calculate_loss(y, reconstructed_y, mean, log_sd, vae_sd=args["vae_sd"]):

    # Compute the negative log-likelihood of the Gaussian distribution
    RCL = -torch.sum(- 0.5 * ((y - reconstructed_y) / vae_sd) ** 2)

    # Compute the KL divergence
    KLD = -0.5 * torch.sum(1 + log_sd - mean.pow(2) - log_sd.exp())

    return RCL + KLD

# %% [markdown]
# ## Train PriorVAE

# %%
# 1) Model
input_dim = args["input_dim"]
hidden_dim = args["hidden_dim"]
z_dim = args["z_dim"]
conditional = args["conditional"]

model = VAE(input_dim, hidden_dim, z_dim, conditional)

# 2) optimizer
optimizer = optim.Adam(model.parameters(), lr=args["learning_rate"])       
device = 'cuda' if torch.cuda.is_available() else 'cpu' 
model = model.to(device)

loss_history_train = []
loss_history_test = []

# %%
def calc_loss(model, data, loss_fn):
    
    model.eval()
    with torch.no_grad():
        total_loss = 0

        for i, (_, y, ls) in enumerate(data):    
            y = y.to(device)
            if args["conditional"]:
                ls = ls.to(device)
                reconstructed_y, z_mu, z_sd = model(y, ls) 
            else:
                reconstructed_y, z_mu, z_sd = model(y)
                
            loss_i = loss_fn(y, reconstructed_y, z_mu, z_sd) 
            total_loss += loss_i.item()
            
    return total_loss / len(data)

# %%
num_epochs = args['n_epochs']

best_model = model

if args["train_vae"] == True:
    
    start_time = time.time()

    for epoch in range(num_epochs):
        
        # Set the model back to training mode
        model.train(True)
        
        # batch training
        for i, (_, y, ls) in enumerate(train_dl):

            # Clear the gradients
            optimizer.zero_grad()
            
            # Forward pass
            y = y.to(device)

            if args["conditional"]:
                ls = ls.to(device)
                reconstructed_y, z_mu, z_sd = model(y, ls) 
            else:
                reconstructed_y, z_mu, z_sd = model(y)
                
            # training loss on the batch    
            loss_tr = calculate_loss(y, reconstructed_y, z_mu, z_sd) 
            
            # Backward pass
            loss_tr.backward()
    
            # Update the weights
            optimizer.step()
            
        # Calculate the training loss for the epoch
        train_loss = calc_loss(model, train_dl, calculate_loss)
        loss_history_train.append(train_loss)
        
        # Set the model to evaluation mode
        model.eval()
  
        # Calculate the test loss for the epoch
        test_loss = calc_loss(model, test_dl, calculate_loss)
        loss_history_test.append(test_loss)
        
        if epoch==0:
            best_loss = test_loss
        else:
            if test_loss < best_loss:
                best_model = model
                best_loss = test_loss
        
        # Print loss
        if args["print_loss"] == True:
            print(f"Epoch {epoch}: Train loss = {train_loss:.4f}, Test loss = {test_loss:.4f}")
        
    end_time = time.time()
    t_elapsed = end_time - start_time
    
    # Print elapsed time
    print(f"Elapsed time = {t_elapsed:.4f}")

    plt.figure()
    plt.plot(np.arange(len(loss_history_train)), loss_history_train, label="train loss")
    plt.plot(np.arange(len(loss_history_test)), loss_history_test, label="test loss")
    plt.xlabel("epochs")
    plt.ylabel("train error")
    plt.legend()
    plt.title("Train and test loss, PriorCVAE")
    plt.show()
# Out:
# Epoch 0: Train loss = 11667.0959, Test loss = 11722.7541
# Epoch 1: Train loss = 10669.3020, Test loss = 10716.1188
# Epoch 2: Train loss = 9680.8007, Test loss = 9713.4304
# Epoch 3: Train loss = 8943.9390, Test loss = 8958.8552
# Epoch 4: Train loss = 8517.7771, Test loss = 8524.7300
# Epoch 5: Train loss = 7941.5163, Test loss = 7943.5219
# Epoch 6: Train loss = 7771.7304, Test loss = 7772.7726
# Epoch 7: Train loss = 7662.2410, Test loss = 7662.1330
# Epoch 8: Train loss = 7636.5844, Test loss = 7635.8186
# Epoch 9: Train loss = 7600.8184, Test loss = 7600.1998
# Epoch 10: Train loss = 7584.7338, Test loss = 7584.0010
# Epoch 11: Train loss = 7592.4752, Test loss = 7592.1895
# Epoch 12: Train loss = 7571.8853, Test loss = 7571.7242
# Epoch 13: Train loss = 7575.6839, Test loss = 7576.5549
# Epoch 14: Train loss = 7550.1094, Test loss = 7550.7535
# Epoch 15: Train loss = 7532.2641, Test loss = 7533.3878
# Epoch 16: Train loss = 7507.7741, Test loss = 7509.7133
# Epoch 17: Train loss = 7489.4728, Test loss = 7492.9907
# Epoch 18: Train loss = 7495.6330, Test loss = 7499.2720
# Epoch 19: Train loss = 7431.4849, Test loss = 7435.4591
# Epoch 20: Train loss = 7450.5250, Test loss = 7454.8537
# Epoch 21: Train loss = 7464.0712, Test loss = 7468.8908
# Epoch 22: Train loss = 7432.2203, Test loss = 7437.2861
# Epoch 23: Train loss = 7446.4097, Test loss = 7450.8018
# Epoch 24: Train loss = 7461.1022, Test loss = 7465.5893
# Epoch 25: Train loss = 7492.3081, Test loss = 7497.6695
# Epoch 26: Train loss = 7441.3661, Test loss = 7446.4158
# Epoch 27: Train loss = 7481.2414, Test loss = 7487.0738
# Epoch 28: Train loss = 7451.7733, Test loss = 7456.6734
# Epoch 29: Train loss = 7448.9808, Test loss = 7454.4644
# Epoch 30: Train loss = 7467.8583, Test loss = 7472.9473
# Epoch 31: Train loss = 7469.9673, Test loss = 7475.2487
# Epoch 32: Train loss = 7393.9141, Test loss = 7399.0868
# Epoch 33: Train loss = 7453.0653, Test loss = 7458.4894
# Epoch 34: Train loss = 7460.9052, Test loss = 7466.6232
# Epoch 35: Train loss = 7413.6320, Test loss = 7418.7040
# Epoch 36: Train loss = 7444.4609, Test loss = 7450.0778
# Epoch 37: Train loss = 7446.9312, Test loss = 7452.4779
# Epoch 38: Train loss = 7430.5149, Test loss = 7435.4506
# Epoch 39: Train loss = 7467.0390, Test loss = 7472.3279
# Epoch 40: Train loss = 7487.8056, Test loss = 7493.6279
# Epoch 41: Train loss = 7437.1317, Test loss = 7442.9882
# Epoch 42: Train loss = 7456.8405, Test loss = 7462.4235
# Epoch 43: Train loss = 7451.7524, Test loss = 7457.8167
# Epoch 44: Train loss = 7460.1075, Test loss = 7465.9708
# Epoch 45: Train loss = 7460.7427, Test loss = 7466.4025
# Epoch 46: Train loss = 7403.2535, Test loss = 7409.8773
# Epoch 47: Train loss = 7413.3031, Test loss = 7419.3737
# Epoch 48: Train loss = 7435.8076, Test loss = 7440.9211
# Epoch 49: Train loss = 7464.3342, Test loss = 7471.0200
# Epoch 50: Train loss = 7459.7821, Test loss = 7465.7187
# Epoch 51: Train loss = 7430.3020, Test loss = 7436.3854
# Epoch 52: Train loss = 7431.6836, Test loss = 7437.9264
# Epoch 53: Train loss = 7433.2826, Test loss = 7439.8928
# Epoch 54: Train loss = 7453.8332, Test loss = 7459.9371
# Epoch 55: Train loss = 7444.5608, Test loss = 7450.6722
# Epoch 56: Train loss = 7427.3953, Test loss = 7432.8536
# Epoch 57: Train loss = 7400.6685, Test loss = 7406.3769
# Epoch 58: Train loss = 7444.4704, Test loss = 7451.1640
# Epoch 59: Train loss = 7408.7114, Test loss = 7414.7955
# Epoch 60: Train loss = 7445.6428, Test loss = 7452.5877
# Epoch 61: Train loss = 7422.4134, Test loss = 7428.0603
# Epoch 62: Train loss = 7432.3089, Test loss = 7439.1526
# Epoch 63: Train loss = 7424.7431, Test loss = 7431.0857
# Epoch 64: Train loss = 7381.7528, Test loss = 7387.7511
# Epoch 65: Train loss = 7458.6149, Test loss = 7465.3904
# Epoch 66: Train loss = 7384.3662, Test loss = 7390.7732
# Epoch 67: Train loss = 7394.6320, Test loss = 7401.2987
# Epoch 68: Train loss = 7336.0136, Test loss = 7343.5222
# Epoch 69: Train loss = 7379.0447, Test loss = 7386.5503
# Epoch 70: Train loss = 7371.1468, Test loss = 7379.1377
# Epoch 71: Train loss = 7324.1217, Test loss = 7331.9146
# Epoch 72: Train loss = 7345.1696, Test loss = 7353.5137
# Epoch 73: Train loss = 7337.1474, Test loss = 7345.1776
# Epoch 74: Train loss = 7292.3811, Test loss = 7299.8612
# Epoch 75: Train loss = 7353.1256, Test loss = 7361.4404
# Epoch 76: Train loss = 7306.9534, Test loss = 7314.6949
# Epoch 77: Train loss = 7275.7000, Test loss = 7284.2236
# Epoch 78: Train loss = 7294.5878, Test loss = 7303.2376
# Epoch 79: Train loss = 7314.0984, Test loss = 7323.4250
# Epoch 80: Train loss = 7268.0694, Test loss = 7278.1314
# Epoch 81: Train loss = 7317.1548, Test loss = 7326.4936
# Epoch 82: Train loss = 7267.5752, Test loss = 7277.7935
# Epoch 83: Train loss = 7293.2128, Test loss = 7304.1410
# Epoch 84: Train loss = 7282.2396, Test loss = 7292.9145
# Epoch 85: Train loss = 7331.5095, Test loss = 7342.3100
# Epoch 86: Train loss = 7271.1803, Test loss = 7281.9349
# Epoch 87: Train loss = 7234.1973, Test loss = 7244.8728
# Epoch 88: Train loss = 7270.3150, Test loss = 7281.1065
# Epoch 89: Train loss = 7303.2539, Test loss = 7314.4922
# Epoch 90: Train loss = 7274.6691, Test loss = 7286.3943
# Epoch 91: Train loss = 7231.8784, Test loss = 7243.3487
# Epoch 92: Train loss = 7249.2400, Test loss = 7260.3161
# Epoch 93: Train loss = 7213.8303, Test loss = 7224.7536
# Epoch 94: Train loss = 7238.3727, Test loss = 7249.6056
# Epoch 95: Train loss = 7250.8019, Test loss = 7262.6301
# Epoch 96: Train loss = 7262.9429, Test loss = 7274.4347
# Epoch 97: Train loss = 7267.9700, Test loss = 7279.2487
# Epoch 98: Train loss = 7249.3260, Test loss = 7260.9901
# Epoch 99: Train loss = 7207.9282, Test loss = 7219.7052
# Epoch 100: Train loss = 7242.2440, Test loss = 7253.9684
# Epoch 101: Train loss = 7249.0364, Test loss = 7260.7003
# Epoch 102: Train loss = 7242.3930, Test loss = 7253.3959
# Epoch 103: Train loss = 7226.4410, Test loss = 7238.0581
# Epoch 104: Train loss = 7273.3246, Test loss = 7284.7221
# Epoch 105: Train loss = 7231.3984, Test loss = 7243.0660
# Epoch 106: Train loss = 7248.8343, Test loss = 7260.5164
# Epoch 107: Train loss = 7252.5232, Test loss = 7264.3215
# Epoch 108: Train loss = 7252.8787, Test loss = 7264.3153
# Epoch 109: Train loss = 7211.6003, Test loss = 7223.8893
# Epoch 110: Train loss = 7228.7738, Test loss = 7240.6091
# Epoch 111: Train loss = 7218.5452, Test loss = 7230.4158
# Epoch 112: Train loss = 7215.8125, Test loss = 7227.9768
# Epoch 113: Train loss = 7260.4806, Test loss = 7272.7938
# Epoch 114: Train loss = 7222.1298, Test loss = 7234.7153
# Epoch 115: Train loss = 7236.4616, Test loss = 7248.9072
# Epoch 116: Train loss = 7236.3144, Test loss = 7248.8728
# Epoch 117: Train loss = 7247.5152, Test loss = 7260.5777
# Epoch 118: Train loss = 7184.8792, Test loss = 7197.3564
# Epoch 119: Train loss = 7233.5978, Test loss = 7245.7917
# Epoch 120: Train loss = 7231.0035, Test loss = 7243.7791
# Epoch 121: Train loss = 7230.6646, Test loss = 7242.7760
# Epoch 122: Train loss = 7209.0651, Test loss = 7221.2319
# Epoch 123: Train loss = 7258.1736, Test loss = 7271.6983
# Epoch 124: Train loss = 7243.0071, Test loss = 7255.3270
# Epoch 125: Train loss = 7250.8947, Test loss = 7263.8966
# Epoch 126: Train loss = 7220.6746, Test loss = 7233.6209
# Epoch 127: Train loss = 7218.7688, Test loss = 7230.9728
# Epoch 128: Train loss = 7210.9550, Test loss = 7224.3746
# Epoch 129: Train loss = 7258.0870, Test loss = 7271.1092
# Epoch 130: Train loss = 7218.3576, Test loss = 7231.6362
# Epoch 131: Train loss = 7252.4266, Test loss = 7264.7651
# Epoch 132: Train loss = 7269.5244, Test loss = 7282.0184
# Epoch 133: Train loss = 7229.1037, Test loss = 7242.0392
# Epoch 134: Train loss = 7180.2613, Test loss = 7192.8022
# Epoch 135: Train loss = 7243.4381, Test loss = 7255.7315
# Epoch 136: Train loss = 7235.1126, Test loss = 7248.4992
# Epoch 137: Train loss = 7258.8663, Test loss = 7271.5596
# Epoch 138: Train loss = 7208.8357, Test loss = 7222.2202
# Epoch 139: Train loss = 7239.2150, Test loss = 7252.7021
# Epoch 140: Train loss = 7271.1019, Test loss = 7284.1603
# Epoch 141: Train loss = 7264.4370, Test loss = 7277.1183
# Epoch 142: Train loss = 7225.6265, Test loss = 7238.7925
# Epoch 143: Train loss = 7212.1695, Test loss = 7225.5562
# Epoch 144: Train loss = 7283.6124, Test loss = 7296.8076
# Epoch 145: Train loss = 7264.7050, Test loss = 7277.2332
# Epoch 146: Train loss = 7220.2109, Test loss = 7233.0660
# Epoch 147: Train loss = 7264.3888, Test loss = 7277.5728
# Epoch 148: Train loss = 7222.6972, Test loss = 7235.4906
# Epoch 149: Train loss = 7249.3316, Test loss = 7261.8073
# Epoch 150: Train loss = 7282.2041, Test loss = 7295.3219
# Epoch 151: Train loss = 7239.8333, Test loss = 7253.2862
# Epoch 152: Train loss = 7260.9715, Test loss = 7274.2553
# Epoch 153: Train loss = 7255.0719, Test loss = 7268.7787
# Epoch 154: Train loss = 7254.7321, Test loss = 7268.3770
# Epoch 155: Train loss = 7223.0488, Test loss = 7236.0111
# Epoch 156: Train loss = 7253.5060, Test loss = 7266.6133
# Epoch 157: Train loss = 7221.4331, Test loss = 7234.2724
# Epoch 158: Train loss = 7217.2487, Test loss = 7230.6883
# Epoch 159: Train loss = 7268.5158, Test loss = 7281.9678
# Epoch 160: Train loss = 7223.7718, Test loss = 7236.9756
# Epoch 161: Train loss = 7264.3283, Test loss = 7277.5770
# Epoch 162: Train loss = 7266.9936, Test loss = 7279.8365
# Epoch 163: Train loss = 7223.0537, Test loss = 7236.2441
# Epoch 164: Train loss = 7224.1529, Test loss = 7237.2011
# Epoch 165: Train loss = 7210.4393, Test loss = 7223.4174
# Epoch 166: Train loss = 7209.6842, Test loss = 7222.8894
# Epoch 167: Train loss = 7238.0179, Test loss = 7251.8299
# Epoch 168: Train loss = 7239.5549, Test loss = 7253.2905
# Epoch 169: Train loss = 7214.4909, Test loss = 7228.0949
# Epoch 170: Train loss = 7239.2794, Test loss = 7253.0337
# Epoch 171: Train loss = 7234.8494, Test loss = 7248.0753
# Epoch 172: Train loss = 7213.7378, Test loss = 7228.2076
# Epoch 173: Train loss = 7251.4788, Test loss = 7265.1663
# Epoch 174: Train loss = 7194.3453, Test loss = 7208.0044
# Epoch 175: Train loss = 7235.7511, Test loss = 7249.5294
# Epoch 176: Train loss = 7207.0094, Test loss = 7219.9408
# Epoch 177: Train loss = 7222.8518, Test loss = 7237.1444
# Epoch 178: Train loss = 7244.6851, Test loss = 7258.1027
# Epoch 179: Train loss = 7222.1522, Test loss = 7236.1580
# Epoch 180: Train loss = 7229.2207, Test loss = 7243.0334
# Epoch 181: Train loss = 7231.0379, Test loss = 7245.1336
# Epoch 182: Train loss = 7211.2712, Test loss = 7224.3500
# Epoch 183: Train loss = 7234.2908, Test loss = 7247.2856
# Epoch 184: Train loss = 7236.5792, Test loss = 7250.6962
# Epoch 185: Train loss = 7244.3236, Test loss = 7258.5809
# Epoch 186: Train loss = 7221.8091, Test loss = 7235.8355
# Epoch 187: Train loss = 7240.7509, Test loss = 7254.1129
# Epoch 188: Train loss = 7226.9864, Test loss = 7240.4752
# Epoch 189: Train loss = 7272.2750, Test loss = 7285.7319
# Epoch 190: Train loss = 7216.4570, Test loss = 7230.6784
# Epoch 191: Train loss = 7222.2055, Test loss = 7235.9150
# Epoch 192: Train loss = 7232.8093, Test loss = 7246.8066
# Epoch 193: Train loss = 7252.2302, Test loss = 7266.1855
# Epoch 194: Train loss = 7224.5267, Test loss = 7238.6697
# Epoch 195: Train loss = 7241.7287, Test loss = 7255.5770
# Epoch 196: Train loss = 7277.2460, Test loss = 7291.3831
# Epoch 197: Train loss = 7228.9300, Test loss = 7243.3928
# Epoch 198: Train loss = 7237.7401, Test loss = 7252.0686
# Epoch 199: Train loss = 7202.0526, Test loss = 7216.8957
# Epoch 200: Train loss = 7274.4887, Test loss = 7288.7180
# Epoch 201: Train loss = 7248.0389, Test loss = 7261.3415
# Epoch 202: Train loss = 7250.5025, Test loss = 7264.8326
# Epoch 203: Train loss = 7248.6351, Test loss = 7263.0880
# Epoch 204: Train loss = 7234.9573, Test loss = 7248.8092
# Epoch 205: Train loss = 7219.9755, Test loss = 7234.1985
# Epoch 206: Train loss = 7232.4490, Test loss = 7247.3436
# Epoch 207: Train loss = 7253.9890, Test loss = 7268.5236
# Epoch 208: Train loss = 7193.8098, Test loss = 7208.1225
# Epoch 209: Train loss = 7251.9158, Test loss = 7266.3628
# Epoch 210: Train loss = 7215.1709, Test loss = 7229.4334
# Epoch 211: Train loss = 7225.6308, Test loss = 7239.7355
# Epoch 212: Train loss = 7259.5460, Test loss = 7273.7280
# Epoch 213: Train loss = 7234.4962, Test loss = 7248.6866
# Epoch 214: Train loss = 7229.8347, Test loss = 7243.5868
# Epoch 215: Train loss = 7203.2609, Test loss = 7218.2358
# Epoch 216: Train loss = 7203.2621, Test loss = 7217.4185
# Epoch 217: Train loss = 7213.0314, Test loss = 7227.8693
# Epoch 218: Train loss = 7230.2528, Test loss = 7244.9835
# Epoch 219: Train loss = 7228.0850, Test loss = 7241.8798
# Epoch 220: Train loss = 7252.1174, Test loss = 7266.0146
# Epoch 221: Train loss = 7219.7954, Test loss = 7234.8279
# Epoch 222: Train loss = 7225.6502, Test loss = 7241.0353
# Epoch 223: Train loss = 7206.0619, Test loss = 7221.2072
# Epoch 224: Train loss = 7192.4015, Test loss = 7206.9675
# Epoch 225: Train loss = 7255.4707, Test loss = 7270.7849
# Epoch 226: Train loss = 7178.0807, Test loss = 7192.6770
# Epoch 227: Train loss = 7204.7756, Test loss = 7221.4140
# Epoch 228: Train loss = 7198.4995, Test loss = 7214.6715
# Epoch 229: Train loss = 7193.5084, Test loss = 7209.5310
# Epoch 230: Train loss = 7177.1283, Test loss = 7193.0127
# Epoch 231: Train loss = 7218.7540, Test loss = 7235.1263
# Epoch 232: Train loss = 7192.4626, Test loss = 7208.8702
# Epoch 233: Train loss = 7225.5045, Test loss = 7241.8658
# Epoch 234: Train loss = 7140.7343, Test loss = 7158.3066
# Epoch 235: Train loss = 7173.1214, Test loss = 7190.1436
# Epoch 236: Train loss = 7180.4653, Test loss = 7197.4397
# Epoch 237: Train loss = 7202.3712, Test loss = 7220.0774
# Epoch 238: Train loss = 7186.0371, Test loss = 7203.3519
# Epoch 239: Train loss = 7193.3220, Test loss = 7211.8224
# Epoch 240: Train loss = 7167.9315, Test loss = 7185.7925
# Epoch 241: Train loss = 7201.3026, Test loss = 7218.7142
# Epoch 242: Train loss = 7186.4876, Test loss = 7204.3904
# Epoch 243: Train loss = 7227.0884, Test loss = 7244.1041
# Epoch 244: Train loss = 7204.6829, Test loss = 7222.2975
# Epoch 245: Train loss = 7158.5052, Test loss = 7175.9269
# Epoch 246: Train loss = 7194.2396, Test loss = 7212.8361
# Epoch 247: Train loss = 7169.0971, Test loss = 7186.8253
# Epoch 248: Train loss = 7190.3932, Test loss = 7208.1945
# Epoch 249: Train loss = 7144.1970, Test loss = 7161.8600
# Epoch 250: Train loss = 7141.2296, Test loss = 7159.3232
# Epoch 251: Train loss = 7163.7656, Test loss = 7181.9605
# Epoch 252: Train loss = 7172.2043, Test loss = 7189.6288
# Epoch 253: Train loss = 7199.2984, Test loss = 7218.2109
# Epoch 254: Train loss = 7165.2179, Test loss = 7183.3712
# Epoch 255: Train loss = 7148.3335, Test loss = 7166.7642
# Epoch 256: Train loss = 7204.3787, Test loss = 7223.0655
# Epoch 257: Train loss = 7146.9394, Test loss = 7165.7225
# Epoch 258: Train loss = 7150.4563, Test loss = 7169.8735
# Epoch 259: Train loss = 7160.6107, Test loss = 7178.8001
# Epoch 260: Train loss = 7153.9960, Test loss = 7171.7872
# Epoch 261: Train loss = 7161.4163, Test loss = 7180.1134
# Epoch 262: Train loss = 7129.0172, Test loss = 7147.7728
# Epoch 263: Train loss = 7139.6452, Test loss = 7158.0116
# Epoch 264: Train loss = 7189.6969, Test loss = 7208.5892
# Epoch 265: Train loss = 7188.9421, Test loss = 7207.7066
# Epoch 266: Train loss = 7173.0272, Test loss = 7192.2847
# Epoch 267: Train loss = 7163.6130, Test loss = 7182.5955
# Epoch 268: Train loss = 7163.3619, Test loss = 7182.1585
# Epoch 269: Train loss = 7143.2471, Test loss = 7162.4486
# Epoch 270: Train loss = 7181.3640, Test loss = 7200.6456
# Epoch 271: Train loss = 7182.3043, Test loss = 7201.3921
# Epoch 272: Train loss = 7178.8567, Test loss = 7197.9152
# Epoch 273: Train loss = 7117.6103, Test loss = 7136.0241
# Epoch 274: Train loss = 7195.0418, Test loss = 7213.1162
# Epoch 275: Train loss = 7151.1652, Test loss = 7170.0566
# Epoch 276: Train loss = 7113.2424, Test loss = 7132.3746
# Epoch 277: Train loss = 7098.0332, Test loss = 7117.1851
# Epoch 278: Train loss = 7134.6319, Test loss = 7153.3079
# Epoch 279: Train loss = 7154.2842, Test loss = 7171.9647
# Epoch 280: Train loss = 7157.8632, Test loss = 7176.2675
# Epoch 281: Train loss = 7114.2743, Test loss = 7132.8902
# Epoch 282: Train loss = 7120.9856, Test loss = 7139.1068
# Epoch 283: Train loss = 7182.0707, Test loss = 7201.0200
# Epoch 284: Train loss = 7152.7477, Test loss = 7171.8210
# Epoch 285: Train loss = 7143.0236, Test loss = 7161.5585
# Epoch 286: Train loss = 7180.5780, Test loss = 7199.7815
# Epoch 287: Train loss = 7108.1031, Test loss = 7126.1882
# Epoch 288: Train loss = 7163.8826, Test loss = 7182.7004
# Epoch 289: Train loss = 7161.6381, Test loss = 7181.3465
# Epoch 290: Train loss = 7127.8865, Test loss = 7146.9512
# Epoch 291: Train loss = 7149.3727, Test loss = 7168.0983
# Epoch 292: Train loss = 7171.6701, Test loss = 7190.5323
# Epoch 293: Train loss = 7138.4961, Test loss = 7157.4582
# Epoch 294: Train loss = 7184.7666, Test loss = 7203.2862
# Epoch 295: Train loss = 7158.7245, Test loss = 7178.4338
# Epoch 296: Train loss = 7167.4179, Test loss = 7186.7901
# Epoch 297: Train loss = 7172.7820, Test loss = 7191.9364
# Epoch 298: Train loss = 7167.1574, Test loss = 7186.2461
# Epoch 299: Train loss = 7141.0345, Test loss = 7160.2558
# Epoch 300: Train loss = 7158.3739, Test loss = 7177.1346
# Epoch 301: Train loss = 7132.2689, Test loss = 7151.2102
# Epoch 302: Train loss = 7140.0777, Test loss = 7159.2228
# Epoch 303: Train loss = 7134.1576, Test loss = 7152.7153
# Epoch 304: Train loss = 7187.6563, Test loss = 7206.9124
# Epoch 305: Train loss = 7142.9296, Test loss = 7162.2700
# Epoch 306: Train loss = 7162.0305, Test loss = 7180.8356
# Epoch 307: Train loss = 7186.6661, Test loss = 7205.3312
# Epoch 308: Train loss = 7177.8012, Test loss = 7197.1348
# Epoch 309: Train loss = 7184.8852, Test loss = 7203.7750
# Epoch 310: Train loss = 7163.3928, Test loss = 7183.7880
# Epoch 311: Train loss = 7111.4117, Test loss = 7130.3701
# Epoch 312: Train loss = 7187.8790, Test loss = 7206.7776
# Epoch 313: Train loss = 7140.0165, Test loss = 7158.1961
# Epoch 314: Train loss = 7130.5946, Test loss = 7149.1088
# Epoch 315: Train loss = 7133.3539, Test loss = 7151.6548
# Epoch 316: Train loss = 7135.9674, Test loss = 7154.9103
# Epoch 317: Train loss = 7152.7378, Test loss = 7171.2271
# Epoch 318: Train loss = 7132.3696, Test loss = 7151.7630
# Epoch 319: Train loss = 7171.7085, Test loss = 7190.5294
# Epoch 320: Train loss = 7122.3874, Test loss = 7141.2168
# Epoch 321: Train loss = 7161.8913, Test loss = 7181.0990
# Epoch 322: Train loss = 7117.1518, Test loss = 7135.6906
# Epoch 323: Train loss = 7174.2110, Test loss = 7192.8431
# Epoch 324: Train loss = 7143.7249, Test loss = 7163.0391
# Epoch 325: Train loss = 7167.4132, Test loss = 7186.1321
# Epoch 326: Train loss = 7176.6842, Test loss = 7195.5124
# Epoch 327: Train loss = 7125.8589, Test loss = 7144.5660
# Epoch 328: Train loss = 7183.5688, Test loss = 7202.2112
# Epoch 329: Train loss = 7159.0972, Test loss = 7177.7222
# Epoch 330: Train loss = 7157.0329, Test loss = 7175.8277
# Epoch 331: Train loss = 7151.0386, Test loss = 7170.2569
# Epoch 332: Train loss = 7171.2768, Test loss = 7190.3399
# Epoch 333: Train loss = 7126.6997, Test loss = 7145.8026
# Epoch 334: Train loss = 7122.4994, Test loss = 7141.9680
# Epoch 335: Train loss = 7162.2970, Test loss = 7182.0986
# Epoch 336: Train loss = 7155.9925, Test loss = 7175.7583
# Epoch 337: Train loss = 7158.4569, Test loss = 7177.4587
# Epoch 338: Train loss = 7133.8814, Test loss = 7153.3169
# Epoch 339: Train loss = 7181.0648, Test loss = 7199.2909
# Epoch 340: Train loss = 7143.1934, Test loss = 7162.2715
# Epoch 341: Train loss = 7171.3924, Test loss = 7190.8103
# Epoch 342: Train loss = 7160.6376, Test loss = 7179.5222
# Epoch 343: Train loss = 7161.4292, Test loss = 7181.0049
# Epoch 344: Train loss = 7157.4064, Test loss = 7176.2366
# Epoch 345: Train loss = 7161.7431, Test loss = 7180.5727
# Epoch 346: Train loss = 7191.6768, Test loss = 7211.8538
# Epoch 347: Train loss = 7138.6593, Test loss = 7158.1510
# Epoch 348: Train loss = 7127.3643, Test loss = 7147.0237
# Epoch 349: Train loss = 7168.0765, Test loss = 7187.7462
# Epoch 350: Train loss = 7121.0172, Test loss = 7140.2600
# Epoch 351: Train loss = 7149.9353, Test loss = 7169.3986
# Epoch 352: Train loss = 7167.5100, Test loss = 7186.5369
# Epoch 353: Train loss = 7163.1000, Test loss = 7182.9313
# Epoch 354: Train loss = 7167.8226, Test loss = 7187.1275
# Epoch 355: Train loss = 7172.4851, Test loss = 7191.9332
# Epoch 356: Train loss = 7184.2082, Test loss = 7203.1565
# Epoch 357: Train loss = 7122.0961, Test loss = 7141.4897
# Epoch 358: Train loss = 7148.0495, Test loss = 7167.2546
# Epoch 359: Train loss = 7165.5875, Test loss = 7184.5563
# Epoch 360: Train loss = 7146.7572, Test loss = 7165.9366
# Epoch 361: Train loss = 7139.0982, Test loss = 7159.5518
# Epoch 362: Train loss = 7142.8321, Test loss = 7162.1398
# Epoch 363: Train loss = 7138.9741, Test loss = 7158.6477
# Epoch 364: Train loss = 7159.0195, Test loss = 7178.5556
# Epoch 365: Train loss = 7174.6606, Test loss = 7194.9067
# Epoch 366: Train loss = 7182.0670, Test loss = 7202.1606
# Epoch 367: Train loss = 7122.7145, Test loss = 7142.3718
# Epoch 368: Train loss = 7188.8976, Test loss = 7208.8281
# Epoch 369: Train loss = 7117.4432, Test loss = 7136.3321
# Epoch 370: Train loss = 7173.2780, Test loss = 7192.5904
# Epoch 371: Train loss = 7139.5140, Test loss = 7159.2693
# Epoch 372: Train loss = 7155.3714, Test loss = 7175.1832
# Epoch 373: Train loss = 7157.0920, Test loss = 7176.4623
# Epoch 374: Train loss = 7139.0741, Test loss = 7158.7136
# Epoch 375: Train loss = 7187.2428, Test loss = 7206.9601
# Epoch 376: Train loss = 7185.4563, Test loss = 7205.5276
# Epoch 377: Train loss = 7193.8464, Test loss = 7213.5215
# Epoch 378: Train loss = 7158.7430, Test loss = 7178.6378
# Epoch 379: Train loss = 7134.4560, Test loss = 7154.0245
# Epoch 380: Train loss = 7130.2816, Test loss = 7149.6077
# Epoch 381: Train loss = 7135.4037, Test loss = 7155.1231
# Epoch 382: Train loss = 7168.7679, Test loss = 7188.1561
# Epoch 383: Train loss = 7159.5979, Test loss = 7179.2141
# Epoch 384: Train loss = 7172.8347, Test loss = 7192.4222
# Epoch 385: Train loss = 7155.5269, Test loss = 7175.1036
# Epoch 386: Train loss = 7104.3658, Test loss = 7124.6821
# Epoch 387: Train loss = 7148.6173, Test loss = 7168.3517
# Epoch 388: Train loss = 7147.5141, Test loss = 7167.6374
# Epoch 389: Train loss = 7124.0093, Test loss = 7144.1573
# Epoch 390: Train loss = 7185.4566, Test loss = 7205.7070
# Epoch 391: Train loss = 7148.0063, Test loss = 7167.5791
# Epoch 392: Train loss = 7165.5574, Test loss = 7185.3441
# Epoch 393: Train loss = 7152.5024, Test loss = 7172.2944
# Epoch 394: Train loss = 7156.4486, Test loss = 7175.4783
# Epoch 395: Train loss = 7174.2964, Test loss = 7194.2461
# Epoch 396: Train loss = 7162.5428, Test loss = 7182.7452
# Epoch 397: Train loss = 7195.5996, Test loss = 7216.2757
# Epoch 398: Train loss = 7142.3170, Test loss = 7162.3263
# Epoch 399: Train loss = 7180.1815, Test loss = 7200.2211
# Elapsed time = 1351.7486

# %%
# Print elapsed time
print(f"Elapsed time = {t_elapsed:.4f} s")
print(f"Elapsed time = {t_elapsed/60:.4f} min")
print(f"Elapsed time = {t_elapsed/(60*60):.4f} h")
# Out:
# Elapsed time = 1351.7486 s
# Elapsed time = 22.5291 min
# Elapsed time = 0.3755 h

# %%
args["save_vae"]
# Out:
# True

# %%
# plot the latest epochs 

start_ind = 200

plt.figure()
plt.plot(np.arange(len(loss_history_train[start_ind:])), loss_history_train[start_ind:], label="train loss")
plt.plot(np.arange(len(loss_history_test[start_ind:])), loss_history_test[start_ind:], label="test loss")
plt.xlabel("epochs")
plt.ylabel("train error")
plt.legend()
plt.title("Train and test losses, PriorCVAE")
plt.show()

# %%
model.state_dict()['encoder.linear.weight'] == best_model.state_dict()['encoder.linear.weight']
# Out:
# tensor([[True, True, True,  ..., True, True, True],
#         [True, True, True,  ..., True, True, True],
#         [True, True, True,  ..., True, True, True],
#         ...,
#         [True, True, True,  ..., True, True, True],
#         [True, True, True,  ..., True, True, True],
#         [True, True, True,  ..., True, True, True]])

# %%
model = best_model
del best_model

# %%
###### Sampling 5 draws from learnt model
#model.eval() # model in eval mode

#n_samps = 20
#z = torch.randn(n_samps, z_dim).to(device) # random draw
#c = torch.bernoulli(torch.ones(n_samps) * 0.5)

#with torch.no_grad():
#    sampled_y = model.decoder(z, c)

#fig = plt.figure()
#ax = fig.add_subplot(111)
#for no, y in enumerate(sampled_y):
#    if c[no] == 0:
#        col = 'blue'  
#    else:
#        col = 'orange'
#    ax.plot(train_ds.x[0], y.cpu().numpy(), color=col)

#ax.set_xlabel('$x$')
#ax.set_ylabel('$y=CVAE_f(x)$')
#ax.set_title('20 different function realizations at fixed 100 points\n'
#    'sampled from a CVAE learned with prior as GP (RBF)')

# %%
import pickle

model_save_name = 'PriorVAE_gp1d_n'+str(args["input_dim"])+'_h'+str(args["hidden_dim"])+'_z'+str(args["z_dim"])+'_epochs'+str(args["n_epochs"])+'_b'+str(args["batch_size"])+'_continuous.pt'
loss_train_name = 'PriorVAE_gp1d_n'+str(args["input_dim"])+'_h'+str(args["hidden_dim"])+'_z'+str(args["z_dim"])+'_epochs'+str(args["n_epochs"])+'_b'+str(args["batch_size"])+'_loss_train_continuous'
loss_test_name =  'PriorVAE_gp1d_n'+str(args["input_dim"])+'_h'+str(args["hidden_dim"])+'_z'+str(args["z_dim"])+'_epochs'+str(args["n_epochs"])+'_b'+str(args["batch_size"])+'_loss_test_continuous'
print(model_save_name) 
print(loss_train_name) 
print(loss_test_name) 

PATH = cwd + F"/trained_models/{model_save_name}" 
loss_train_name = cwd +"/trained_models/" + loss_train_name
loss_test_name = cwd + "/trained_models/" + loss_test_name

if args["save_vae"] == True:    
    print("VAE model saved")
    torch.save(model.state_dict(), PATH)
    
    with open(loss_train_name, "wb") as fp:  
        pickle.dump(loss_history_train, fp)
    with open(loss_test_name, "wb") as fp:  
        pickle.dump(loss_history_test, fp)
        
elif args["load_vae"] == True:
    model.load_state_dict(torch.load(PATH))
    
    with open(loss_train_name, "rb") as fp:   
        loss_history_train = pickle.load(fp)
    with open(loss_test_name, "rb") as fp:   
        loss_history_test = pickle.load(fp)

    print("VAE model loaded")
else:
    print("no model loaded")
# Out:
# PriorVAE_gp1d_n80_h60_z40_epochs400_b1000_continuous.pt
# PriorVAE_gp1d_n80_h60_z40_epochs400_b1000_loss_train
# PriorVAE_gp1d_n80_h60_z40_epochs400_b1000_loss_test
# VAE model saved

# %% [markdown]
# ## Visual diagnostics of how well we have learnt

# %%
def MMD(x, y, kernel="multiscale"):
    """Emprical maximum mean discrepancy. The lower the result, the more evidence that distributions are the same.

    Args:
        x: first sample, distribution P
        y: second sample, distribution Q
        kernel: kernel type such as "multiscale" or "rbf"
    """
    xx, yy, zz = torch.mm(x, x.t()), torch.mm(y, y.t()), torch.mm(x, y.t())
    rx = (xx.diag().unsqueeze(0).expand_as(xx))
    ry = (yy.diag().unsqueeze(0).expand_as(yy))
    
    dxx = rx.t() + rx - 2. * xx # Used for A in (1)
    dyy = ry.t() + ry - 2. * yy # Used for B in (1)
    dxy = rx.t() + ry - 2. * zz # Used for C in (1)
    
    XX, YY, XY = (torch.zeros(xx.shape).to(device),
                  torch.zeros(xx.shape).to(device),
                  torch.zeros(xx.shape).to(device))
    
    if kernel == "multiscale":
        
        bandwidth_range = [0.2, 0.5, 0.9, 1.3]
        for a in bandwidth_range:
            XX += a**2 * (a**2 + dxx)**-1
            YY += a**2 * (a**2 + dyy)**-1
            XY += a**2 * (a**2 + dxy)**-1
            
    if kernel == "rbf":
      
        bandwidth_range = [10, 15, 20, 50]
        for a in bandwidth_range:
            XX += torch.exp(-0.5*dxx/a)
            YY += torch.exp(-0.5*dyy/a)
            XY += torch.exp(-0.5*dxy/a)
      
    return torch.mean(XX + YY - 2. * XY)

# %%
def demo_plots(conditional =False, 
               ttl1="GP priors to encode",
               ttl2="Priors learnt by VAE", 
               ylbl1='$y=f_{GP}(x)$', 
               ylbl2='$y=f_{VAE}(x)$', 
               ls=None):

    n_samps = 100000
    if conditional == True:
        dataset = GP1D(n_dataPoints=args["input_dim"], n_samples=n_samps, ls=ls)
        ttl2="Priors learnt by CVAE"
        ylbl2='$y=f_{CVAE}(x)$'
    else:
        dataset = GP1D(n_dataPoints=args["input_dim"], n_samples=n_samps, ls=ls)    

    gp_draws = dataset.y
    x = dataset.x[0,:]
    gp_draws = gp_draws.transpose()

    model.eval() # model in eval mode
    z = torch.randn(n_samps, z_dim).to(device) # random draw

    if conditional == True:
        c = torch.ones(n_samps) * ls
        c = c[:, None]
        with torch.no_grad():
            vae_draws = model.decoder(z, c).numpy().transpose()
    else:
        with torch.no_grad():
            vae_draws = model.decoder(z, c=None).numpy().transpose()

    mean_gp = np.nanmean(gp_draws, axis=1)
    q025_gp = np.quantile(gp_draws, 0.025, axis=1)
    q975_gp = np.quantile(gp_draws, 0.975, axis=1)
    #print(mean_gp.shape)

    mean_vae = np.nanmean(vae_draws, axis=1)
    q025_vae = np.quantile(vae_draws, 0.025, axis=1)
    q975_vae = np.quantile(vae_draws, 0.975, axis=1)

    #print("q025: ")
    #print(q025_gp)
    #print(q025_vae)
    #print("q975: ")
    #print(q975_gp)
    #print(q975_vae)

    # plot results
    fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12,3))

    _min, _max = -3, 3
    lines_alpha_gp = 0.5
    lines_alpha_vae = 0.5
    N_lines = 20

    if ls==None:
        ttl = ttl1
    else:
        ttl = ttl1+ ", ls=" + str(ls)
    ylbl = ylbl1

    for j in range(N_lines):
        itr = int(gp_draws.shape[1]/N_lines)
        axs[0].plot(x, gp_draws[:,j*itr], alpha=lines_alpha_gp, label="")

    axs[0].plot(x, gp_draws[:,0], alpha=lines_alpha_gp, color="darkgreen", label="GP draws")  
    axs[0].fill_between(x, q025_gp[0], q975_gp[1], alpha=0.1, interpolate=True, label="95% BCI")
    axs[0].plot(x, mean_gp, label="mean")
    axs[0].legend(loc=4)
    axs[0].set_ylim([_min, _max])
    axs[0].set_xlabel('$x$')
    axs[0].set_ylabel(ylbl)
    axs[0].set_title(ttl)

    if ls==None:
        tt2 = ttl2
    else:
        tt2 = ttl2+ ", ls=" + str(ls)
    ylbl=ylbl2

    for j in range(N_lines):
        itr = int(vae_draws.shape[1]/N_lines)
        axs[1].plot(x, vae_draws[:,j*itr], alpha=lines_alpha_vae, label="")

    axs[1].plot(x, vae_draws[:,0], alpha=lines_alpha_vae, color="darkgreen", label="VAE draws")  
    axs[1].fill_between(x, q025_vae[0], q975_vae[1], alpha=0.1, interpolate=True, label="95% BCI")
    axs[1].plot(x, mean_vae, label="mean")
    axs[1].legend(loc=4)
    axs[1].set_ylim([_min, _max])
    axs[1].set_xlabel('$x$')
    axs[1].set_ylabel(ylbl)
    axs[1].set_title(tt2)

    axs[2].fill_between(x, q025_gp[0], q975_gp[1], alpha=0.1, interpolate=True, label="95% BCI")
    axs[2].plot(x, mean_gp, label="mean")
    axs[2].fill_between(x, q025_vae[0], q975_vae[1], alpha=0.1, interpolate=True, label="95% BCI")
    axs[2].plot(x, mean_vae, label="mean")
    axs[2].legend(loc=4)
    axs[2].set_ylim([_min, _max])

    plt.show()

    m_vae = np.cov((vae_draws))
    m_gp = np.cov((gp_draws))
    print('Frobenius norm = ' + str(np.linalg.norm(m_gp - m_vae,  'fro')))
    
    gg = torch.from_numpy(gp_draws)
    vv = torch.from_numpy(vae_draws)
    print('MMD, multiscale = ' + str(MMD(gg, vv)))
    print('MMD, rbf = ' + str(MMD(gg, vv, "rbf")))
    
    cmap_choice = 'inferno'
    
    gp_cm_ttl = 'GP covariance matrix'
    if ls is not None:
        gp_cm_ttl = gp_cm_ttl + ', c='+ str(ls)
    vae_cm_ttl = 'VAE covariance matrix'
    if ls is not None:
        vae_cm_ttl = vae_cm_ttl +', c='+ str(ls)


    #'plasma'
    #'inferno'
    fig, axs = plt.subplots(nrows=1, ncols=2, figsize = (8,4))
    axs[0].imshow(m_gp, cmap=cmap_choice)
    axs[0].axis('off')

    axs[0].set_title(gp_cm_ttl)
    #axs[0].set_title('GP covariance matrix, c=' + str(ls))

    axs[1].imshow(m_vae, cmap=cmap_choice)
    axs[1].axis('off')
    axs[1].set_title(vae_cm_ttl)

    plt.show()
    
    #return (gp_draws, vae_draws)

# %%
# 1).
demo_plots(conditional=False)
# Out:
# Frobenius norm = 3.1909410855344293
# MMD, multiscale = tensor(0.1014)
# MMD, rbf = tensor(0.1157)

# %%
# 2).
demo_plots(conditional=False, ls=0.4)
# Out:
# Frobenius norm = 9.1173493045069
# MMD, multiscale = tensor(0.1023)
# MMD, rbf = tensor(0.1279)

# %%
# 3).
demo_plots(conditional=False, ls=0.05)
# Out:
# Frobenius norm = 45.52074965945702
# MMD, multiscale = tensor(0.1012)
# MMD, rbf = tensor(0.1156)

# %%
demo_plots(conditional=False, ls=0.9)
# Out:
# Frobenius norm = 22.937949059790828
# MMD, multiscale = tensor(0.1062)
# MMD, rbf = tensor(0.1914)

# %%
#?plt.psd

# %% [markdown]
# # Inference

# %% [markdown]
# ## Generate data

# %%
x = np.linspace(0, 1, args["input_dim"])   

rng_key_draw =  random.PRNGKey(1)
rng_key, rng_key_post, rng_key_preds, rng_key_draw = random.split(rng_key_draw, 4)

gp_predictive = Predictive(GP, num_samples=1)
draws = gp_predictive(rng_key_draw, x=x, jitter=1e-6, 
                      noise=True, length=args["true_ls"], var=1)

gp_draw = draws['f'].T
y_draw = draws['y'].T

obs_idx_lst = []
obs_idx_lst.append([10, 30, 54, 64]) # points correspond to n=80, ls=0.2, rng1
i = 0

# choose indices of data points for inference
obs_idx = jnp.array(obs_idx_lst[i])

y_obs = y_draw[obs_idx,0]
x_obs = x[np.array(obs_idx)]

args['y_obs'] = y_obs
args['obs_idx'] = obs_idx
args['x_obs'] = x_obs

plt.plot(x, gp_draw, label="ground truth", color="orange")
plt.scatter(x_obs, y_obs, color="red", label="observed data", s=60)
plt.title('Ground truth, corresponds to ls=' + str(args["true_ls"]))
# Out:
# Text(0.5, 1.0, 'Ground truth, corresponds to ls=0.2')

# %% [markdown]
# ## Numpyro model - PriorVAE

# %%
# decoder parameters

model = model.to('cpu')
decoder_dict = model.decoder.state_dict()
decoder_dict.keys()

W1 = decoder_dict['linear.weight'].T.numpy()
B1 = decoder_dict['linear.bias'].numpy()
W2 = decoder_dict['out.weight'].T.numpy()
B2 = decoder_dict['out.bias'].T.numpy()

print(W1.shape)
print(B1.shape)
print(W2.shape)
print(B2.shape)
# Out:
# (40, 60)
# (60,)
# (60, 80)
# (80,)
# /var/folders/q3/n2z18__9281b8xfhctcpxfsr0000gn/T/ipykernel_60798/2358429211.py:10: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matricesor `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at  /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1659484782168/work/aten/src/ATen/native/TensorShape.cpp:2985.)
#   B2 = decoder_dict['out.bias'].T.numpy()

# %%
def c_decoder_numpy(z, W1, B1, W2, B2, c=None):
   
    def linear(z, W, B):
        lin_out = jnp.matmul(z, W) + B
        return lin_out

    if c is not None:
        c = jnp.array(c).reshape(1)
        z = jnp.concatenate([z, c], axis=0)

    hidden = jax.nn.relu(linear(z, W1, B1))
    out = linear(hidden, W2, B2)
    return out

def numpyro_model(z_dim, y=None, obs_idx=None, c=None):

    z = numpyro.sample("z", npdist.Normal(jnp.zeros(z_dim), jnp.ones(z_dim))) 
    
    f = numpyro.deterministic("f", c_decoder_numpy(z, W1, B1, W2, B2, c))
    sigma = numpyro.sample("sigma", npdist.HalfNormal(0.1))

    if y is None: # durinig prediction
        y_pred = numpyro.sample("y_pred", npdist.Normal(f, sigma))
    else: # during inference
        y = numpyro.sample("y", npdist.Normal(f[obs_idx], sigma), obs=y)

# %%
def run_mcmc_vae(rng_key, numpyro_model, args, verbose=True):
    start = time.time()

    init_strategy = init_to_median(num_samples=10)
    kernel = NUTS(numpyro_model, init_strategy=init_strategy)
    mcmc = MCMC(
        kernel,
        num_warmup=args["num_warmup"],
        num_samples=args["num_samples"],
        num_chains=args["num_chains"],
        thinning=args["thinning"],
        progress_bar=False if "NUMPYRO_SPHINXBUILD" in os.environ else True,
    )
    start = time.time()
    mcmc.run(rng_key, args["z_dim"], args["y_obs"], args["obs_idx"])
    t_elapsed = time.time() - start
    if verbose:
        mcmc.print_summary(exclude_deterministic=False)
    
    print("\nMCMC elapsed time:", round(t_elapsed), "s")
    ss = numpyro.diagnostics.summary(mcmc.get_samples(group_by_chain=True))
    r = np.mean(ss['f']['n_eff'])
    print("Average ESS for all VAE-GP effects : " + str(round(r)))

    return (mcmc, mcmc.get_samples(), t_elapsed)

# %% [markdown]
# ## Inference on observed data - PriorVAE

# %%
rng_key, rng_key_prior, rng_key_post, rng_key_pred = random.split(rng_key, 4)

mcmc_vae, mcmc_vae_samples, t_elapsed = run_mcmc_vae(rng_key_post, numpyro_model, args)
# Out:
#   0%|          | 0/55000 [00:00<?, ?it/s]
#   0%|          | 0/55000 [00:00<?, ?it/s]
#   0%|          | 0/55000 [00:00<?, ?it/s]
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#       f[0]      0.04      0.28      0.06     -0.41      0.45   7328.33      1.00
#       f[1]      0.05      0.28      0.07     -0.42      0.46   7159.95      1.00
#       f[2]      0.05      0.28      0.07     -0.41      0.46   7170.78      1.00
#       f[3]      0.05      0.27      0.07     -0.40      0.44   7049.72      1.00
#       f[4]      0.04      0.26      0.06     -0.39      0.41   7022.11      1.00
#       f[5]      0.04      0.24      0.06     -0.35      0.39   7142.90      1.00
#       f[6]      0.03      0.21      0.05     -0.33      0.34   7694.74      1.00
#       f[7]      0.01      0.19      0.03     -0.29      0.30   9009.00      1.00
#       f[8]     -0.01      0.16      0.01     -0.27      0.24  13998.15      1.00
#       f[9]     -0.03      0.14     -0.01     -0.26      0.19  31239.39      1.00
#      f[10]     -0.06      0.13     -0.04     -0.27      0.14  82222.46      1.00
#      f[11]     -0.09      0.13     -0.08     -0.30      0.12  54301.32      1.00
#      f[12]     -0.13      0.14     -0.13     -0.35      0.10  24729.00      1.00
#      f[13]     -0.17      0.17     -0.18     -0.43      0.10  14611.76      1.00
#      f[14]     -0.21      0.19     -0.24     -0.50      0.11  10895.55      1.00
#      f[15]     -0.26      0.22     -0.29     -0.58      0.11   8969.49      1.00
#      f[16]     -0.31      0.25     -0.34     -0.65      0.10   8031.04      1.00
#      f[17]     -0.36      0.27     -0.39     -0.73      0.08   7544.46      1.00
#      f[18]     -0.41      0.28     -0.43     -0.80      0.05   7358.97      1.00
#      f[19]     -0.45      0.29     -0.48     -0.85      0.01   7115.72      1.00
#      f[20]     -0.50      0.29     -0.51     -0.91     -0.04   6567.33      1.00
#      f[21]     -0.54      0.29     -0.55     -0.95     -0.08   6210.00      1.00
#      f[22]     -0.57      0.28     -0.59     -0.98     -0.13   6070.72      1.00
#      f[23]     -0.61      0.26     -0.62     -0.99     -0.19   6238.48      1.00
#      f[24]     -0.64      0.24     -0.65     -1.01     -0.25   6371.65      1.00
#      f[25]     -0.67      0.22     -0.68     -1.01     -0.31   6684.86      1.00
#      f[26]     -0.70      0.20     -0.71     -1.01     -0.36   7228.03      1.00
#      f[27]     -0.71      0.18     -0.73     -1.00     -0.40   8088.25      1.00
#      f[28]     -0.72      0.17     -0.75     -0.98     -0.45   9846.61      1.00
#      f[29]     -0.73      0.15     -0.76     -0.95     -0.47  14987.58      1.00
#      f[30]     -0.73      0.15     -0.77     -0.93     -0.47  29193.77      1.00
#      f[31]     -0.73      0.15     -0.76     -0.95     -0.47  31310.72      1.00
#      f[32]     -0.71      0.16     -0.74     -0.95     -0.45  25487.41      1.00
#      f[33]     -0.69      0.17     -0.71     -0.97     -0.40  18927.32      1.00
#      f[34]     -0.67      0.19     -0.68     -0.97     -0.35  14706.29      1.00
#      f[35]     -0.63      0.21     -0.64     -0.95     -0.28  11972.74      1.00
#      f[36]     -0.59      0.22     -0.60     -0.95     -0.23  10119.20      1.00
#      f[37]     -0.55      0.24     -0.56     -0.94     -0.17   8597.62      1.00
#      f[38]     -0.51      0.25     -0.52     -0.91     -0.09   7191.51      1.00
#      f[39]     -0.47      0.26     -0.48     -0.89     -0.04   6274.85      1.00
#      f[40]     -0.44      0.27     -0.45     -0.87      0.01   5737.36      1.00
#      f[41]     -0.40      0.28     -0.41     -0.84      0.07   5389.52      1.00
#      f[42]     -0.36      0.28     -0.37     -0.82      0.10   5148.13      1.00
#      f[43]     -0.32      0.28     -0.33     -0.78      0.13   5012.63      1.00
#      f[44]     -0.28      0.27     -0.29     -0.75      0.15   4938.44      1.00
#      f[45]     -0.25      0.26     -0.25     -0.69      0.18   5009.62      1.00
#      f[46]     -0.21      0.25     -0.21     -0.64      0.19   5156.16      1.00
#      f[47]     -0.18      0.24     -0.17     -0.59      0.20   5487.46      1.00
#      f[48]     -0.15      0.22     -0.14     -0.53      0.20   6059.20      1.00
#      f[49]     -0.12      0.20     -0.11     -0.47      0.20   6999.15      1.00
#      f[50]     -0.11      0.18     -0.09     -0.44      0.17   8734.02      1.00
#      f[51]     -0.10      0.17     -0.08     -0.39      0.16  11926.15      1.00
#      f[52]     -0.10      0.15     -0.07     -0.36      0.14  20065.22      1.00
#      f[53]     -0.10      0.14     -0.07     -0.34      0.11  34217.91      1.00
#      f[54]     -0.10      0.13     -0.07     -0.32      0.09  50524.41      1.00
#      f[55]     -0.10      0.12     -0.08     -0.31      0.08  43678.02      1.00
#      f[56]     -0.11      0.12     -0.10     -0.31      0.07  25705.95      1.00
#      f[57]     -0.12      0.12     -0.11     -0.31      0.07  16721.32      1.00
#      f[58]     -0.14      0.12     -0.13     -0.33      0.05  13002.95      1.00
#      f[59]     -0.15      0.12     -0.14     -0.34      0.04  11831.92      1.00
#      f[60]     -0.17      0.11     -0.16     -0.36      0.02  12487.90      1.00
#      f[61]     -0.19      0.11     -0.19     -0.37      0.00  16584.13      1.00
#      f[62]     -0.21      0.11     -0.21     -0.38     -0.02  34500.31      1.00
#      f[63]     -0.22      0.11     -0.23     -0.40     -0.04 104070.41      1.00
#      f[64]     -0.24      0.12     -0.26     -0.43     -0.04 101815.23      1.00
#      f[65]     -0.26      0.13     -0.27     -0.47     -0.05  46381.68      1.00
#      f[66]     -0.27      0.15     -0.28     -0.52     -0.03  17169.81      1.00
#      f[67]     -0.28      0.18     -0.29     -0.57      0.01  10034.44      1.00
#      f[68]     -0.29      0.21     -0.30     -0.64      0.05   7304.03      1.00
#      f[69]     -0.30      0.24     -0.30     -0.70      0.09   6005.37      1.00
#      f[70]     -0.31      0.28     -0.30     -0.78      0.12   5321.10      1.00
#      f[71]     -0.32      0.31     -0.31     -0.83      0.19   4864.88      1.00
#      f[72]     -0.33      0.34     -0.31     -0.88      0.23   4572.83      1.00
#      f[73]     -0.33      0.37     -0.31     -0.93      0.26   4375.90      1.00
#      f[74]     -0.33      0.39     -0.31     -0.99      0.27   4227.66      1.00
#      f[75]     -0.32      0.41     -0.30     -0.99      0.32   4113.85      1.00
#      f[76]     -0.30      0.42     -0.28     -0.99      0.35   4022.33      1.00
#      f[77]     -0.29      0.42     -0.27     -0.99      0.37   3939.67      1.00
#      f[78]     -0.27      0.42     -0.26     -0.96      0.38   3871.42      1.00
#      f[79]     -0.26      0.41     -0.24     -0.92      0.39   3792.64      1.00
#      sigma      0.10      0.07      0.09      0.01      0.20   1489.19      1.00
#       z[0]     -0.01      0.99     -0.02     -1.60      1.65  13094.74      1.00
#       z[1]     -0.03      0.99     -0.05     -1.71      1.58  19559.60      1.00
#       z[2]      0.05      0.22      0.04     -0.32      0.43   6586.39      1.00
#       z[3]     -0.07      1.07     -0.05     -1.74      1.65    609.18      1.00
#       z[4]     -0.01      0.99     -0.01     -1.66      1.61  16306.35      1.00
#       z[5]     -0.01      0.99     -0.03     -1.58      1.63   3075.56      1.00
#       z[6]     -0.03      0.99     -0.03     -1.66      1.60  10019.18      1.00
#       z[7]      0.04      0.99      0.04     -1.59      1.65   4732.97      1.00
#       z[8]     -0.05      0.99     -0.05     -1.68      1.58  15966.09      1.00
#       z[9]      0.01      1.00      0.02     -1.63      1.64   3429.01      1.00
#      z[10]      0.01      1.00      0.00     -1.63      1.64   6358.03      1.00
#      z[11]      0.01      0.99      0.01     -1.60      1.66  18890.35      1.00
#      z[12]      0.04      1.05      0.01     -1.73      1.73    577.61      1.01
#      z[13]     -0.02      0.99     -0.03     -1.62      1.64   6475.54      1.00
#      z[14]      1.58      0.65      1.73      0.55      2.52   6924.28      1.00
#      z[15]      0.42      0.12      0.42      0.23      0.61   6956.68      1.00
#      z[16]     -0.01      0.99     -0.00     -1.65      1.62  23903.47      1.00
#      z[17]     -0.01      0.99      0.00     -1.67      1.59  17060.96      1.00
#      z[18]      0.45      1.03      0.43     -1.23      2.14   5921.74      1.00
#      z[19]     -0.59      0.41     -0.60     -1.29      0.04  22548.79      1.00
#      z[20]      0.02      1.09      0.02     -1.76      1.87   2839.97      1.00
#      z[21]     -0.03      1.00     -0.04     -1.68      1.59   4360.69      1.00
#      z[22]     -0.01      0.99     -0.03     -1.61      1.66  10934.80      1.00
#      z[23]     -0.00      1.00     -0.01     -1.63      1.66   5244.40      1.00
#      z[24]      0.03      0.99      0.03     -1.63      1.62   5511.30      1.00
#      z[25]     -0.03      1.02     -0.03     -1.73      1.64   2273.89      1.00
#      z[26]     -0.00      0.99     -0.00     -1.63      1.61   4566.03      1.00
#      z[27]     -0.02      1.00     -0.02     -1.62      1.65   3368.25      1.00
#      z[28]     -0.03      0.99     -0.03     -1.68      1.57  18993.24      1.00
#      z[29]     -0.02      0.99     -0.03     -1.67      1.57  19150.83      1.00
#      z[30]      0.01      0.99      0.01     -1.66      1.58  24356.13      1.00
#      z[31]      0.04      1.01      0.05     -1.54      1.78   1420.99      1.00
#      z[32]      0.07      1.03      0.06     -1.62      1.76   1018.21      1.00
#      z[33]     -0.03      0.99     -0.05     -1.62      1.62  11497.58      1.00
#      z[34]     -0.01      1.00      0.00     -1.66      1.67   2328.62      1.00
#      z[35]      0.00      1.00     -0.00     -1.58      1.69   2082.31      1.00
#      z[36]      0.00      1.00      0.00     -1.65      1.61   8712.72      1.00
#      z[37]     -0.02      0.99     -0.04     -1.64      1.60  20303.03      1.00
#      z[38]      0.00      0.99     -0.00     -1.61      1.65  23108.12      1.00
#      z[39]     -0.03      0.98     -0.06     -1.64      1.61  14579.20      1.00
#
# Number of divergences: 15201
#
# MCMC elapsed time: 11 s
# Average ESS for all VAE-GP effects : 15793

# %%
predictive = Predictive(numpyro_model, mcmc_vae_samples)

predictions_vae = predictive(rng_key_pred, z_dim=args["z_dim"], c=None)["f"]
mean_post_pred_vae = jnp.mean(predictions_vae, axis=0)
hpdi_post_pred_vae = hpdi(predictions_vae, 0.9)
percentiles_vae = np.percentile(predictions_vae, [5.0, 95.0], axis=0)

N_lines = 10
plt.plot(x, gp_draw, label="ground truth", color="orange")
plt.scatter(x_obs, y_obs, color="red", label="observed data", s=60)
plt.plot(x, mean_post_pred_vae, label="predicted mean VAE")

plt.fill_between(x, percentiles_vae[0, :], percentiles_vae[1, :], alpha=0.3, interpolate=True, label="VAE posterior: 90% BCI")
for j in range(N_lines):
    itr = int(predictions_vae.shape[0]/N_lines)
    plt.plot(x, predictions_vae[j* itr,:], alpha=0.2, color="darkgreen", label="")

plt.title('PriorVAE inference')
#plt.legend(loc=1)
plt.ylim([-2, 1])
# Out:
# (-2.0, 1.0)

# %%
#true_ls_lst = [0.2, 0.3,  0.5]

#rng_key_lst = [ random.PRNGKey(1), random.PRNGKey(2), random.PRNGKey(1)]

#obs_idx_lst = []
#gp_draw_lst = []

#obs_idx_lst.append([10, 30, 54, 64])
#obs_idx_lst.append([25,28, 70])
#obs_idx_lst.append([15,  54, 63])

#mean_post_pred_lst = []
#perc_post_pred_lst = []
#x_obs_lst = []
#y_obs_lst = []
#predictions_lst = []

#x = train_ds[0][0]

#for i in range(len(true_ls_lst)):
#    true_ls = true_ls_lst[i]
#    rng_key_draw = rng_key_lst[i]
    
#    # generate data
#    rng_key, rng_key_post, rng_key_preds, rng_key_draw = random.split(rng_key_draw, 4)

#    gp_predictive = Predictive(GP, num_samples=1)
#    draws = gp_predictive(rng_key_draw, x=x, jitter=1e-6, 
#                          noise=True, length=true_ls, var=1)

#    gp_draw = draws['f'].T
#    y_draw = draws['y'].T
    
  
    # choose indices of data points for inference
#    obs_idx = jnp.array(obs_idx_lst[i])

#    y_obs = y_draw[obs_idx,0]
#    x_obs = x[np.array(obs_idx)]

#    args['y_obs'] = y_obs
#    args['obs_idx'] = obs_idx
#    args['x_obs'] = x_obs
    
#    # inference
#    mcmc_vae, mcmc_vae_samples, t_elapsed = run_mcmc_vae(rng_key_post, numpyro_model, args)
    
#    predictive = Predictive(numpyro_model, mcmc_vae_samples)

#    predictions_vae = predictive(rng_key_pred, z_dim=args["z_dim"], c=None)["f"]
#    mean_post_pred_vae = jnp.mean(predictions_vae, axis=0)
#    percentiles_vae = np.percentile(predictions_vae, [5.0, 95.0], axis=0)
    
#    mean_post_pred_lst.append(mean_post_pred_vae)
#    perc_post_pred_lst.append(percentiles_vae)
#    gp_draw_lst.append(gp_draw)
#    x_obs_lst.append(x_obs)
#    y_obs_lst.append(y_obs)
#    predictions_lst.append(predictions_vae)

# %%
# plot results
#fig, axs = plt.subplots(nrows=1, ncols=len(mean_post_pred_lst), figsize=(20,5))
#_min, _max = np.amin(perc_post_pred_lst), np.amax(perc_post_pred_lst)

#for i in range(len(mean_post_pred_lst)):
#    #axs[i].set_ylim([_min, _max])
#    axs[i].plot(x, gp_draw_lst[i], label="ground truth", color="orange")
#    axs[i].scatter(x_obs_lst[i], y_obs_lst[i], color="red", label="observed data", s=60)
#    axs[i].fill_between(x, 
#                      perc_post_pred_lst[i][0], perc_post_pred_lst[i][1], 
#                      alpha=0.3, interpolate=True, label="VAE posterior: 90% BCI")
#    axs[i].plot(x, mean_post_pred_lst[i], label="predicted mean")
#    for j in range(N_lines):
#        itr = int(predictions_lst[i].shape[0]/N_lines)
#        axs[i].plot(x, predictions_lst[i][j* itr,:], alpha=0.2, color="darkgreen", label="")
        
#    axs[i].set_title('PriorVAE, ls =' + str(true_ls_lst[i]))
#    axs[i].set_ylim(-2.5, 1.5)
