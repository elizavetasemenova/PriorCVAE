# %% [markdown]
# # PriorCVAE: scalable MCMC parameter inference with Bayesian deep generative modelling
#
# ## PriorCVAE wokflow
#
#
# - Draws from a prior such as a GP with conditioning on hyperparameter $c$, are encoded with a CVAE.
# - Once trained, the decoder from this trained CVAE is fixed.
# - Fully Bayesian inference with MCMC is used to combine a likelihood with a prior to infer a posterior. The prior is the drop-in prior expressed as the trained CVAE decoder, which is an approximation to the true prior from the previous step. A hyperprior is placed on $c$, with given draws from this prior passed to the CVAE decoder.

# %%
# general
import os
import sys
import time
import numpy as np 
import matplotlib.pyplot as plt 

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F 
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# Numpyro
import numpyro
import numpyro.distributions as npdist
import random as rnd
from numpyro.infer import Predictive, init_to_median, MCMC, NUTS
from numpyro.diagnostics import hpdi

numpyro.set_host_device_count(4)

#JAX
import jax
from jax import random
import jax.numpy as jnp

# check versions
print(numpyro.__version__)
print(jax.__version__)
print(torch.__version__)
from platform import python_version
print(python_version())
# Out:
# 0.10.1
# 0.3.25
# 1.12.1
# 3.8.16

# %%
# set device
torch.manual_seed(0)
if torch.cuda.is_available():
    torch.cuda.manual_seed(0)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
args = {"seed": 0,
        
        # architecture
        "conditional": True,   # CVAE if True, VAE otherwise
        "input_dim": 80,
        "hidden_dim": 60,
        "z_dim": 40,
        
        # data generation
        "new_data": False,      # set to True to generate new data. Otherwise read from file
        "save_data": False,     # set to True to save generated training and test datasets
        "samples": 100000,
        
        # VAE setup
        "vae_sd": 1, 
        "n_epochs": 400,      
        "batch_size": 1000,
        "learning_rate": 1e-3,
        "train_vae": True,      # set to True to train VAE
        "save_vae": True,
        "load_vae": False,      # set to True to load trained CVAE
        "print_loss": True,
        
        # MCMC setup
        "num_warmup": 5000,
        "num_samples": 50000,
        "num_chains": 3,
        "thinning": 1,
        "true_ls": 0.2
       }

# %% [markdown]
# ## GP priors

# %%
# functions implementiong GP priors, which are generalisable for any number of dimensions

def dist_euclid(x, z):
    x = jnp.array(x) 
    z = jnp.array(z)
    if len(x.shape)==1:
        x = x.reshape(x.shape[0], 1)
    if len(z.shape)==1:
        z = z.reshape(z.shape[0], 1)
    n_x, m = x.shape
    n_z, m_z = z.shape
    assert m == m_z
    delta = jnp.zeros((n_x,n_z))
    for d in jnp.arange(m):
        x_d = x[:,d]
        z_d = z[:,d]
        delta += (x_d[:,jnp.newaxis] - z_d)**2
    return jnp.sqrt(delta)

def exp_sq_kernel(x, z, var, length, noise=0, jitter=1.0e-5):
    dist = dist_euclid(x, z)
    deltaXsq = jnp.power(dist/ length, 2.0)
    k = var * jnp.exp(-0.5 * deltaXsq)
    k += (noise + jitter) * jnp.eye(x.shape[0])
    return k

def GP(x, jitter=1e-5, var=1.0, length=None, y=None, noise=False, gp_kernel=exp_sq_kernel):

    if length==None:  
        length = numpyro.sample("length", npdist.Uniform(0.01,0.99)) 
            
    k = gp_kernel(x, x, var, length, jitter)
    
    if noise==False:
        y = numpyro.sample("y",  npdist.MultivariateNormal(loc=jnp.zeros(x.shape[0]), covariance_matrix=k), obs=y)
    else:
        sigma = numpyro.sample("noise", npdist.HalfNormal(0.1))
        f = numpyro.sample("f", npdist.MultivariateNormal(loc=jnp.zeros(x.shape[0]), covariance_matrix=k))
        y = numpyro.sample("y", npdist.Normal(f, sigma), obs=y)
    
    ls = numpyro.deterministic("ls", jnp.array([length]))

# %% [markdown]
# ## Generate data - 1d GP

# %%
class GP1D(Dataset):
    # generate GP draws over the regular grid in the interval (x_lim_low, x_lim_high) with n_dataPoints points
    def __init__(self, 
                 n_dataPoints=400, # number of data points in the interval
                 n_samples=10000,  # number of samples
                 x_lim_low = 0,    # lower limit if the interval
                 x_lim_high = 1,   # upper limit if the interval
                 ls = None         # lengthscale to generate from. If None, draw from prior
                 ): 
        self.n_dataPoints = n_dataPoints
        self.n_samples = n_samples
        self.x_lim_low = x_lim_low
        self.x_lim_high = x_lim_high
        self.ls = ls
        self.x, self.y, self.ls = self.__simulatedata__()
    
    def __len__(self):
        return self.n_samples
    
    def __getitem__(self, idx=0):
        return(self.x[idx], self.y[idx], self.ls[idx])

    def __simulatedata__(self):
        rng_key = rnd.randint(0, 912393890428)
        rng_key, _ = random.split(random.PRNGKey(rng_key))
        x = np.linspace(self.x_lim_low, self.x_lim_high, self.n_dataPoints)   
        gp_predictive = Predictive(GP, num_samples=self.n_samples)  
        all_draws = gp_predictive(rng_key, x=x, gp_kernel = exp_sq_kernel, jitter=1e-6, length=self.ls)

        ls_draws = np.array(all_draws['ls'])
        gp_draws = np.array(all_draws['y'])
        
        return (x.repeat(self.n_samples).reshape(x.shape[0], self.n_samples).transpose(), gp_draws, ls_draws)

# %%
# what lengthscales are we generating?
dataset = GP1D(n_dataPoints=args["input_dim"])
ls_dataset = dataset.ls
plt.hist(ls_dataset) 
plt.xlim(0,1)
# Out:
# (0.0, 1.0)

# %%
# what trajectories are we getting?
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)

fig, ax = plt.subplots()
for no, dt in enumerate(dataloader):
    if dt[2] <= 0.2:
        col = 'orange'  
    elif dt[2] <= 0.6:
        col = 'green'
    else: 
        col = 'blue'
    ax.plot(dt[0].reshape(-1,1), dt[1].reshape(-1,1), color=col)
    if no > 15: break
ax.set_xlabel('$x$')
ax.set_ylabel('$y=f(x)$')
ax.set_title('realizations of a Gaussian process')

plt.show()

# %%
# create or read training and test data

cwd = os.getcwd()

train_ds_name = 'gp1d_n' + str(args["input_dim"]) + '_train.pt'
test_ds_name = 'gp1d_n' + str(args["input_dim"]) + '_test.pt'
PATH_train = cwd+ F"/data/gp1d/{train_ds_name}"
PATH_test =  cwd+ F"/data/gp1d/{test_ds_name}" 
    
if args["new_data"] == True:
    print("Generating new data")
    train_ds = GP1D(n_dataPoints=args["input_dim"], n_samples=args["samples"])
    test_ds = GP1D(n_dataPoints=args["input_dim"], n_samples=args["samples"])
    torch.save(train_ds, PATH_train)
    torch.save(test_ds, PATH_test)
    
else:
    print("Loading data")
    train_ds = torch.load(PATH_train)
    test_ds = torch.load(PATH_test)
    
test_dl = DataLoader(test_ds, batch_size=args["batch_size"], shuffle=True)
train_dl = DataLoader(train_ds, batch_size=args["batch_size"], shuffle=True)

# check distribution of lengthscales in training and test data
ls_train = train_ds.ls
plt.hist(ls_train, density=True) 
plt.xlim(0,1)
plt.show()

ls_test = test_ds.ls
plt.hist(ls_test, density=True) 
plt.xlim(0,1)
plt.show()
# Out:
# Loading data

# %% [markdown]
# ## CVAE architecture

# %%
class Encoder(nn.Module):
    ''' This the encoder part of CVAE
    '''
    def __init__(self, input_dim, hidden_dim, z_dim, conditional):
        super().__init__()
        self.conditional = conditional
        if self.conditional:
            input_dim = input_dim + 1
        
        self.linear = nn.Linear(input_dim, hidden_dim)
        self.mu = nn.Linear(hidden_dim, z_dim)
        self.sd = nn.Linear(hidden_dim, z_dim)
        
    def forward(self, x, c=None):
        if self.conditional:
            x = torch.cat((x, c), dim=-1)

        hidden = torch.relu(self.linear(x))
        z_mu = self.mu(hidden)
        z_sd = self.sd(hidden)
        return z_mu, z_sd

# %%
class Decoder(nn.Module):
    ''' This the decoder part of VAE
    '''
    def __init__(self,z_dim, hidden_dim, input_dim,  conditional):
        super().__init__()
        
        self.conditional = conditional
        if self.conditional:
            z_dim = z_dim + 1
            
        self.linear = nn.Linear(z_dim, hidden_dim)
        self.out = nn.Linear(hidden_dim, input_dim)
    
    def forward(self, z, c):
        if self.conditional:
            z = torch.cat((z, c), dim=-1)

        hidden = torch.relu(self.linear(z))
        pred = self.out(hidden)
        return pred

# %%
class VAE(nn.Module):
    ''' This the VAE, which takes a encoder and decoder.
    '''
    def __init__(self, input_dim, hidden_dim, latent_dim,
                 conditional=False):
        
        super().__init__()        
        self.encoder = Encoder(input_dim, hidden_dim, latent_dim, conditional) 
        self.decoder = Decoder(latent_dim, hidden_dim, input_dim, conditional)

    def reparameterize(self, z_mu, z_sd):
        '''During training random sample from the learned ZDIMS-dimensional
           normal distribution; during inference its mean.
        '''
        if self.training:
            std = torch.exp(z_sd / 2)
            eps = torch.randn_like(std)
            return (eps.mul(std).add_(z_mu))
        else:
            return z_mu

    def forward(self, x, c=None):
        z_mu, z_sd = self.encoder(x, c)
        x_sample = self.reparameterize(z_mu, z_sd)
        generated_x = self.decoder(x_sample, c)
        return generated_x, z_mu,z_sd

# %%
def calculate_loss(y, reconstructed_y, mean, log_sd, vae_sd=args["vae_sd"]):

    # Compute the negative log-likelihood of the Gaussian distribution
    RCL = -torch.sum(- 0.5 * ((y - reconstructed_y) / vae_sd) ** 2)

    # Compute the KL divergence
    KLD = -0.5 * torch.sum(1 + log_sd - mean.pow(2) - log_sd.exp())

    return RCL + KLD

# %% [markdown]
# ## Train PriorCVAE

# %%
# 1) Model
input_dim = args["input_dim"]
hidden_dim = args["hidden_dim"]
z_dim = args["z_dim"]
conditional = args["conditional"]

model = VAE(input_dim, hidden_dim, z_dim, conditional)

# 2) optimizer
optimizer = optim.Adam(model.parameters(), lr=args["learning_rate"])       
device = 'cuda' if torch.cuda.is_available() else 'cpu' 
model = model.to(device)

loss_history_train = []
loss_history_test = []

# %%
def calc_loss(model, data, loss_fn):
    
    model.eval()
    with torch.no_grad():
        total_loss = 0

        for i, (_, y, ls) in enumerate(data):    
            y = y.to(device)
            if args["conditional"]:
                ls = ls.to(device)
                reconstructed_y, z_mu, z_sd = model(y, ls) 
            else:
                reconstructed_y, z_mu, z_sd = model(y)
                
            loss_i = loss_fn(y, reconstructed_y, z_mu, z_sd) 
            total_loss += loss_i.item()
            
    return total_loss / len(data)

# %%
num_epochs = args['n_epochs']

best_model = model

if args["train_vae"] == True:
    
    start_time = time.time()

    for epoch in range(num_epochs):
        
        # Set the model back to training mode
        model.train(True)
        
        # batch training
        for i, (_, y, ls) in enumerate(train_dl):

            # Clear the gradients
            optimizer.zero_grad()
            
            # Forward pass
            y = y.to(device)

            if args["conditional"]:
                ls = ls.to(device)
                reconstructed_y, z_mu, z_sd = model(y, ls) 
            else:
                reconstructed_y, z_mu, z_sd = model(y)
                
            # training loss on the batch    
            loss_tr = calculate_loss(y, reconstructed_y, z_mu, z_sd) 
            
            # Backward pass
            loss_tr.backward()
    
            # Update the weights
            optimizer.step()
            
        # Calculate the training loss for the epoch
        train_loss = calc_loss(model, train_dl, calculate_loss)
        loss_history_train.append(train_loss)
        
        # Set the model to evaluation mode
        model.eval()
  
        # Calculate the test loss for the epoch
        test_loss = calc_loss(model, test_dl, calculate_loss)
        loss_history_test.append(test_loss)
        
        if epoch==0:
            best_loss = test_loss
        else:
            if test_loss < best_loss:
                best_model = model
                best_loss = test_loss
        
        # Print loss
        if args["print_loss"] == True:
            print(f"Epoch {epoch}: Train loss = {train_loss:.4f}, Test loss = {test_loss:.4f}")
        
    end_time = time.time()
    t_elapsed = end_time - start_time
    
    # Print elapsed time
    print(f"Elapsed time = {t_elapsed:.4f}")

    plt.figure()
    plt.plot(np.arange(len(loss_history_train)), loss_history_train, label="train loss")
    plt.plot(np.arange(len(loss_history_test)), loss_history_test, label="test loss")
    plt.xlabel("epochs")
    plt.ylabel("train error")
    plt.legend()
    plt.title("Train and test loss, PriorCVAE")
    plt.show()
# Out:
# Epoch 0: Train loss = 11775.6095, Test loss = 11835.6206
# Epoch 1: Train loss = 10279.7214, Test loss = 10318.1878
# Epoch 2: Train loss = 9480.2070, Test loss = 9505.9250
# Epoch 3: Train loss = 8841.8468, Test loss = 8854.7245
# Epoch 4: Train loss = 8470.2964, Test loss = 8480.3417
# Epoch 5: Train loss = 7922.8296, Test loss = 7932.3400
# Epoch 6: Train loss = 7566.3053, Test loss = 7572.4767
# Epoch 7: Train loss = 7425.6115, Test loss = 7430.8525
# Epoch 8: Train loss = 7351.3854, Test loss = 7357.4938
# Epoch 9: Train loss = 7304.3334, Test loss = 7310.9637
# Epoch 10: Train loss = 7285.3887, Test loss = 7292.6583
# Epoch 11: Train loss = 7261.3683, Test loss = 7268.8436
# Epoch 12: Train loss = 7250.3962, Test loss = 7257.4203
# Epoch 13: Train loss = 7208.6228, Test loss = 7216.9524
# Epoch 14: Train loss = 7230.7482, Test loss = 7239.5429
# Epoch 15: Train loss = 7170.4122, Test loss = 7179.4375
# Epoch 16: Train loss = 7170.9962, Test loss = 7180.1450
# Epoch 17: Train loss = 7172.5148, Test loss = 7181.5733
# Epoch 18: Train loss = 7182.8491, Test loss = 7192.6442
# Epoch 19: Train loss = 7153.8853, Test loss = 7163.7401
# Epoch 20: Train loss = 7137.4946, Test loss = 7148.1717
# Epoch 21: Train loss = 7081.6404, Test loss = 7092.3255
# Epoch 22: Train loss = 6938.8394, Test loss = 6950.1863
# Epoch 23: Train loss = 6935.2235, Test loss = 6948.6848
# Epoch 24: Train loss = 6890.6472, Test loss = 6903.7149
# Epoch 25: Train loss = 6849.0921, Test loss = 6863.6450
# Epoch 26: Train loss = 6853.0240, Test loss = 6867.3194
# Epoch 27: Train loss = 6845.3576, Test loss = 6860.5595
# Epoch 28: Train loss = 6832.8378, Test loss = 6847.6585
# Epoch 29: Train loss = 6782.8153, Test loss = 6797.7763
# Epoch 30: Train loss = 6800.0430, Test loss = 6815.0750
# Epoch 31: Train loss = 6780.8456, Test loss = 6795.8163
# Epoch 32: Train loss = 6758.6963, Test loss = 6774.0236
# Epoch 33: Train loss = 6732.0161, Test loss = 6748.3985
# Epoch 34: Train loss = 6718.9090, Test loss = 6735.2237
# Epoch 35: Train loss = 6723.7489, Test loss = 6740.1251
# Epoch 36: Train loss = 6698.4039, Test loss = 6715.0605
# Epoch 37: Train loss = 6706.6757, Test loss = 6723.4959
# Epoch 38: Train loss = 6704.9078, Test loss = 6723.2271
# Epoch 39: Train loss = 6659.6226, Test loss = 6677.0148
# Epoch 40: Train loss = 6616.4026, Test loss = 6634.2539
# Epoch 41: Train loss = 6580.4498, Test loss = 6599.0233
# Epoch 42: Train loss = 6555.2741, Test loss = 6573.5170
# Epoch 43: Train loss = 6530.5561, Test loss = 6548.2782
# Epoch 44: Train loss = 6517.0293, Test loss = 6535.1067
# Epoch 45: Train loss = 6473.7624, Test loss = 6492.2795
# Epoch 46: Train loss = 6494.5660, Test loss = 6513.2140
# Epoch 47: Train loss = 6495.6002, Test loss = 6513.8655
# Epoch 48: Train loss = 6450.9770, Test loss = 6469.2128
# Epoch 49: Train loss = 6462.0156, Test loss = 6480.5873
# Epoch 50: Train loss = 6444.0578, Test loss = 6461.3309
# Epoch 51: Train loss = 6458.6874, Test loss = 6476.6386
# Epoch 52: Train loss = 6444.9622, Test loss = 6462.8481
# Epoch 53: Train loss = 6431.5028, Test loss = 6449.5904
# Epoch 54: Train loss = 6435.6424, Test loss = 6453.2408
# Epoch 55: Train loss = 6424.7487, Test loss = 6442.7476
# Epoch 56: Train loss = 6426.8094, Test loss = 6445.0036
# Epoch 57: Train loss = 6424.8461, Test loss = 6443.6750
# Epoch 58: Train loss = 6419.1544, Test loss = 6437.2052
# Epoch 59: Train loss = 6417.5406, Test loss = 6435.1967
# Epoch 60: Train loss = 6427.8801, Test loss = 6446.6172
# Epoch 61: Train loss = 6389.6811, Test loss = 6408.1741
# Epoch 62: Train loss = 6400.2623, Test loss = 6419.0695
# Epoch 63: Train loss = 6420.3773, Test loss = 6438.4202
# Epoch 64: Train loss = 6423.2701, Test loss = 6441.8209
# Epoch 65: Train loss = 6451.1735, Test loss = 6469.2013
# Epoch 66: Train loss = 6412.8100, Test loss = 6431.0681
# Epoch 67: Train loss = 6394.3325, Test loss = 6412.4650
# Epoch 68: Train loss = 6406.4555, Test loss = 6425.2680
# Epoch 69: Train loss = 6383.4348, Test loss = 6402.5945
# Epoch 70: Train loss = 6398.6528, Test loss = 6417.3650
# Epoch 71: Train loss = 6378.5713, Test loss = 6397.6872
# Epoch 72: Train loss = 6358.7372, Test loss = 6378.1743
# Epoch 73: Train loss = 6329.2214, Test loss = 6349.6951
# Epoch 74: Train loss = 6343.7327, Test loss = 6364.7901
# Epoch 75: Train loss = 6305.9442, Test loss = 6327.6266
# Epoch 76: Train loss = 6304.5584, Test loss = 6326.2579
# Epoch 126: Train loss = 6207.1598, Test loss = 6234.4260
# Epoch 127: Train loss = 6216.2323, Test loss = 6243.2839
# Epoch 128: Train loss = 6189.9336, Test loss = 6216.1918
# Epoch 129: Train loss = 6183.9150, Test loss = 6210.7513
# Epoch 130: Train loss = 6184.7767, Test loss = 6211.6563
# Epoch 131: Train loss = 6180.5132, Test loss = 6207.2877
# Epoch 132: Train loss = 6199.5091, Test loss = 6226.8033
# Epoch 133: Train loss = 6197.0388, Test loss = 6224.1518
# Epoch 134: Train loss = 6201.9889, Test loss = 6228.3373
# Epoch 135: Train loss = 6229.0387, Test loss = 6255.5683
# Epoch 136: Train loss = 6184.5412, Test loss = 6211.1430
# Epoch 137: Train loss = 6193.7209, Test loss = 6220.6769
# Epoch 138: Train loss = 6189.9299, Test loss = 6216.4687
# Epoch 139: Train loss = 6168.2732, Test loss = 6194.9801
# Epoch 140: Train loss = 6218.6735, Test loss = 6245.6888
# Epoch 141: Train loss = 6184.1944, Test loss = 6211.0566
# Epoch 142: Train loss = 6211.4660, Test loss = 6238.6117
# Epoch 143: Train loss = 6185.7737, Test loss = 6212.6219
# Epoch 144: Train loss = 6197.9775, Test loss = 6224.6131
# Epoch 145: Train loss = 6179.8171, Test loss = 6206.8280
# Epoch 146: Train loss = 6175.5819, Test loss = 6202.5488
# Epoch 147: Train loss = 6187.2972, Test loss = 6214.3349
# Epoch 148: Train loss = 6182.9495, Test loss = 6209.1886
# Epoch 149: Train loss = 6167.6964, Test loss = 6194.1696
# Epoch 150: Train loss = 6137.7368, Test loss = 6164.1556
# Epoch 151: Train loss = 6158.8532, Test loss = 6185.2712
# Epoch 152: Train loss = 6156.5894, Test loss = 6181.9375
# Epoch 153: Train loss = 6141.7012, Test loss = 6166.9891
# Epoch 154: Train loss = 6157.2432, Test loss = 6182.9286
# Epoch 155: Train loss = 6120.0537, Test loss = 6145.7390
# Epoch 156: Train loss = 6113.8416, Test loss = 6139.8393
# Epoch 157: Train loss = 6162.9135, Test loss = 6188.3638
# Epoch 158: Train loss = 6162.0098, Test loss = 6187.0608
# Epoch 159: Train loss = 6113.8541, Test loss = 6139.0507
# Epoch 160: Train loss = 6128.7041, Test loss = 6153.9381
# Epoch 161: Train loss = 6124.6280, Test loss = 6149.6075
# Epoch 162: Train loss = 6136.9547, Test loss = 6161.1136
# Epoch 163: Train loss = 6075.3678, Test loss = 6100.3702
# Epoch 164: Train loss = 6097.0812, Test loss = 6121.3864
# Epoch 165: Train loss = 6084.4414, Test loss = 6108.8209
# Epoch 166: Train loss = 6093.3433, Test loss = 6117.6828
# Epoch 167: Train loss = 6105.5809, Test loss = 6129.7405
# Epoch 168: Train loss = 6102.0493, Test loss = 6126.2010
# Epoch 169: Train loss = 6116.6196, Test loss = 6140.5532
# Epoch 170: Train loss = 6130.7211, Test loss = 6155.6068
# Epoch 171: Train loss = 6082.3789, Test loss = 6106.5095
# Epoch 172: Train loss = 6130.3933, Test loss = 6154.3171
# Epoch 173: Train loss = 6080.8149, Test loss = 6104.5870
# Epoch 174: Train loss = 6093.9417, Test loss = 6118.4806
# Epoch 175: Train loss = 6118.3908, Test loss = 6142.1355
# Epoch 176: Train loss = 6074.2084, Test loss = 6097.8526
# Epoch 177: Train loss = 6096.0303, Test loss = 6119.9934
# Epoch 178: Train loss = 6075.3165, Test loss = 6099.5926
# Epoch 179: Train loss = 6086.2223, Test loss = 6110.1364
# Epoch 180: Train loss = 6119.4888, Test loss = 6143.5775
# Epoch 181: Train loss = 6077.2755, Test loss = 6101.0061
# Epoch 182: Train loss = 6092.1178, Test loss = 6115.0166
# Epoch 183: Train loss = 6079.0415, Test loss = 6102.1728
# Epoch 184: Train loss = 6056.2611, Test loss = 6080.1508
# Epoch 185: Train loss = 6089.8069, Test loss = 6113.8436
# Epoch 186: Train loss = 6064.6561, Test loss = 6088.6650
# Epoch 187: Train loss = 6097.8118, Test loss = 6121.3359
# Epoch 188: Train loss = 6083.2775, Test loss = 6106.8852
# Epoch 189: Train loss = 6084.8881, Test loss = 6108.3215
# Epoch 190: Train loss = 6068.9558, Test loss = 6092.1423
# Epoch 191: Train loss = 6085.6515, Test loss = 6108.7701
# Epoch 192: Train loss = 6060.0868, Test loss = 6083.8651
# Epoch 193: Train loss = 6072.2693, Test loss = 6095.4407
# Epoch 194: Train loss = 6084.5367, Test loss = 6107.8016
# Epoch 195: Train loss = 6064.9024, Test loss = 6088.6121
# Epoch 196: Train loss = 6100.8494, Test loss = 6124.7862
# Epoch 197: Train loss = 6095.6887, Test loss = 6119.6885
# Epoch 198: Train loss = 6071.7819, Test loss = 6095.2086
# Epoch 199: Train loss = 6073.3604, Test loss = 6096.6033
# Epoch 200: Train loss = 6047.6091, Test loss = 6069.8444
# Epoch 201: Train loss = 6071.9840, Test loss = 6094.7188
# Epoch 202: Train loss = 6041.2595, Test loss = 6063.8272
# Epoch 203: Train loss = 6025.1624, Test loss = 6047.8213
# Epoch 204: Train loss = 6040.9111, Test loss = 6063.2302
# Epoch 205: Train loss = 6048.9503, Test loss = 6071.8329
# Epoch 206: Train loss = 6041.1810, Test loss = 6063.9623
# Epoch 207: Train loss = 6032.5514, Test loss = 6054.9584
# Epoch 208: Train loss = 6025.5972, Test loss = 6048.3372
# Epoch 209: Train loss = 6038.5529, Test loss = 6060.4489
# Epoch 210: Train loss = 6042.4478, Test loss = 6064.9133
# Epoch 211: Train loss = 6004.4178, Test loss = 6025.8461
# Epoch 212: Train loss = 5976.7698, Test loss = 5999.0823
# Epoch 213: Train loss = 6006.8918, Test loss = 6027.9712
# Epoch 214: Train loss = 6015.5965, Test loss = 6038.2663
# Epoch 215: Train loss = 6018.3356, Test loss = 6039.4056
# Epoch 216: Train loss = 6014.0696, Test loss = 6036.5316
# Epoch 217: Train loss = 6035.9411, Test loss = 6057.3422
# Epoch 218: Train loss = 6030.5056, Test loss = 6053.3409
# Epoch 219: Train loss = 5987.3448, Test loss = 6008.9498
# Epoch 220: Train loss = 6027.1723, Test loss = 6048.7863
# Epoch 221: Train loss = 6003.7359, Test loss = 6026.0612
# Epoch 222: Train loss = 5983.7707, Test loss = 6005.6106
# Epoch 223: Train loss = 6016.1398, Test loss = 6038.1166
# Epoch 224: Train loss = 6040.1536, Test loss = 6061.5373
# Epoch 225: Train loss = 6000.4912, Test loss = 6022.6577
# Epoch 226: Train loss = 5996.6361, Test loss = 6017.5502
# Epoch 227: Train loss = 5989.8488, Test loss = 6011.6505
# Epoch 228: Train loss = 5982.9945, Test loss = 6004.5014
# Epoch 229: Train loss = 6027.5245, Test loss = 6049.6061
# Epoch 230: Train loss = 5989.3267, Test loss = 6011.4305
# Epoch 231: Train loss = 5978.7905, Test loss = 6000.3094
# Epoch 232: Train loss = 6020.3943, Test loss = 6042.2441
# Epoch 233: Train loss = 6001.7972, Test loss = 6023.8273
# Epoch 234: Train loss = 5969.0069, Test loss = 5990.4876
# Epoch 235: Train loss = 5983.6010, Test loss = 6005.6947
# Epoch 236: Train loss = 5999.3853, Test loss = 6021.3003
# Epoch 237: Train loss = 6017.1522, Test loss = 6038.6212
# Epoch 238: Train loss = 5979.0438, Test loss = 6000.0739
# Epoch 239: Train loss = 6014.8772, Test loss = 6036.0902
# Epoch 240: Train loss = 6009.7513, Test loss = 6031.4900
# Epoch 241: Train loss = 6013.7622, Test loss = 6035.3084
# Epoch 242: Train loss = 6025.9564, Test loss = 6048.1968
# Epoch 243: Train loss = 5995.3116, Test loss = 6017.0862
# Epoch 244: Train loss = 5986.5233, Test loss = 6008.3325
# Epoch 245: Train loss = 6011.4768, Test loss = 6033.0778
# Epoch 246: Train loss = 6001.9058, Test loss = 6023.7325
# Epoch 247: Train loss = 5980.7862, Test loss = 6001.9873
# Epoch 248: Train loss = 5985.1574, Test loss = 6007.0564
# Epoch 249: Train loss = 6004.5388, Test loss = 6026.6576
# Epoch 250: Train loss = 5993.2545, Test loss = 6015.1202
# Epoch 251: Train loss = 5983.9601, Test loss = 6004.7436
# Epoch 252: Train loss = 6001.2551, Test loss = 6022.1810
# Epoch 253: Train loss = 6005.8890, Test loss = 6027.9792
# Epoch 254: Train loss = 6002.6213, Test loss = 6025.1144
# Epoch 255: Train loss = 6024.3858, Test loss = 6045.6974
# Epoch 256: Train loss = 6000.1686, Test loss = 6022.2044
# Epoch 257: Train loss = 5995.5468, Test loss = 6017.7361
# Epoch 258: Train loss = 6003.6624, Test loss = 6025.6227
# Epoch 259: Train loss = 5973.4615, Test loss = 5996.3565
# Epoch 260: Train loss = 6006.4228, Test loss = 6028.0025
# Epoch 261: Train loss = 5999.2517, Test loss = 6020.4755
# Epoch 262: Train loss = 5993.4963, Test loss = 6014.9635
# Epoch 263: Train loss = 5996.1818, Test loss = 6017.4947
# Epoch 264: Train loss = 6022.4125, Test loss = 6043.8694
# Epoch 265: Train loss = 5990.2628, Test loss = 6011.8825
# Epoch 266: Train loss = 5997.9803, Test loss = 6019.6487
# Epoch 267: Train loss = 5982.1131, Test loss = 6003.8005
# Epoch 268: Train loss = 5991.5130, Test loss = 6012.6547
# Epoch 269: Train loss = 5959.3306, Test loss = 5980.6421
# Epoch 270: Train loss = 6009.3431, Test loss = 6030.8487
# Epoch 368: Train loss = 5970.9370, Test loss = 5991.4846
# Epoch 369: Train loss = 5955.4775, Test loss = 5976.3106
# Epoch 370: Train loss = 5967.8415, Test loss = 5988.4723
# Epoch 371: Train loss = 5999.9854, Test loss = 6020.4396
# Epoch 372: Train loss = 5965.1595, Test loss = 5985.7734
# Epoch 373: Train loss = 5986.1454, Test loss = 6006.6894
# Epoch 374: Train loss = 5972.2168, Test loss = 5992.9638
# Epoch 375: Train loss = 5969.5822, Test loss = 5991.1394
# Epoch 376: Train loss = 5962.3502, Test loss = 5982.0997
# Epoch 377: Train loss = 5983.3672, Test loss = 6004.1589
# Epoch 378: Train loss = 5990.0097, Test loss = 6010.5647
# Epoch 379: Train loss = 5995.8092, Test loss = 6016.0744
# Epoch 380: Train loss = 5982.1823, Test loss = 6003.1816
# Epoch 381: Train loss = 6005.1620, Test loss = 6025.6702
# Epoch 382: Train loss = 5998.8824, Test loss = 6020.3212
# Epoch 383: Train loss = 5971.2458, Test loss = 5992.0013
# Epoch 384: Train loss = 5976.8303, Test loss = 5997.9520
# Epoch 385: Train loss = 5984.0518, Test loss = 6004.6915
# Epoch 386: Train loss = 5971.0910, Test loss = 5992.4969
# Epoch 387: Train loss = 5990.4988, Test loss = 6010.6768
# Epoch 388: Train loss = 5991.8751, Test loss = 6012.3698
# Epoch 389: Train loss = 6005.0853, Test loss = 6025.6521
# Epoch 390: Train loss = 5982.5983, Test loss = 6003.6733
# Epoch 391: Train loss = 5970.5206, Test loss = 5990.8670
# Epoch 392: Train loss = 5963.1287, Test loss = 5985.0060
# Epoch 393: Train loss = 5986.0376, Test loss = 6006.5339
# Epoch 394: Train loss = 5969.2721, Test loss = 5989.9160
# Epoch 395: Train loss = 5973.5630, Test loss = 5995.1795
# Epoch 396: Train loss = 5969.2416, Test loss = 5990.0486
# Epoch 397: Train loss = 5980.6076, Test loss = 6001.4743
# Epoch 398: Train loss = 5975.8414, Test loss = 5996.2357
# Epoch 399: Train loss = 5997.3115, Test loss = 6017.9563
# Elapsed time = 1352.0440

# %%
# Print elapsed time
print(f"Elapsed time = {t_elapsed:.4f} s")
print(f"Elapsed time = {t_elapsed/60:.4f} min")
print(f"Elapsed time = {t_elapsed/(60*60):.4f} h")
# Out:
# Elapsed time = 1352.0440 s
# Elapsed time = 22.5341 min
# Elapsed time = 0.3756 h

# %%
args["save_vae"]
# Out:
# True

# %%
# plot the latest epochs 

start_ind = 200

plt.figure()
plt.plot(np.arange(len(loss_history_train[start_ind:])), loss_history_train[start_ind:], label="train loss")
plt.plot(np.arange(len(loss_history_test[start_ind:])), loss_history_test[start_ind:], label="test loss")
plt.xlabel("epochs")
plt.ylabel("train error")
plt.legend()
plt.title("Train and test losses, PriorCVAE")
plt.show()

# %%
model.state_dict()['encoder.linear.weight'] == best_model.state_dict()['encoder.linear.weight']
# Out:
# tensor([[True, True, True,  ..., True, True, True],
#         [True, True, True,  ..., True, True, True],
#         [True, True, True,  ..., True, True, True],
#         ...,
#         [True, True, True,  ..., True, True, True],
#         [True, True, True,  ..., True, True, True],
#         [True, True, True,  ..., True, True, True]])

# %%
model = best_model
del best_model

# %%
###### Sampling draws from learnt model
#model.eval() # model in eval mode

#n_samps = 20
#z = torch.randn(n_samps, z_dim).to(device) # random draw
#c = torch.rand(n_samps)

#with torch.no_grad():
#    c = c[:, None]
#    sampled_y = model.decoder(z, c)

#fig = plt.figure()
#ax = fig.add_subplot(111)
#for no, y in enumerate(sampled_y):
#    if c[no] == 0:
#        col = 'blue'  
#    else:
#        col = 'orange'
#    ax.plot(train_ds.x[0], y.cpu().numpy(), color=col)

#ax.set_xlabel('$x$')
#ax.set_ylabel('$y=CVAE_f(x)$')
#ax.set_title('realizations of PriorCVAE')

# %%
import pickle

model_save_name = 'PriorCVAE_gp1d_n'+str(args["input_dim"])+'_h'+str(args["hidden_dim"])+'_z'+str(args["z_dim"])+'_epochs'+str(args["n_epochs"])+'_b'+str(args["batch_size"]) + '_continuous.pt'
loss_train_name = 'PriorCVAE_gp1d_n'+str(args["input_dim"])+'_h'+str(args["hidden_dim"])+'_z'+str(args["z_dim"])+'_epochs'+str(args["n_epochs"])+'_b'+str(args["batch_size"]) +'_loss_train_continuous'
loss_test_name =  'PriorCVAE_gp1d_n'+str(args["input_dim"])+'_h'+str(args["hidden_dim"])+'_z'+str(args["z_dim"])+'_epochs'+str(args["n_epochs"])+'_b'+str(args["batch_size"]) +'_loss_test_continuous'
print(model_save_name) 
print(loss_train_name) 
print(loss_test_name) 

PATH = cwd + F"/trained_models/{model_save_name}" 
loss_train_name = cwd +"/trained_models/" + loss_train_name
loss_test_name = cwd + "/trained_models/" + loss_test_name

if args["save_vae"] == True:    
    print("VAE model saved")
    torch.save(model.state_dict(), PATH)
    
    with open(loss_train_name, "wb") as fp:  
        pickle.dump(loss_history_train, fp)
    with open(loss_test_name, "wb") as fp:  
        pickle.dump(loss_history_test, fp)
        
elif args["load_vae"] == True:
    model.load_state_dict(torch.load(PATH))
    
    with open(loss_train_name, "rb") as fp:   
        loss_history_train = pickle.load(fp)
    with open(loss_test_name, "rb") as fp:   
        loss_history_test = pickle.load(fp)

    print("CVAE model loaded")
else:
    print("no model loaded")
# Out:
# PriorCVAE_gp1d_n80_h60_z40_epochs400_b1000_continuous.pt
# PriorCVAE_gp1d_n80_h60_z40_epochs400_b1000_loss_train
# PriorCVAE_gp1d_n80_h60_z40_epochs400_b1000_loss_test
# VAE model saved

# %% [markdown]
# ## Visual diagnostics of how well we have learnt

# %%
def MMD(x, y, kernel="multiscale"):
    """Emprical maximum mean discrepancy. The lower the result, the more evidence that distributions are the same.

    Args:
        x: first sample, distribution P
        y: second sample, distribution Q
        kernel: kernel type such as "multiscale" or "rbf"
    """
    xx, yy, zz = torch.mm(x, x.t()), torch.mm(y, y.t()), torch.mm(x, y.t())
    rx = (xx.diag().unsqueeze(0).expand_as(xx))
    ry = (yy.diag().unsqueeze(0).expand_as(yy))
    
    dxx = rx.t() + rx - 2. * xx # Used for A in (1)
    dyy = ry.t() + ry - 2. * yy # Used for B in (1)
    dxy = rx.t() + ry - 2. * zz # Used for C in (1)
    
    XX, YY, XY = (torch.zeros(xx.shape).to(device),
                  torch.zeros(xx.shape).to(device),
                  torch.zeros(xx.shape).to(device))
    
    if kernel == "multiscale":
        
        bandwidth_range = [0.2, 0.5, 0.9, 1.3]
        for a in bandwidth_range:
            XX += a**2 * (a**2 + dxx)**-1
            YY += a**2 * (a**2 + dyy)**-1
            XY += a**2 * (a**2 + dxy)**-1
            
    if kernel == "rbf":
      
        bandwidth_range = [10, 15, 20, 50]
        for a in bandwidth_range:
            XX += torch.exp(-0.5*dxx/a)
            YY += torch.exp(-0.5*dyy/a)
            XY += torch.exp(-0.5*dxy/a)
      
    return torch.mean(XX + YY - 2. * XY)

# %%
def demo_plots(conditional =False, 
               ttl1="GP priors to encode",
               ttl2="Priors learnt by VAE", 
               ylbl1='$y=f_{GP}(x)$', 
               ylbl2='$y=f_{VAE}(x)$', 
               ls=None):

    n_samps = 100000
    if conditional == True:
        dataset = GP1D(n_dataPoints=args["input_dim"], n_samples=n_samps, ls=ls)
        ttl2="Priors learnt by CVAE"
        ylbl2='$y=f_{CVAE}(x)$'
    else:
        dataset = GP1D(n_dataPoints=args["input_dim"], n_samples=n_samps, ls=ls)    

    gp_draws = dataset.y
    x = dataset.x[0,:]
    gp_draws = gp_draws.transpose()

    model.eval() # model in eval mode
    z = torch.randn(n_samps, z_dim).to(device) # random draw

    if conditional == True:
        c = torch.ones(n_samps) * ls
        c = c[:, None]
        with torch.no_grad():
            vae_draws = model.decoder(z, c).numpy().transpose()
    else:
        with torch.no_grad():
            vae_draws = model.decoder(z, c=None).numpy().transpose()

    mean_gp = np.nanmean(gp_draws, axis=1)
    q025_gp = np.quantile(gp_draws, 0.025, axis=1)
    q975_gp = np.quantile(gp_draws, 0.975, axis=1)
    #print(mean_gp.shape)

    mean_vae = np.nanmean(vae_draws, axis=1)
    q025_vae = np.quantile(vae_draws, 0.025, axis=1)
    q975_vae = np.quantile(vae_draws, 0.975, axis=1)

    #print("q025: ")
    #print(q025_gp)
    #print(q025_vae)
    #print("q975: ")
    #print(q975_gp)
    #print(q975_vae)

    # plot results
    fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12,3))

    _min, _max = -3, 3
    lines_alpha_gp = 0.5
    lines_alpha_vae = 0.5
    N_lines = 20

    if ls==None:
        ttl = ttl1
    else:
        ttl = ttl1+ ", ls=" + str(ls)
    ylbl = ylbl1

    for j in range(N_lines):
        itr = int(gp_draws.shape[1]/N_lines)
        axs[0].plot(x, gp_draws[:,j*itr], alpha=lines_alpha_gp, label="")

    axs[0].plot(x, gp_draws[:,0], alpha=lines_alpha_gp, color="darkgreen", label="GP draws")  
    axs[0].fill_between(x, q025_gp[0], q975_gp[1], alpha=0.1, interpolate=True, label="95% BCI")
    axs[0].plot(x, mean_gp, label="mean")
    axs[0].legend(loc=4)
    axs[0].set_ylim([_min, _max])
    axs[0].set_xlabel('$x$')
    axs[0].set_ylabel(ylbl)
    axs[0].set_title(ttl)

    if ls==None:
        tt2 = ttl2
    else:
        tt2 = ttl2+ ", ls=" + str(ls)
    ylbl=ylbl2

    for j in range(N_lines):
        itr = int(vae_draws.shape[1]/N_lines)
        axs[1].plot(x, vae_draws[:,j*itr], alpha=lines_alpha_vae, label="")

    axs[1].plot(x, vae_draws[:,0], alpha=lines_alpha_vae, color="darkgreen", label="VAE draws")  
    axs[1].fill_between(x, q025_vae[0], q975_vae[1], alpha=0.1, interpolate=True, label="95% BCI")
    axs[1].plot(x, mean_vae, label="mean")
    axs[1].legend(loc=4)
    axs[1].set_ylim([_min, _max])
    axs[1].set_xlabel('$x$')
    axs[1].set_ylabel(ylbl)
    axs[1].set_title(tt2)

    axs[2].fill_between(x, q025_gp[0], q975_gp[1], alpha=0.1, interpolate=True, label="95% BCI")
    axs[2].plot(x, mean_gp, label="mean")
    axs[2].fill_between(x, q025_vae[0], q975_vae[1], alpha=0.1, interpolate=True, label="95% BCI")
    axs[2].plot(x, mean_vae, label="mean")
    axs[2].legend(loc=4)
    axs[2].set_ylim([_min, _max])

    plt.show()

    m_vae = np.cov((vae_draws))
    m_gp = np.cov((gp_draws))
    print('Frobenius norm = ' + str(np.linalg.norm(m_gp - m_vae,  'fro')))
    
    gg = torch.from_numpy(gp_draws)
    vv = torch.from_numpy(vae_draws)
    print('MMD, multiscale = ' + str(MMD(gg, vv)))
    print('MMD, rbf = ' + str(MMD(gg, vv, "rbf")))
    
    cmap_choice = 'inferno'
    
    gp_cm_ttl = 'GP covariance matrix'
    if ls is not None:
        gp_cm_ttl = gp_cm_ttl + ', c='+ str(ls)
    vae_cm_ttl = 'VAE covariance matrix'
    if ls is not None:
        vae_cm_ttl = vae_cm_ttl +', c='+ str(ls)


    #'plasma'
    #'inferno'
    fig, axs = plt.subplots(nrows=1, ncols=2, figsize = (8,4))
    axs[0].imshow(m_gp, cmap=cmap_choice)
    axs[0].axis('off')

    axs[0].set_title(gp_cm_ttl)
    #axs[0].set_title('GP covariance matrix, c=' + str(ls))

    axs[1].imshow(m_vae, cmap=cmap_choice)
    axs[1].axis('off')
    axs[1].set_title(vae_cm_ttl)

    plt.show()
    
    #return (gp_draws, vae_draws)

# %%
# 2).
demo_plots(conditional=True, ls=0.4)
# Out:
# Frobenius norm = 6.817112722048632
# MMD, multiscale = tensor(0.1027)
# MMD, rbf = tensor(0.1351)

# %%
# 3).
demo_plots(conditional=True, ls=0.1)
# Out:
# Frobenius norm = 7.609191136925814
# MMD, multiscale = tensor(0.1002)
# MMD, rbf = tensor(0.1001)

# %%
# 4).
demo_plots(conditional=True, ls=0.9)
# Out:
# Frobenius norm = 1.8431837732700875
# MMD, multiscale = tensor(0.1106)
# MMD, rbf = tensor(0.2591)

# %% [markdown]
# # Inference

# %% [markdown]
# ## Generate data

# %%
x = np.linspace(0, 1, args["input_dim"])   

rng_key_draw =  random.PRNGKey(1)
rng_key, rng_key_post, rng_key_preds, rng_key_draw = random.split(rng_key_draw, 4)

gp_predictive = Predictive(GP, num_samples=1)
draws = gp_predictive(rng_key_draw, x=x, jitter=1e-6, 
                      noise=True, length=args["true_ls"], var=1)

gp_draw = draws['f'].T
y_draw = draws['y'].T

obs_idx_lst = []
obs_idx_lst.append([10, 30, 54, 64]) # points correspond to n=80, ls=0.2, rng1
i = 0

# choose indices of data points for inference
obs_idx = jnp.array(obs_idx_lst[i])

y_obs = y_draw[obs_idx,0]
x_obs = x[np.array(obs_idx)]

args['y_obs'] = y_obs
args['obs_idx'] = obs_idx
args['x_obs'] = x_obs

plt.plot(x, gp_draw, label="ground truth", color="orange")
plt.scatter(x_obs, y_obs, color="red", label="observed data", s=60)
plt.title('Ground truth, corresponds to ls=' + str(args["true_ls"]))
# Out:
# Text(0.5, 1.0, 'Ground truth, corresponds to ls=0.2')

# %% [markdown]
# ## Numpyro model - PriorCVAE

# %%
# decoder parameters

model = model.to('cpu')
decoder_dict = model.decoder.state_dict()
decoder_dict.keys()

W1 = decoder_dict['linear.weight'].T.numpy()
B1 = decoder_dict['linear.bias'].numpy()
W2 = decoder_dict['out.weight'].T.numpy()
B2 = decoder_dict['out.bias'].T.numpy()

print(W1.shape)
print(B1.shape)
print(W2.shape)
print(B2.shape)
# Out:
# (41, 60)
# (60,)
# (60, 80)
# (80,)
# /var/folders/q3/n2z18__9281b8xfhctcpxfsr0000gn/T/ipykernel_60792/2358429211.py:10: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matricesor `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at  /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1659484782168/work/aten/src/ATen/native/TensorShape.cpp:2985.)
#   B2 = decoder_dict['out.bias'].T.numpy()

# %%
def c_decoder_numpy(z, W1, B1, W2, B2, c=None):
   
    def linear(z, W, B):
        lin_out = jnp.matmul(z, W) + B
        return lin_out

    if c is not None:
        c = jnp.array(c).reshape(1)
        z = jnp.concatenate([z, c], axis=0)

    hidden = jax.nn.relu(linear(z, W1, B1))
    out = linear(hidden, W2, B2)
    return out

        
def numpyro_model(z_dim, conditional=False,  y=None, obs_idx=None, c=None,):
    
    if c is None and conditional==True:
        c = numpyro.sample("c", npdist.Uniform(0.01,0.99))

    z = numpyro.sample("z", npdist.Normal(jnp.zeros(z_dim), jnp.ones(z_dim))) 
    
    f = numpyro.deterministic("f", c_decoder_numpy(z, W1, B1, W2, B2, c))
    sigma = numpyro.sample("sigma", npdist.HalfNormal(0.1))

    if y is None: # durinig prediction
        y_pred = numpyro.sample("y_pred", npdist.Normal(f, sigma))
    else: # during inference
        y = numpyro.sample("y", npdist.Normal(f[obs_idx], sigma), obs=y)

# %%
def run_mcmc_vae(rng_key, numpyro_model, args, verbose=True, c=None, conditional=False):
    start = time.time()

    init_strategy = init_to_median(num_samples=10)
    kernel = NUTS(numpyro_model, init_strategy=init_strategy)
    mcmc = MCMC(
        kernel,
        num_warmup=args["num_warmup"],
        num_samples=args["num_samples"],
        num_chains=args["num_chains"],
        thinning=args["thinning"],
        progress_bar=False if "NUMPYRO_SPHINXBUILD" in os.environ else True,
    )
    start = time.time()
    mcmc.run(rng_key, args["z_dim"], conditional, args["y_obs"], args["obs_idx"], c )
    t_elapsed = time.time() - start
    if verbose:
        mcmc.print_summary(exclude_deterministic=False)
    
    print("\nMCMC elapsed time:", round(t_elapsed), "s")
    ss = numpyro.diagnostics.summary(mcmc.get_samples(group_by_chain=True))
    r = np.mean(ss['f']['n_eff'])
    print("Average ESS for all VAE-GP effects : " + str(round(r)))

    return (mcmc, mcmc.get_samples(), t_elapsed)

# %% [markdown]
# ## Inference on observed data - PriorCVAE

# %%
args.keys()
# Out:
# dict_keys(['seed', 'conditional', 'input_dim', 'hidden_dim', 'z_dim', 'new_data', 'save_data', 'samples', 'vae_sd', 'n_epochs', 'batch_size', 'learning_rate', 'train_vae', 'save_vae', 'load_vae', 'print_loss', 'num_warmup', 'num_samples', 'num_chains', 'thinning', 'true_ls', 'y_obs', 'obs_idx', 'x_obs'])

# %%
rng_key, rng_key_prior, rng_key_post, rng_key_pred = random.split(rng_key, 4)

mcmc_vae, mcmc_vae_samples, t_elapsed = run_mcmc_vae(rng_key_post, numpyro_model, args, conditional=True)
# Out:
#   0%|          | 0/55000 [00:00<?, ?it/s]
#   0%|          | 0/55000 [00:00<?, ?it/s]
#   0%|          | 0/55000 [00:00<?, ?it/s]
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#          c      0.19      0.15      0.17      0.01      0.28  10825.92      1.00
#       f[0]      0.17      0.49      0.25     -0.73      0.85   1584.85      1.00
#       f[1]      0.16      0.51      0.24     -0.74      0.89   1626.65      1.00
#       f[2]      0.15      0.51      0.23     -0.75      0.88   1665.94      1.00
#       f[3]      0.14      0.49      0.21     -0.71      0.86   1701.01      1.00
#       f[4]      0.11      0.45      0.18     -0.66      0.79   1734.11      1.00
#       f[5]      0.09      0.40      0.15     -0.59      0.70   1782.30      1.00
#       f[6]      0.07      0.34      0.11     -0.52      0.58   1866.78      1.00
#       f[7]      0.04      0.27      0.08     -0.44      0.46   2065.53      1.00
#       f[8]      0.01      0.21      0.04     -0.38      0.31   2684.92      1.00
#       f[9]     -0.02      0.15      0.00     -0.27      0.22   6667.65      1.00
#      f[10]     -0.05      0.13     -0.03     -0.25      0.15  38988.12      1.00
#      f[11]     -0.09      0.14     -0.08     -0.31      0.16   4602.95      1.00
#      f[12]     -0.13      0.19     -0.14     -0.42      0.19   2143.51      1.00
#      f[13]     -0.17      0.24     -0.19     -0.53      0.25   1752.96      1.00
#      f[14]     -0.20      0.29     -0.24     -0.62      0.34   1662.56      1.00
#      z[13]      0.01      0.99     -0.02     -1.58      1.66   4527.68      1.00
#      z[14]     -0.01      0.99     -0.01     -1.62      1.61   3892.58      1.00
#      z[15]      0.02      0.99      0.01     -1.56      1.69   4127.74      1.00
#      z[16]     -0.01      1.00     -0.00     -1.66      1.59   1619.16      1.00
#      z[17]      0.01      0.98     -0.00     -1.59      1.61   3693.95      1.00
#      z[18]     -0.01      1.00     -0.01     -1.62      1.64   2711.89      1.00
#      z[19]      0.01      0.99      0.01     -1.64      1.57   3167.55      1.00
#      z[20]     -0.00      0.98      0.01     -1.67      1.58  12553.01      1.00
#      z[21]     -0.00      1.00      0.02     -1.75      1.57   1972.59      1.00
#      z[22]     -0.00      0.99     -0.00     -1.67      1.59   5150.99      1.00
#      z[23]     -0.05      1.00     -0.06     -1.70      1.59   2604.05      1.00
#      z[24]     -0.02      0.99     -0.00     -1.73      1.56   4699.98      1.00
#      z[25]     -0.04      1.01     -0.04     -1.65      1.63   2128.72      1.00
#      z[26]     -0.00      0.99      0.00     -1.62      1.60   4183.06      1.00
#      z[27]      0.03      0.99      0.03     -1.61      1.65   5555.09      1.00
#      z[28]     -0.05      1.05     -0.04     -1.74      1.67    580.27      1.00
#      z[29]     -0.00      1.00     -0.02     -1.54      1.73   1832.67      1.00
#      z[30]      0.18      0.49      0.15     -0.61      0.98   3117.74      1.00
#      z[31]     -0.25      0.94     -0.25     -1.80      1.27   5854.75      1.00
#      z[32]     -0.04      1.00     -0.06     -1.73      1.43    699.68      1.00
#      z[33]      0.02      0.98     -0.00     -1.55      1.66   9178.19      1.00
#      z[34]     -0.03      0.99     -0.03     -1.61      1.63   4496.60      1.00
#      z[35]      0.88      0.74      0.96     -0.34      2.03   2879.74      1.00
#      z[36]      0.02      1.02     -0.01     -1.49      1.91   1128.91      1.01
#      z[37]      0.03      1.01      0.04     -1.64      1.62   1700.19      1.00
#      z[38]     -0.01      0.97      0.01     -1.61      1.61  17982.39      1.00
#      z[39]     -0.04      1.00     -0.05     -1.66      1.60   3138.53      1.00
#
# Number of divergences: 16660
#
# MCMC elapsed time: 18 s
# Average ESS for all VAE-GP effects : 7129

# %%
predictive = Predictive(numpyro_model, mcmc_vae_samples)
predictions_vae = predictive(rng_key_pred,  args["z_dim"], True, args["y_obs"], args["obs_idx"] )["f"]

mean_post_pred_vae = jnp.mean(predictions_vae, axis=0)
hpdi_post_pred_vae = hpdi(predictions_vae, 0.9)
percentiles_vae = np.percentile(predictions_vae, [5.0, 95.0], axis=0)

N_lines = 10
plt.plot(x, gp_draw, label="ground truth", color="orange")
plt.scatter(x_obs, y_obs, color="red", label="observed data", s=60)
plt.plot(x, mean_post_pred_vae, label="predicted mean VAE")

plt.fill_between(x, percentiles_vae[0, :], percentiles_vae[1, :], alpha=0.3, interpolate=True, label="VAE posterior: 90% BCI")
#for j in range(N_lines):
#    itr = int(predictions_vae.shape[0]/N_lines)
#    plt.plot(x, predictions_vae[j* itr,:], alpha=0.2, color="darkgreen", label="")


plt.title('PriorCVAE inference')
plt.ylim([-2, 1])
# Out:
# (-2.0, 1.0)

# %%
c_samps = mcmc_vae_samples['c']
plt.hist(c_samps, density=True, label = 'posterior samples', bins=20)
plt.axvline(x = args["true_ls"], color = 'red', label = 'true lengthscale')
plt.xlim(0,1)
plt.title('ls - posterior samples')
plt.legend()

# %%
import arviz as az
az_data = az.from_numpyro(mcmc_vae)
az.plot_trace(az_data, var_names=('c'), filter_vars="like")
# Out:
# array([[<AxesSubplot: title={'center': 'c'}>,
#         <AxesSubplot: title={'center': 'c'}>]], dtype=object)
