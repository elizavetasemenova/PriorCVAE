# %% [markdown]
# # PriorCVAE: scalable MCMC parameter inference with Bayesian deep generative modelling
#
# ## PriorCVAE wokflow
#
#
# - Draws from a prior such as a GP with conditioning on hyperparameter $c$, are encoded with a CVAE.
# - Once trained, the decoder from this trained CVAE is fixed.
# - Fully Bayesian inference with MCMC is used to combine a likelihood with a prior to infer a posterior. The prior is the drop-in prior expressed as the trained CVAE decoder, which is an approximation to the true prior from the previous step. A hyperprior is placed on $c$, with given draws from this prior passed to the CVAE decoder.

# %%
# general
import os
import sys
import time
import numpy as np 
import matplotlib.pyplot as plt 

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F 
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
#from tqdm import tqdm, trange

# Numpyro
import numpyro
import numpyro.distributions as npdist
import random as rnd
from numpyro.infer import Predictive, init_to_median, MCMC, NUTS
from numpyro.diagnostics import hpdi

numpyro.set_host_device_count(4)

#JAX
import jax
from jax import random
import jax.numpy as jnp

# check versions
print(numpyro.__version__)
print(jax.__version__)
print(torch.__version__)
from platform import python_version
print(python_version())
# Out:
# 0.10.1
# 0.3.25
# 1.12.1
# 3.8.16

# %%
# set device
torch.manual_seed(0)
if torch.cuda.is_available():
    torch.cuda.manual_seed(0)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
args = {"seed": 0,
        
        # architecture
        "conditional": True,
        "input_dim": 80,
        "hidden_dim": 60,
        "z_dim": 40,
        
        # data generation
        "new_data": True,  # set to True to generate new data. Otherwise read from file
        "save_data": False, # set to True to save generated training and test datasets
        "batch_size": 500,
        "samples": 100000,
        
        # VAE setup
        "vae_sd": 1, 
        "n_epochs": 800,        # for better results, set to 15000
        "learning_rate": 1e-3,
        "train_vae": True,      # set to True to train VAE
        "save_vae": False,
        "load_vae": False,      # set to True to load trained CVAE
        
        # MCMC setup
        "num_warmup": 1000,
        "num_samples": 4000,
        "num_chains": 4,
        "thinning": 1,
        "true_ls": 0.2
       }

# %% [markdown]
# ## GP priors

# %%
def dist_euclid(x, z):
    x = jnp.array(x) 
    z = jnp.array(z)
    if len(x.shape)==1:
        x = x.reshape(x.shape[0], 1)
    if len(z.shape)==1:
        z = z.reshape(z.shape[0], 1)
    n_x, m = x.shape
    n_z, m_z = z.shape
    assert m == m_z
    delta = jnp.zeros((n_x,n_z))
    for d in jnp.arange(m):
        x_d = x[:,d]
        z_d = z[:,d]
        delta += (x_d[:,jnp.newaxis] - z_d)**2
    return jnp.sqrt(delta)

def exp_sq_kernel(x, z, var, length, noise=0, jitter=1.0e-5):
    dist = dist_euclid(x, z)
    deltaXsq = jnp.power(dist/ length, 2.0)
    k = var * jnp.exp(-0.5 * deltaXsq)
    k += (noise + jitter) * jnp.eye(x.shape[0])
    return k

def GP(x, jitter=1e-5, var=1.0, length=None, y=None, noise=False, gp_kernel=exp_sq_kernel):

    if length==None:  
        length = numpyro.sample("length", npdist.Uniform(0.01,0.99)) 
            
    k = gp_kernel(x, x, var, length, jitter)
    
    if noise==False:
        y = numpyro.sample("y",  npdist.MultivariateNormal(loc=jnp.zeros(x.shape[0]), covariance_matrix=k), obs=y)
    else:
        sigma = numpyro.sample("noise", npdist.HalfNormal(0.1))
        f = numpyro.sample("f", npdist.MultivariateNormal(loc=jnp.zeros(x.shape[0]), covariance_matrix=k))
        y = numpyro.sample("y", npdist.Normal(f, sigma), obs=y)
    
    ls = numpyro.deterministic("ls", jnp.array([length]))

# %% [markdown]
# ## Generate data - 1d GP

# %%
class GP1D(Dataset):
    def __init__(self, n_dataPoints=400, 
                       n_samples=10000, 
                       x_lim_low = 0, 
                       x_lim_high = 1,
                       ls = None
                 ): 
        self.n_dataPoints = n_dataPoints
        self.n_samples = n_samples
        self.x_lim_low = x_lim_low
        self.x_lim_high = x_lim_high
        self.ls = ls
        self.x, self.y, self.ls = self.__simulatedata__()
    
    def __len__(self):
        return self.n_samples
    
    def __getitem__(self, idx=0):
        return(self.x[idx], self.y[idx], self.ls[idx])

    def __simulatedata__(self):
        rng_key = rnd.randint(0, 912393890428)
        rng_key, _ = random.split(random.PRNGKey(rng_key))
        x = np.linspace(self.x_lim_low, self.x_lim_high, self.n_dataPoints)   
        gp_predictive = Predictive(GP, num_samples=self.n_samples)  
        all_draws = gp_predictive(rng_key, x=x, gp_kernel = exp_sq_kernel, jitter=1e-6, length=self.ls)

        ls_draws = np.array(all_draws['ls'])
        gp_draws = np.array(all_draws['y'])
        
        return (x.repeat(self.n_samples).reshape(x.shape[0], self.n_samples).transpose(), gp_draws, ls_draws)

# %%
# what lengthscales are we generating?
dataset = GP1D(n_dataPoints=args["input_dim"])
ls_dataset = dataset.ls
plt.hist(ls_dataset) 
plt.xlim(0,1)
# Out:
# (0.0, 1.0)

# %%
# what trajectories are we getting?
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)

fig, ax = plt.subplots()
for no, dt in enumerate(dataloader):
    if dt[2] <= 0.2:
        col = 'orange'  
    elif dt[2] <= 0.6:
        col = 'green'
    else: 
        col = 'blue'
    ax.plot(dt[0].reshape(-1,1), dt[1].reshape(-1,1), color=col)
    if no > 15: break
ax.set_xlabel('$x$')
ax.set_ylabel('$y=f(x)$')
ax.set_title('realizations of a Gaussian process with RBF')

plt.show()

# %%
###### create or read training and test data
cwd = os.getcwd()
train_ds_name = 'gp1d_n' + str(args["input_dim"]) + '_train.pt'
test_ds_name = 'gp1d_n' + str(args["input_dim"]) + '_test.pt'
PATH_train = cwd+ "/data/gp1d/{train_ds_name}"
PATH_test =  cwd+"/data/gp1d/{test_ds_name}" 
    
if args["new_data"] == True:
    print("Generating new data")
    train_ds = GP1D(n_dataPoints=args["input_dim"], n_samples=args["samples"])
    test_ds = GP1D(n_dataPoints=args["input_dim"], n_samples=args["samples"])
    torch.save(train_ds, PATH_train)
    torch.save(test_ds, PATH_test)
else:
    print("Loading data")
    train_ds = torch.load(PATH_train)
    test_ds = torch.load(PATH_test)
    
test_dl = DataLoader(test_ds, batch_size=args["batch_size"], shuffle=True)
train_dl = DataLoader(train_ds, batch_size=args["batch_size"], shuffle=True)

# check distribution of lengthscales in training and test data
ls_train = train_ds.ls
plt.hist(ls_train, density=True) 
plt.xlim(0,1)
plt.show()

ls_test = test_ds.ls
plt.hist(ls_test, density=True) 
plt.xlim(0,1)
plt.show()
# Out:
# Generating new data

# %% [markdown]
# ## CVAE architecture

# %%
class Encoder(nn.Module):
    ''' This the encoder part of CVAE
    '''
    def __init__(self, input_dim, hidden_dim, z_dim, conditional):
        super().__init__()
        self.conditional = conditional
        if self.conditional:
            input_dim = input_dim + 1
        
        self.linear = nn.Linear(input_dim, hidden_dim)
        self.mu = nn.Linear(hidden_dim, z_dim)
        self.sd = nn.Linear(hidden_dim, z_dim)
        
    def forward(self, x, c=None):
        if self.conditional:
            x = torch.cat((x, c), dim=-1)

        hidden = torch.relu(self.linear(x))
        z_mu = self.mu(hidden)
        z_sd = self.sd(hidden)
        return z_mu, z_sd

# %%
class Decoder(nn.Module):
    ''' This the decoder part of VAE
    '''
    def __init__(self,z_dim, hidden_dim, input_dim,  conditional):
        super().__init__()
        
        self.conditional = conditional
        if self.conditional:
            z_dim = z_dim + 1
            
        self.linear = nn.Linear(z_dim, hidden_dim)
        self.out = nn.Linear(hidden_dim, input_dim)
    
    def forward(self, z, c):
        if self.conditional:
            z = torch.cat((z, c), dim=-1)

        hidden = torch.relu(self.linear(z))
        pred = self.out(hidden)
        return pred

# %%
class VAE(nn.Module):
    ''' This the VAE, which takes a encoder and decoder.
    '''
    def __init__(self, input_dim, hidden_dim, latent_dim,
                 conditional=False):
        
        super().__init__()        
        self.encoder = Encoder(input_dim, hidden_dim, latent_dim, conditional) 
        self.decoder = Decoder(latent_dim, hidden_dim, input_dim, conditional)

    def reparameterize(self, z_mu, z_sd):
        '''During training random sample from the learned ZDIMS-dimensional
           normal distribution; during inference its mean.
        '''
        if self.training:
            std = torch.exp(z_sd / 2)
            eps = torch.randn_like(std)
            return (eps.mul(std).add_(z_mu))
        else:
            return z_mu

    def forward(self, x, c=None):
        z_mu, z_sd = self.encoder(x, c)
        x_sample = self.reparameterize(z_mu, z_sd)
        generated_x = self.decoder(x_sample, c)
        return generated_x, z_mu,z_sd

# %%
def calculate_loss(y, reconstructed_y, mean, log_sd, vae_sd=args["vae_sd"]):

    # Compute the negative log-likelihood of the Gaussian distribution
    RCL = -torch.sum(- 0.5 * ((y - reconstructed_y) / vae_sd) ** 2)

    # Compute the KL divergence
    KLD = -0.5 * torch.sum(1 + log_sd - mean.pow(2) - log_sd.exp())

    return RCL + KLD

# %% [markdown]
# ## Train PriorVAE

# %%
# 1) Model
input_dim = args["input_dim"]
hidden_dim = args["hidden_dim"]
z_dim = args["z_dim"]
conditional = args["conditional"]

model = VAE(input_dim, hidden_dim, z_dim, conditional)

# 2) optimizer
optimizer = optim.Adam(model.parameters(), lr=args["learning_rate"])       
device = 'cuda' if torch.cuda.is_available() else 'cpu' 
model = model.to(device)

loss_history_train = []
loss_history_test = []

# %%
def calc_loss(model, data, loss_fn):
    
    model.eval()
    with torch.no_grad():
        total_loss = 0

        for i, (_, y, ls) in enumerate(data):    
            y = y.to(device)
            if args["conditional"]:
                ls = ls.to(device)
                reconstructed_y, z_mu, z_sd = model(y, ls) 
            else:
                reconstructed_y, z_mu, z_sd = model(y)
                
            loss_i = loss_fn(y, reconstructed_y, z_mu, z_sd) 
            total_loss += loss_i.item()
            
    return total_loss / len(data)

# %%
num_epochs = args['n_epochs']

best_model = model

if args["train_vae"] == True:

    for epoch in range(num_epochs):
        
        # Set the model back to training mode
        model.train(True)
        
        # batch training
        for i, (_, y, ls) in enumerate(train_dl):

            # Clear the gradients
            optimizer.zero_grad()
            
            # Forward pass
            y = y.to(device)

            if args["conditional"]:
                ls = ls.to(device)
                reconstructed_y, z_mu, z_sd = model(y, ls) 
            else:
                reconstructed_y, z_mu, z_sd = model(y)
                
            # training loss on the batch    
            loss_tr = calculate_loss(y, reconstructed_y, z_mu, z_sd) 
            
            # Backward pass
            loss_tr.backward()
    
            # Update the weights
            optimizer.step()
            
        # Calculate the training loss for the epoch
        train_loss = calc_loss(model, train_dl, calculate_loss)
        loss_history_train.append(train_loss)
        
        # Set the model to evaluation mode
        model.eval()
  
        # Calculate the test loss for the epoch
        test_loss = calc_loss(model, test_dl, calculate_loss)
        loss_history_test.append(test_loss)
        
        if epoch==0:
            best_loss = test_loss
        else:
            if test_loss < best_loss:
                best_model = model
                best_loss = test_loss
        
        # Print the losses
        print(f"Epoch {epoch}: Train loss = {train_loss:.4f}, Test loss = {test_loss:.4f}")
        
        
    plt.figure()
    plt.plot(np.arange(len(loss_history_train)), loss_history_train, label="train loss")
    plt.plot(np.arange(len(loss_history_test)), loss_history_test, label="test loss")
    plt.xlabel("epochs")
    plt.ylabel("train error")
    plt.legend()
    plt.title("Train and test loss, PriorCVAE")
    plt.show()
# Out:
# Epoch 0: Train loss = 5289.1045, Test loss = 5269.3529
# Epoch 1: Train loss = 4488.4231, Test loss = 4472.8026
# Epoch 2: Train loss = 3944.7469, Test loss = 3932.6072
# Epoch 3: Train loss = 3790.4607, Test loss = 3779.8467
# Epoch 4: Train loss = 3744.7008, Test loss = 3734.0942
# Epoch 5: Train loss = 3686.1212, Test loss = 3675.5013
# Epoch 6: Train loss = 3668.9579, Test loss = 3659.2794
# Epoch 7: Train loss = 3637.1851, Test loss = 3627.6651
# Epoch 8: Train loss = 3635.6894, Test loss = 3626.4015
# Epoch 9: Train loss = 3573.3280, Test loss = 3563.8175
# Epoch 10: Train loss = 3594.6745, Test loss = 3585.2516
# Epoch 11: Train loss = 3552.3123, Test loss = 3543.0686
# Epoch 12: Train loss = 3496.5408, Test loss = 3487.3380
# Epoch 13: Train loss = 3483.2519, Test loss = 3474.0510
# Epoch 14: Train loss = 3463.4316, Test loss = 3454.1978
# Epoch 15: Train loss = 3439.3978, Test loss = 3429.9257
# Epoch 16: Train loss = 3421.6326, Test loss = 3411.6519
# Epoch 17: Train loss = 3394.3613, Test loss = 3384.2050
# Epoch 18: Train loss = 3412.4943, Test loss = 3402.1705
# Epoch 19: Train loss = 3386.8157, Test loss = 3376.6931
# Epoch 20: Train loss = 3387.9052, Test loss = 3377.6013
# Epoch 21: Train loss = 3397.9966, Test loss = 3387.7477
# Epoch 22: Train loss = 3361.8913, Test loss = 3351.7683
# Epoch 23: Train loss = 3329.4303, Test loss = 3319.6441
# Epoch 24: Train loss = 3288.7200, Test loss = 3279.2712
# Epoch 25: Train loss = 3303.2353, Test loss = 3293.9395
# Epoch 26: Train loss = 3278.4319, Test loss = 3268.9758
# Epoch 27: Train loss = 3289.4608, Test loss = 3279.9097
# Epoch 28: Train loss = 3263.5315, Test loss = 3254.5810
# Epoch 29: Train loss = 3268.2623, Test loss = 3259.2503
# Epoch 30: Train loss = 3268.2555, Test loss = 3259.5890
# Epoch 31: Train loss = 3234.1209, Test loss = 3225.8110
# Epoch 32: Train loss = 3221.5036, Test loss = 3213.1652
# Epoch 33: Train loss = 3214.7858, Test loss = 3206.2842
# Epoch 34: Train loss = 3198.8141, Test loss = 3190.2261
# Epoch 35: Train loss = 3230.0022, Test loss = 3221.6370
# Epoch 36: Train loss = 3218.6311, Test loss = 3210.2652
# Epoch 37: Train loss = 3227.3205, Test loss = 3218.9736
# Epoch 38: Train loss = 3221.3216, Test loss = 3213.1659
# Epoch 39: Train loss = 3218.2766, Test loss = 3209.9448
# Epoch 40: Train loss = 3235.1982, Test loss = 3226.8994
# Epoch 41: Train loss = 3206.9407, Test loss = 3198.7456
# Epoch 42: Train loss = 3207.9819, Test loss = 3199.4349
# Epoch 43: Train loss = 3230.4722, Test loss = 3222.5544
# Epoch 44: Train loss = 3212.7910, Test loss = 3204.4698
# Epoch 45: Train loss = 3205.3122, Test loss = 3196.8876
# Epoch 46: Train loss = 3202.8936, Test loss = 3194.3519
# Epoch 47: Train loss = 3195.0241, Test loss = 3186.7872
# Epoch 48: Train loss = 3209.5235, Test loss = 3200.9487
# Epoch 49: Train loss = 3195.8207, Test loss = 3187.6399
# Epoch 50: Train loss = 3202.8341, Test loss = 3194.3284
# Epoch 51: Train loss = 3181.7260, Test loss = 3173.6376
# Epoch 52: Train loss = 3191.9502, Test loss = 3183.5269
# Epoch 53: Train loss = 3182.0004, Test loss = 3173.5878
# Epoch 54: Train loss = 3171.2083, Test loss = 3163.1738
# Epoch 55: Train loss = 3174.6762, Test loss = 3167.1944
# Epoch 56: Train loss = 3145.1965, Test loss = 3137.7907
# Epoch 57: Train loss = 3144.4709, Test loss = 3137.2266
# Epoch 58: Train loss = 3152.2105, Test loss = 3144.8878
# Epoch 59: Train loss = 3150.9375, Test loss = 3143.6183
# Epoch 60: Train loss = 3151.3055, Test loss = 3144.4848
# Epoch 61: Train loss = 3119.5034, Test loss = 3112.8626
# Epoch 62: Train loss = 3125.9058, Test loss = 3118.7571
# Epoch 63: Train loss = 3135.8340, Test loss = 3128.8199
# Epoch 64: Train loss = 3133.4550, Test loss = 3126.4001
# Epoch 65: Train loss = 3126.6757, Test loss = 3120.2542
# Epoch 66: Train loss = 3140.6518, Test loss = 3133.9618
# Epoch 67: Train loss = 3140.1189, Test loss = 3132.7020
# Epoch 68: Train loss = 3124.8934, Test loss = 3117.4110
# Epoch 69: Train loss = 3121.3528, Test loss = 3114.2594
# Epoch 70: Train loss = 3128.6750, Test loss = 3121.2045
# Epoch 71: Train loss = 3124.0828, Test loss = 3116.6979
# Epoch 72: Train loss = 3113.9238, Test loss = 3106.6313
# Epoch 73: Train loss = 3111.0322, Test loss = 3104.2230
# Epoch 74: Train loss = 3141.5780, Test loss = 3134.6942
# Epoch 75: Train loss = 3108.9569, Test loss = 3102.2174
# Epoch 76: Train loss = 3102.6459, Test loss = 3095.3795
# Epoch 77: Train loss = 3135.3517, Test loss = 3128.2504
# Epoch 78: Train loss = 3115.6391, Test loss = 3108.6780
# Epoch 79: Train loss = 3127.1971, Test loss = 3119.9800
# Epoch 80: Train loss = 3129.3632, Test loss = 3121.5362
# Epoch 81: Train loss = 3127.5956, Test loss = 3119.9857
# Epoch 82: Train loss = 3118.4530, Test loss = 3111.2350
# Epoch 83: Train loss = 3142.2050, Test loss = 3135.3075
# Epoch 84: Train loss = 3117.3791, Test loss = 3110.2249
# Epoch 85: Train loss = 3115.7796, Test loss = 3108.5557
# Epoch 86: Train loss = 3114.8150, Test loss = 3107.6997
# Epoch 87: Train loss = 3105.7244, Test loss = 3098.5408
# Epoch 88: Train loss = 3114.9809, Test loss = 3107.7834
# Epoch 89: Train loss = 3144.5086, Test loss = 3137.6280
# Epoch 90: Train loss = 3110.1100, Test loss = 3103.1531
# Epoch 91: Train loss = 3101.5702, Test loss = 3094.7962
# Epoch 92: Train loss = 3101.8251, Test loss = 3094.8132
# Epoch 93: Train loss = 3102.3180, Test loss = 3095.2466
# Epoch 94: Train loss = 3119.1849, Test loss = 3112.3414
# Epoch 95: Train loss = 3101.5809, Test loss = 3094.4560
# Epoch 96: Train loss = 3112.8096, Test loss = 3105.4602
# Epoch 97: Train loss = 3107.2630, Test loss = 3100.1443
# Epoch 98: Train loss = 3114.1727, Test loss = 3107.2759
# Epoch 99: Train loss = 3101.5172, Test loss = 3094.7244
# Epoch 100: Train loss = 3111.7312, Test loss = 3104.6362
# Epoch 101: Train loss = 3105.4908, Test loss = 3098.5753
# Epoch 102: Train loss = 3115.8074, Test loss = 3108.8849
# Epoch 103: Train loss = 3107.5955, Test loss = 3100.7206
# Epoch 104: Train loss = 3133.5504, Test loss = 3126.7988
# Epoch 105: Train loss = 3111.4818, Test loss = 3104.7355
# Epoch 106: Train loss = 3100.3548, Test loss = 3093.5578
# Epoch 107: Train loss = 3109.2630, Test loss = 3102.2130
# Epoch 108: Train loss = 3125.7000, Test loss = 3119.0023
# Epoch 109: Train loss = 3106.5578, Test loss = 3099.6601
# Epoch 110: Train loss = 3110.0715, Test loss = 3102.8501
# Epoch 111: Train loss = 3084.9839, Test loss = 3077.8626
# Epoch 112: Train loss = 3105.5991, Test loss = 3098.5814
# Epoch 113: Train loss = 3070.9964, Test loss = 3064.2529
# Epoch 114: Train loss = 3084.6916, Test loss = 3077.8241
# Epoch 115: Train loss = 3069.7571, Test loss = 3063.1696
# Epoch 116: Train loss = 3076.4968, Test loss = 3069.4712
# Epoch 117: Train loss = 3067.5372, Test loss = 3060.9152
# Epoch 118: Train loss = 3071.1616, Test loss = 3064.2557
# Epoch 119: Train loss = 3082.1877, Test loss = 3075.2266
# Epoch 120: Train loss = 3078.1571, Test loss = 3071.4142
# Epoch 121: Train loss = 3069.8530, Test loss = 3063.1212
# Epoch 122: Train loss = 3053.2299, Test loss = 3046.6322
# Epoch 123: Train loss = 3072.0938, Test loss = 3065.0952
# Epoch 124: Train loss = 3057.9989, Test loss = 3051.1282
# Epoch 125: Train loss = 3059.6068, Test loss = 3052.6102
# Epoch 126: Train loss = 3063.8508, Test loss = 3057.3004
# Epoch 127: Train loss = 3067.8037, Test loss = 3061.7247
# Epoch 128: Train loss = 3050.9659, Test loss = 3044.5207
# Epoch 129: Train loss = 3058.4475, Test loss = 3052.1353
# Epoch 130: Train loss = 3051.1857, Test loss = 3044.5790
# Epoch 131: Train loss = 3038.2895, Test loss = 3032.0850
# Epoch 132: Train loss = 3060.5719, Test loss = 3053.9706
# Epoch 133: Train loss = 3061.1570, Test loss = 3054.8595
# Epoch 134: Train loss = 3064.0848, Test loss = 3058.2694
# Epoch 135: Train loss = 3075.0102, Test loss = 3068.5656
# Epoch 136: Train loss = 3040.0344, Test loss = 3033.7842
# Epoch 137: Train loss = 3041.6168, Test loss = 3035.7003
# Epoch 138: Train loss = 3043.6246, Test loss = 3037.2071
# Epoch 139: Train loss = 3065.4021, Test loss = 3059.4690
# Epoch 140: Train loss = 3054.4217, Test loss = 3048.4897
# Epoch 141: Train loss = 3052.4504, Test loss = 3046.7179
# Epoch 142: Train loss = 3054.9820, Test loss = 3049.1027
# Epoch 143: Train loss = 3047.5676, Test loss = 3041.7960
# Epoch 144: Train loss = 3072.3152, Test loss = 3065.9836
# Epoch 145: Train loss = 3052.0052, Test loss = 3045.8338
# Epoch 146: Train loss = 3054.9180, Test loss = 3048.9653
# Epoch 147: Train loss = 3066.1974, Test loss = 3060.4178
# Epoch 148: Train loss = 3046.8486, Test loss = 3040.8905
# Epoch 149: Train loss = 3037.8854, Test loss = 3031.7267
# Epoch 150: Train loss = 3059.4818, Test loss = 3053.6211
# Epoch 151: Train loss = 3029.3615, Test loss = 3023.6290
# Epoch 152: Train loss = 3053.6063, Test loss = 3047.9689
# Epoch 153: Train loss = 3043.7439, Test loss = 3037.8758
# Epoch 154: Train loss = 3060.7258, Test loss = 3054.7977
# Epoch 155: Train loss = 3045.8928, Test loss = 3039.7505
# Epoch 156: Train loss = 3014.1189, Test loss = 3008.0151
# Epoch 157: Train loss = 3017.4314, Test loss = 3011.3942
# Epoch 158: Train loss = 3018.1092, Test loss = 3012.6205
# Epoch 159: Train loss = 3019.3846, Test loss = 3013.4638
# Epoch 160: Train loss = 3024.4636, Test loss = 3018.6639
# Epoch 161: Train loss = 3030.8352, Test loss = 3024.9942
# Epoch 162: Train loss = 3015.3257, Test loss = 3009.2743
# Epoch 163: Train loss = 3003.3955, Test loss = 2997.3146
# Epoch 164: Train loss = 3018.3398, Test loss = 3012.4935
# Epoch 165: Train loss = 3021.7992, Test loss = 3015.8880
# Epoch 166: Train loss = 3005.0936, Test loss = 2998.8915
# Epoch 167: Train loss = 3018.0491, Test loss = 3012.3875
# Epoch 168: Train loss = 3030.2637, Test loss = 3024.4592
# Epoch 169: Train loss = 3018.1162, Test loss = 3012.2126
# Epoch 170: Train loss = 3013.7823, Test loss = 3007.7563
# Epoch 171: Train loss = 3004.9536, Test loss = 2999.1455
# Epoch 172: Train loss = 3015.5594, Test loss = 3009.6902
# Epoch 173: Train loss = 3006.6941, Test loss = 3000.4519
# Epoch 174: Train loss = 3022.8213, Test loss = 3016.9475
# Epoch 175: Train loss = 3019.5282, Test loss = 3013.7192
# Epoch 176: Train loss = 3006.4826, Test loss = 3000.3989
# Epoch 177: Train loss = 3016.4776, Test loss = 3010.7903
# Epoch 178: Train loss = 2996.0858, Test loss = 2990.1049
# Epoch 179: Train loss = 3023.4765, Test loss = 3017.2740
# Epoch 180: Train loss = 3017.3005, Test loss = 3011.4801
# Epoch 181: Train loss = 3012.8268, Test loss = 3006.8607
# Epoch 182: Train loss = 3026.1084, Test loss = 3019.8105
# Epoch 183: Train loss = 3018.7646, Test loss = 3012.8005
# Epoch 184: Train loss = 3011.1817, Test loss = 3005.3518
# Epoch 185: Train loss = 3017.2726, Test loss = 3011.0780
# Epoch 186: Train loss = 3004.0602, Test loss = 2998.0352
# Epoch 187: Train loss = 3018.5778, Test loss = 3012.5493
# Epoch 188: Train loss = 3009.9280, Test loss = 3004.0149
# Epoch 189: Train loss = 3014.7511, Test loss = 3008.5019
# Epoch 190: Train loss = 3002.7898, Test loss = 2996.9832
# Epoch 191: Train loss = 3007.7311, Test loss = 3001.9893
# Epoch 192: Train loss = 3007.4339, Test loss = 3001.0417
# Epoch 193: Train loss = 3001.1271, Test loss = 2995.3434
# Epoch 194: Train loss = 3012.4962, Test loss = 3006.6805
# Epoch 195: Train loss = 3009.3532, Test loss = 3003.4963
# Epoch 196: Train loss = 3015.8748, Test loss = 3010.1596
# Epoch 197: Train loss = 3027.5537, Test loss = 3021.8697
# Epoch 198: Train loss = 3010.2658, Test loss = 3004.7573
# Epoch 199: Train loss = 3027.0477, Test loss = 3021.6048
# Epoch 200: Train loss = 3025.0357, Test loss = 3018.5630
# Epoch 201: Train loss = 3006.5533, Test loss = 3000.4916
# Epoch 202: Train loss = 3033.0044, Test loss = 3026.7198
# Epoch 203: Train loss = 3002.3460, Test loss = 2996.4037
# Epoch 204: Train loss = 3009.8412, Test loss = 3004.2715
# Epoch 205: Train loss = 3010.7285, Test loss = 3004.9505
# Epoch 206: Train loss = 2995.8118, Test loss = 2989.8047
# Epoch 207: Train loss = 3008.7239, Test loss = 3002.9504
# Epoch 208: Train loss = 3006.4373, Test loss = 3000.8829
# Epoch 209: Train loss = 3010.2180, Test loss = 3004.5518
# Epoch 210: Train loss = 3009.6252, Test loss = 3004.0366
# Epoch 211: Train loss = 3016.9696, Test loss = 3011.1957
# Epoch 212: Train loss = 2990.2590, Test loss = 2984.2810
# Epoch 213: Train loss = 3022.2463, Test loss = 3016.3872
# Epoch 214: Train loss = 3010.2877, Test loss = 3004.5080
# Epoch 215: Train loss = 3004.0307, Test loss = 2998.0015
# Epoch 216: Train loss = 3010.9819, Test loss = 3005.4235
# Epoch 217: Train loss = 3010.7690, Test loss = 3004.9494
# Epoch 218: Train loss = 3009.9255, Test loss = 3004.0060
# Epoch 219: Train loss = 3008.1587, Test loss = 3002.9432
# Epoch 220: Train loss = 3003.3311, Test loss = 2997.3749
# Epoch 221: Train loss = 3011.4804, Test loss = 3005.7490
# Epoch 222: Train loss = 3001.5478, Test loss = 2995.9082
# Epoch 223: Train loss = 3016.5770, Test loss = 3010.9108
# Epoch 224: Train loss = 3000.4627, Test loss = 2994.6167
# Epoch 225: Train loss = 3003.2163, Test loss = 2997.6083
# Epoch 226: Train loss = 3005.5007, Test loss = 2999.3480
# Epoch 227: Train loss = 2989.8213, Test loss = 2984.2485
# Epoch 228: Train loss = 2990.1199, Test loss = 2984.2164
# Epoch 229: Train loss = 3014.7018, Test loss = 3008.9053
# Epoch 230: Train loss = 2991.9445, Test loss = 2985.8849
# Epoch 231: Train loss = 2993.1273, Test loss = 2987.1137
# Epoch 232: Train loss = 3020.5485, Test loss = 3014.9081
# Epoch 233: Train loss = 2992.0747, Test loss = 2986.0554
# Epoch 234: Train loss = 3004.2853, Test loss = 2998.6356
# Epoch 235: Train loss = 2996.8452, Test loss = 2990.8814
# Epoch 236: Train loss = 3001.6571, Test loss = 2995.8753
# Epoch 237: Train loss = 3026.3383, Test loss = 3020.5781
# Epoch 238: Train loss = 2992.8313, Test loss = 2986.9313
# Epoch 239: Train loss = 3001.5231, Test loss = 2996.2258
# Epoch 240: Train loss = 2998.8326, Test loss = 2992.9124
# Epoch 241: Train loss = 3007.8227, Test loss = 3002.0360
# Epoch 242: Train loss = 2997.1417, Test loss = 2991.0793
# Epoch 243: Train loss = 3015.4912, Test loss = 3009.5662
# Epoch 244: Train loss = 3002.1799, Test loss = 2996.3619
# Epoch 245: Train loss = 3006.4689, Test loss = 3000.7660
# Epoch 246: Train loss = 3032.2920, Test loss = 3025.9948
# Epoch 247: Train loss = 3009.7619, Test loss = 3003.9927
# Epoch 248: Train loss = 2995.3900, Test loss = 2989.7089
# Epoch 249: Train loss = 3019.1854, Test loss = 3013.3489
# Epoch 250: Train loss = 2984.7581, Test loss = 2978.8359
# Epoch 251: Train loss = 2995.3028, Test loss = 2989.6145
# Epoch 252: Train loss = 2985.9355, Test loss = 2979.9707
# Epoch 253: Train loss = 2998.3709, Test loss = 2992.5358
# Epoch 254: Train loss = 3017.9598, Test loss = 3011.5940
# Epoch 255: Train loss = 3009.8305, Test loss = 3004.2492
# Epoch 256: Train loss = 3015.5981, Test loss = 3009.8713
# Epoch 257: Train loss = 3020.7329, Test loss = 3014.6888
# Epoch 258: Train loss = 3006.6604, Test loss = 3000.7768
# Epoch 259: Train loss = 2994.4219, Test loss = 2988.8459
# Epoch 260: Train loss = 3014.1321, Test loss = 3008.1883
# Epoch 261: Train loss = 3007.5128, Test loss = 3001.9201
# Epoch 262: Train loss = 2989.6173, Test loss = 2983.8680
# Epoch 263: Train loss = 2990.2658, Test loss = 2984.6795
# Epoch 264: Train loss = 3011.8126, Test loss = 3005.9057
# Epoch 265: Train loss = 2993.7207, Test loss = 2988.1756
# Epoch 266: Train loss = 3002.9083, Test loss = 2997.2491
# Epoch 267: Train loss = 3001.1229, Test loss = 2995.2974
# Epoch 268: Train loss = 3007.3458, Test loss = 3001.2636
# Epoch 269: Train loss = 3004.3964, Test loss = 2998.7720
# Epoch 270: Train loss = 3000.1248, Test loss = 2994.3443
# Epoch 271: Train loss = 2999.5420, Test loss = 2993.6668
# Epoch 272: Train loss = 2987.4572, Test loss = 2981.3350
# Epoch 273: Train loss = 3006.3760, Test loss = 3000.7721
# Epoch 274: Train loss = 2999.0326, Test loss = 2993.1667
# Epoch 275: Train loss = 3011.7174, Test loss = 3005.9555
# Epoch 276: Train loss = 2990.4121, Test loss = 2984.5131
# Epoch 277: Train loss = 3013.7702, Test loss = 3007.8116
# Epoch 278: Train loss = 2996.4501, Test loss = 2990.6527
# Epoch 279: Train loss = 3006.4657, Test loss = 3000.5454
# Epoch 280: Train loss = 2985.5520, Test loss = 2979.2925
# Epoch 281: Train loss = 3017.2001, Test loss = 3011.1879
# Epoch 282: Train loss = 2990.2061, Test loss = 2984.1919
# Epoch 283: Train loss = 3007.6577, Test loss = 3001.5268
# Epoch 284: Train loss = 3001.1083, Test loss = 2994.9947
# Epoch 285: Train loss = 3008.4628, Test loss = 3002.5099
# Epoch 286: Train loss = 2997.8983, Test loss = 2991.9518
# Epoch 287: Train loss = 3001.1164, Test loss = 2995.4719
# Epoch 288: Train loss = 2981.4618, Test loss = 2975.7016
# Epoch 289: Train loss = 3008.0207, Test loss = 3002.1514
# Epoch 290: Train loss = 2983.8482, Test loss = 2977.8931
# Epoch 291: Train loss = 3002.9564, Test loss = 2996.9485
# Epoch 292: Train loss = 2996.8485, Test loss = 2990.9807
# Epoch 293: Train loss = 3002.1609, Test loss = 2996.3562
# Epoch 294: Train loss = 2992.7455, Test loss = 2986.8183
# Epoch 295: Train loss = 2981.9846, Test loss = 2976.2143
# Epoch 296: Train loss = 2977.5002, Test loss = 2971.4071
# Epoch 297: Train loss = 3001.6431, Test loss = 2995.9953
# Epoch 298: Train loss = 3005.8591, Test loss = 2999.8109
# Epoch 299: Train loss = 2984.3221, Test loss = 2978.0900
# Epoch 300: Train loss = 2996.9711, Test loss = 2991.0162
# Epoch 301: Train loss = 2997.1377, Test loss = 2991.2496
# Epoch 302: Train loss = 2991.7572, Test loss = 2986.0597
# Epoch 303: Train loss = 3003.1045, Test loss = 2997.3629
# Epoch 304: Train loss = 2991.6081, Test loss = 2985.4390
# Epoch 305: Train loss = 2997.4710, Test loss = 2991.9890
# Epoch 306: Train loss = 3030.5209, Test loss = 3024.8009
# Epoch 307: Train loss = 3011.1075, Test loss = 3004.7437
# Epoch 308: Train loss = 2972.5029, Test loss = 2966.4569
# Epoch 309: Train loss = 2986.9810, Test loss = 2980.9027
# Epoch 310: Train loss = 3007.7734, Test loss = 3001.7677
# Epoch 311: Train loss = 2996.8291, Test loss = 2990.7076
# Epoch 312: Train loss = 2999.4795, Test loss = 2993.2245
# Epoch 313: Train loss = 3007.5888, Test loss = 3001.4193
# Epoch 314: Train loss = 2994.1441, Test loss = 2988.2340
# Epoch 315: Train loss = 2994.5436, Test loss = 2988.6127
# Epoch 316: Train loss = 3002.7527, Test loss = 2996.9316
# Epoch 317: Train loss = 3002.7243, Test loss = 2997.3452
# Epoch 318: Train loss = 2999.0131, Test loss = 2993.3920
# Epoch 319: Train loss = 2991.9287, Test loss = 2986.5898
# Epoch 320: Train loss = 2981.0717, Test loss = 2975.1520
# Epoch 321: Train loss = 3016.0437, Test loss = 3009.9026
# Epoch 322: Train loss = 3000.7038, Test loss = 2995.3586
# Epoch 323: Train loss = 2993.7783, Test loss = 2988.1290
# Epoch 324: Train loss = 2995.9785, Test loss = 2990.2140
# Epoch 325: Train loss = 3001.4994, Test loss = 2995.3704
# Epoch 326: Train loss = 2986.8204, Test loss = 2980.4886
# Epoch 327: Train loss = 2996.0676, Test loss = 2990.0403
# Epoch 328: Train loss = 2995.9269, Test loss = 2990.4138
# Epoch 329: Train loss = 3008.3292, Test loss = 3002.1248
# Epoch 330: Train loss = 3014.3045, Test loss = 3008.4373
# Epoch 331: Train loss = 2989.6186, Test loss = 2983.2280
# Epoch 332: Train loss = 3006.0453, Test loss = 3000.2878
# Epoch 333: Train loss = 3016.7090, Test loss = 3010.9749
# Epoch 334: Train loss = 2998.5024, Test loss = 2992.5543
# Epoch 335: Train loss = 2976.1934, Test loss = 2970.0248
# Epoch 336: Train loss = 2999.0811, Test loss = 2993.1048
# Epoch 337: Train loss = 3010.2830, Test loss = 3004.1089
# Epoch 338: Train loss = 2992.8437, Test loss = 2986.7876
# Epoch 339: Train loss = 3015.2974, Test loss = 3009.1685
# Epoch 340: Train loss = 2988.9016, Test loss = 2983.3575
# Epoch 341: Train loss = 2991.5173, Test loss = 2985.6634
# Epoch 342: Train loss = 3006.2988, Test loss = 3000.3472
# Epoch 343: Train loss = 3019.1725, Test loss = 3013.3731
# Epoch 344: Train loss = 3000.9207, Test loss = 2995.0240
# Epoch 345: Train loss = 3001.4640, Test loss = 2995.9002
# Epoch 346: Train loss = 2999.1681, Test loss = 2993.1700
# Epoch 347: Train loss = 2975.7239, Test loss = 2970.0065
# Epoch 348: Train loss = 3004.1002, Test loss = 2998.2908
# Epoch 349: Train loss = 3010.6892, Test loss = 3004.9256
# Epoch 350: Train loss = 2997.3551, Test loss = 2991.6732
# Epoch 351: Train loss = 3006.5237, Test loss = 3000.6848
# Epoch 352: Train loss = 2995.6400, Test loss = 2989.8524
# Epoch 353: Train loss = 2994.1475, Test loss = 2988.2241
# Epoch 354: Train loss = 2995.2412, Test loss = 2989.4114
# Epoch 355: Train loss = 2995.5031, Test loss = 2989.4885
# Epoch 356: Train loss = 2996.3541, Test loss = 2990.4738
# Epoch 357: Train loss = 2991.6095, Test loss = 2986.2207
# Epoch 358: Train loss = 3002.0048, Test loss = 2996.3403
# Epoch 359: Train loss = 3013.0651, Test loss = 3007.3256
# Epoch 360: Train loss = 2998.6989, Test loss = 2992.8016
# Epoch 361: Train loss = 3003.5436, Test loss = 2998.3611
# Epoch 362: Train loss = 3000.3762, Test loss = 2994.7038
# Epoch 363: Train loss = 2991.2733, Test loss = 2985.3156
# Epoch 364: Train loss = 3001.7573, Test loss = 2996.0847
# Epoch 365: Train loss = 3001.1192, Test loss = 2995.4442
# Epoch 366: Train loss = 2981.3922, Test loss = 2975.7505
# Epoch 367: Train loss = 3005.2896, Test loss = 2999.9712
# Epoch 368: Train loss = 2995.6434, Test loss = 2989.9844
# Epoch 369: Train loss = 2991.6145, Test loss = 2985.8734
# Epoch 370: Train loss = 2985.3039, Test loss = 2979.5096
# Epoch 371: Train loss = 3000.3663, Test loss = 2994.6630
# Epoch 372: Train loss = 2995.0792, Test loss = 2989.4510
# Epoch 373: Train loss = 2996.1414, Test loss = 2990.1568
# Epoch 374: Train loss = 2978.2871, Test loss = 2972.3140
# Epoch 375: Train loss = 2993.7344, Test loss = 2987.9474
# Epoch 376: Train loss = 2999.9905, Test loss = 2994.1231
# Epoch 377: Train loss = 3004.2137, Test loss = 2998.3871
# Epoch 378: Train loss = 3004.9480, Test loss = 2999.6639
# Epoch 379: Train loss = 2994.3931, Test loss = 2988.5279
# Epoch 380: Train loss = 3007.2666, Test loss = 3001.1750
# Epoch 381: Train loss = 2998.6528, Test loss = 2992.2086
# Epoch 382: Train loss = 3008.3246, Test loss = 3002.6888
# Epoch 383: Train loss = 2992.1662, Test loss = 2986.4116
# Epoch 384: Train loss = 2998.2013, Test loss = 2992.5372
# Epoch 385: Train loss = 3009.0378, Test loss = 3003.5808
# Epoch 386: Train loss = 2982.3588, Test loss = 2976.6967
# Epoch 387: Train loss = 3014.1976, Test loss = 3008.7990
# Epoch 388: Train loss = 2993.2160, Test loss = 2987.7248
# Epoch 389: Train loss = 3009.1627, Test loss = 3003.5994
# Epoch 390: Train loss = 2986.8435, Test loss = 2981.1229
# Epoch 391: Train loss = 2994.4857, Test loss = 2988.6601
# Epoch 392: Train loss = 2985.6601, Test loss = 2979.3719
# Epoch 393: Train loss = 2994.4227, Test loss = 2988.4875
# Epoch 394: Train loss = 2985.3977, Test loss = 2979.8565
# Epoch 395: Train loss = 2993.1384, Test loss = 2987.1817
# Epoch 396: Train loss = 2993.8624, Test loss = 2988.1274
# Epoch 397: Train loss = 3010.1661, Test loss = 3004.2517
# Epoch 398: Train loss = 2980.3169, Test loss = 2974.6553
# Epoch 399: Train loss = 2988.0663, Test loss = 2982.3610
# Epoch 400: Train loss = 2992.5439, Test loss = 2986.6070
# Epoch 401: Train loss = 3010.8611, Test loss = 3005.1715
# Epoch 402: Train loss = 3007.6529, Test loss = 3001.4723
# Epoch 403: Train loss = 2989.2308, Test loss = 2983.0681
# Epoch 404: Train loss = 2983.0096, Test loss = 2977.4769
# Epoch 405: Train loss = 2997.3183, Test loss = 2991.6884
# Epoch 406: Train loss = 3000.5357, Test loss = 2994.9434
# Epoch 407: Train loss = 3002.4295, Test loss = 2996.4978
# Epoch 408: Train loss = 3008.5552, Test loss = 3002.9688
# Epoch 409: Train loss = 3007.5229, Test loss = 3001.7801
# Epoch 410: Train loss = 3001.8374, Test loss = 2995.7441
# Epoch 411: Train loss = 2992.0824, Test loss = 2986.4528
# Epoch 412: Train loss = 3000.0779, Test loss = 2994.4982
# Epoch 413: Train loss = 3002.0890, Test loss = 2996.0457
# Epoch 414: Train loss = 2998.9958, Test loss = 2993.4294
# Epoch 415: Train loss = 2988.1137, Test loss = 2982.4057
# Epoch 416: Train loss = 2990.5356, Test loss = 2984.6851
# Epoch 417: Train loss = 2995.0378, Test loss = 2988.7967
# Epoch 418: Train loss = 3007.5681, Test loss = 3001.8346
# Epoch 419: Train loss = 2990.0634, Test loss = 2984.3634
# Epoch 420: Train loss = 2995.5537, Test loss = 2989.7033
# Epoch 421: Train loss = 2977.7394, Test loss = 2972.1397
# Epoch 422: Train loss = 2994.3440, Test loss = 2989.1096
# Epoch 423: Train loss = 2990.5046, Test loss = 2985.1135
# Epoch 424: Train loss = 3004.6174, Test loss = 2999.0224
# Epoch 425: Train loss = 2983.1299, Test loss = 2977.4800
# Epoch 426: Train loss = 2991.9435, Test loss = 2986.2266
# Epoch 427: Train loss = 2995.6965, Test loss = 2990.0242
# Epoch 428: Train loss = 2985.6624, Test loss = 2979.9268
# Epoch 429: Train loss = 3008.0545, Test loss = 3001.8103
# Epoch 430: Train loss = 2979.5175, Test loss = 2973.6425
# Epoch 431: Train loss = 2990.3677, Test loss = 2984.3285
# Epoch 432: Train loss = 3006.4846, Test loss = 3000.4515
# Epoch 433: Train loss = 2990.4179, Test loss = 2984.9549
# Epoch 434: Train loss = 2998.9106, Test loss = 2992.6571
# Epoch 435: Train loss = 3012.1083, Test loss = 3006.2893
# Epoch 436: Train loss = 2996.4838, Test loss = 2990.9345
# Epoch 437: Train loss = 3008.8126, Test loss = 3003.3502
# Epoch 438: Train loss = 2978.8629, Test loss = 2973.0435
# Epoch 439: Train loss = 2987.1486, Test loss = 2981.4352
# Epoch 440: Train loss = 2988.4056, Test loss = 2982.5330
# Epoch 441: Train loss = 2972.1627, Test loss = 2966.2720
# Epoch 442: Train loss = 2992.8004, Test loss = 2987.2262
# Epoch 443: Train loss = 2990.0642, Test loss = 2984.6873
# Epoch 444: Train loss = 2988.0408, Test loss = 2982.5620
# Epoch 445: Train loss = 2986.7381, Test loss = 2981.3426
# Epoch 446: Train loss = 2991.7345, Test loss = 2985.8635
# Epoch 447: Train loss = 2983.0875, Test loss = 2977.5388
# Epoch 448: Train loss = 2990.7528, Test loss = 2985.0023
# Epoch 449: Train loss = 3004.4238, Test loss = 2998.4800
# Epoch 450: Train loss = 2979.1671, Test loss = 2973.4763
# Epoch 451: Train loss = 2997.1024, Test loss = 2991.3673
# Epoch 452: Train loss = 2991.4397, Test loss = 2985.9789
# Epoch 453: Train loss = 2984.1032, Test loss = 2978.2462
# Epoch 454: Train loss = 2993.9167, Test loss = 2988.3612
# Epoch 455: Train loss = 3005.4461, Test loss = 2999.4644
# Epoch 456: Train loss = 2985.7360, Test loss = 2979.9840
# Epoch 457: Train loss = 2992.5433, Test loss = 2986.5127
# Epoch 458: Train loss = 3005.0127, Test loss = 2999.2371
# Epoch 459: Train loss = 3000.8084, Test loss = 2995.0986
# Epoch 460: Train loss = 2997.2252, Test loss = 2991.4672
# Epoch 461: Train loss = 2978.4508, Test loss = 2972.5915
# Epoch 462: Train loss = 2989.2668, Test loss = 2983.5988
# Epoch 463: Train loss = 2990.8033, Test loss = 2985.5309
# Epoch 464: Train loss = 2985.5811, Test loss = 2980.0259
# Epoch 465: Train loss = 2978.1748, Test loss = 2972.5968
# Epoch 466: Train loss = 2982.2071, Test loss = 2977.1363
# Epoch 467: Train loss = 2982.9033, Test loss = 2977.5125
# Epoch 468: Train loss = 2975.3416, Test loss = 2969.6544
# Epoch 469: Train loss = 2993.6368, Test loss = 2988.3888
# Epoch 470: Train loss = 2983.2000, Test loss = 2977.6597
# Epoch 471: Train loss = 2983.7615, Test loss = 2978.1369
# Epoch 472: Train loss = 2982.6067, Test loss = 2977.2620
# Epoch 473: Train loss = 2974.4040, Test loss = 2969.2679
# Epoch 474: Train loss = 2982.1819, Test loss = 2976.7306
# Epoch 475: Train loss = 2986.8666, Test loss = 2981.6336
# Epoch 476: Train loss = 2964.3101, Test loss = 2958.9318
# Epoch 477: Train loss = 2968.8738, Test loss = 2963.8546
# Epoch 478: Train loss = 2965.9602, Test loss = 2960.9108
# Epoch 479: Train loss = 2983.0974, Test loss = 2978.2046
# Epoch 480: Train loss = 2968.1840, Test loss = 2963.1105
# Epoch 481: Train loss = 2965.0905, Test loss = 2960.3842
# Epoch 482: Train loss = 2974.7237, Test loss = 2969.9466
# Epoch 483: Train loss = 2961.6416, Test loss = 2956.9804
# Epoch 484: Train loss = 2970.7278, Test loss = 2965.7038
# Epoch 485: Train loss = 2965.5561, Test loss = 2960.4806
# Epoch 486: Train loss = 2989.6370, Test loss = 2984.7629
# Epoch 487: Train loss = 2962.9703, Test loss = 2958.0850
# Epoch 488: Train loss = 2963.2511, Test loss = 2958.2665
# Epoch 489: Train loss = 2974.5184, Test loss = 2969.6804
# Epoch 490: Train loss = 2955.2055, Test loss = 2950.5574
# Epoch 491: Train loss = 2968.5757, Test loss = 2963.7538
# Epoch 492: Train loss = 2973.1706, Test loss = 2968.6081
# Epoch 493: Train loss = 2946.5250, Test loss = 2941.9328
# Epoch 494: Train loss = 2965.7621, Test loss = 2961.1186
# Epoch 495: Train loss = 2948.6713, Test loss = 2944.0281
# Epoch 496: Train loss = 2979.0047, Test loss = 2974.3396
# Epoch 497: Train loss = 2978.2944, Test loss = 2973.6953
# Epoch 498: Train loss = 2971.8774, Test loss = 2967.4031
# Epoch 499: Train loss = 2971.6598, Test loss = 2967.2337
# Epoch 500: Train loss = 2965.5344, Test loss = 2961.1983
# Epoch 501: Train loss = 2975.6107, Test loss = 2971.0505
# Epoch 502: Train loss = 2957.8442, Test loss = 2953.3932
# Epoch 503: Train loss = 2957.8958, Test loss = 2953.0062
# Epoch 504: Train loss = 2977.2864, Test loss = 2972.7122
# Epoch 505: Train loss = 2968.7215, Test loss = 2964.1831
# Epoch 506: Train loss = 2976.2345, Test loss = 2971.3478
# Epoch 507: Train loss = 2982.6658, Test loss = 2978.1086
# Epoch 508: Train loss = 2966.7708, Test loss = 2961.7204
# Epoch 509: Train loss = 2962.2217, Test loss = 2957.8784
# Epoch 510: Train loss = 2964.8511, Test loss = 2960.5022
# Epoch 511: Train loss = 2975.0376, Test loss = 2970.4420
# Epoch 512: Train loss = 2967.0070, Test loss = 2962.5638
# Epoch 513: Train loss = 2960.0033, Test loss = 2955.5747
# Epoch 514: Train loss = 2977.3151, Test loss = 2972.8905
# Epoch 515: Train loss = 2973.7248, Test loss = 2969.5367
# Epoch 516: Train loss = 2960.5921, Test loss = 2956.2256
# Epoch 517: Train loss = 2976.7736, Test loss = 2972.4745
# Epoch 518: Train loss = 2966.2272, Test loss = 2961.8931
# Epoch 519: Train loss = 2964.0197, Test loss = 2959.9157
# Epoch 520: Train loss = 2961.6323, Test loss = 2957.1503
# Epoch 521: Train loss = 2971.8404, Test loss = 2967.3998
# Epoch 522: Train loss = 2947.7786, Test loss = 2943.6281
# Epoch 523: Train loss = 2965.2048, Test loss = 2960.8928
# Epoch 524: Train loss = 2975.0025, Test loss = 2970.2489
# Epoch 525: Train loss = 2952.5132, Test loss = 2948.1602
# Epoch 526: Train loss = 2965.5160, Test loss = 2961.2226
# Epoch 527: Train loss = 2965.6647, Test loss = 2961.3628
# Epoch 528: Train loss = 2960.3077, Test loss = 2956.1809
# Epoch 529: Train loss = 2966.2648, Test loss = 2961.9383
# Epoch 530: Train loss = 2969.1272, Test loss = 2964.8905
# Epoch 531: Train loss = 2979.3266, Test loss = 2974.3163
# Epoch 532: Train loss = 2953.4682, Test loss = 2948.9397
# Epoch 533: Train loss = 2965.5482, Test loss = 2961.2269
# Epoch 534: Train loss = 2963.9717, Test loss = 2959.7006
# Epoch 535: Train loss = 2966.5106, Test loss = 2962.3033
# Epoch 536: Train loss = 2954.4087, Test loss = 2950.1997
# Epoch 537: Train loss = 2972.1952, Test loss = 2967.4050
# Epoch 538: Train loss = 2964.8356, Test loss = 2960.4306
# Epoch 539: Train loss = 2961.8310, Test loss = 2957.4074
# Epoch 540: Train loss = 2962.7154, Test loss = 2958.3116
# Epoch 541: Train loss = 2950.3429, Test loss = 2946.1768
# Epoch 542: Train loss = 2966.8013, Test loss = 2962.5823
# Epoch 543: Train loss = 2973.7066, Test loss = 2969.1381
# Epoch 544: Train loss = 2946.8451, Test loss = 2942.2480
# Epoch 545: Train loss = 2970.5595, Test loss = 2966.3299
# Epoch 546: Train loss = 2957.0106, Test loss = 2952.6073
# Epoch 547: Train loss = 2955.0026, Test loss = 2950.2164
# Epoch 548: Train loss = 2958.2955, Test loss = 2953.9889
# Epoch 549: Train loss = 2964.0864, Test loss = 2959.7620
# Epoch 550: Train loss = 2952.8141, Test loss = 2948.4130
# Epoch 551: Train loss = 2957.4562, Test loss = 2953.3267
# Epoch 552: Train loss = 2968.2475, Test loss = 2964.1853
# Epoch 553: Train loss = 2948.6622, Test loss = 2944.0847
# Epoch 554: Train loss = 2969.8923, Test loss = 2965.6252
# Epoch 555: Train loss = 2969.1194, Test loss = 2965.0513
# Epoch 556: Train loss = 2970.8536, Test loss = 2966.7472
# Epoch 557: Train loss = 2969.7259, Test loss = 2965.4162
# Epoch 558: Train loss = 2963.5439, Test loss = 2959.3702
# Epoch 559: Train loss = 2965.8568, Test loss = 2961.5469
# Epoch 560: Train loss = 2950.0375, Test loss = 2945.8093
# Epoch 561: Train loss = 2978.0478, Test loss = 2973.1577
# Epoch 562: Train loss = 2957.6026, Test loss = 2952.9466
# Epoch 563: Train loss = 2967.3346, Test loss = 2962.8808
# Epoch 564: Train loss = 2957.7523, Test loss = 2953.5708
# Epoch 565: Train loss = 2965.6689, Test loss = 2961.4306
# Epoch 566: Train loss = 2973.7098, Test loss = 2969.1826
# Epoch 567: Train loss = 2964.6795, Test loss = 2960.1822
# Epoch 568: Train loss = 2940.8708, Test loss = 2936.4642
# Epoch 569: Train loss = 2951.9366, Test loss = 2947.5100
# Epoch 570: Train loss = 2953.1587, Test loss = 2949.1321
# Epoch 571: Train loss = 2956.4143, Test loss = 2952.2319
# Epoch 572: Train loss = 2964.3387, Test loss = 2960.1806
# Epoch 573: Train loss = 2955.7685, Test loss = 2951.7505
# Epoch 574: Train loss = 2943.6300, Test loss = 2939.5545
# Epoch 575: Train loss = 2958.0087, Test loss = 2953.6669
# Epoch 576: Train loss = 2946.9121, Test loss = 2942.7652
# Epoch 577: Train loss = 2949.3593, Test loss = 2944.7197
# Epoch 578: Train loss = 2940.1303, Test loss = 2936.1693
# Epoch 579: Train loss = 2953.6405, Test loss = 2949.4997
# Epoch 580: Train loss = 2949.2181, Test loss = 2945.0182
# Epoch 581: Train loss = 2941.2867, Test loss = 2936.8328
# Epoch 582: Train loss = 2941.5312, Test loss = 2936.9111
# Epoch 583: Train loss = 2936.3628, Test loss = 2932.2635
# Epoch 584: Train loss = 2951.7398, Test loss = 2947.2159
# Epoch 585: Train loss = 2954.6826, Test loss = 2950.4829
# Epoch 586: Train loss = 2947.5261, Test loss = 2943.1985
# Epoch 587: Train loss = 2936.6412, Test loss = 2932.5032
# Epoch 588: Train loss = 2937.1459, Test loss = 2933.3318
# Epoch 589: Train loss = 2943.3270, Test loss = 2939.1093
# Epoch 590: Train loss = 2952.9701, Test loss = 2949.0054
# Epoch 591: Train loss = 2949.9289, Test loss = 2945.8239
# Epoch 592: Train loss = 2945.4844, Test loss = 2941.0405
# Epoch 593: Train loss = 2929.6898, Test loss = 2925.4897
# Epoch 594: Train loss = 2950.9310, Test loss = 2946.6718
# Epoch 595: Train loss = 2949.1127, Test loss = 2945.2420
# Epoch 596: Train loss = 2927.3780, Test loss = 2923.1811
# Epoch 597: Train loss = 2931.8935, Test loss = 2927.7629
# Epoch 598: Train loss = 2955.6495, Test loss = 2951.2353
# Epoch 599: Train loss = 2945.0217, Test loss = 2941.1998
# Epoch 600: Train loss = 2955.1483, Test loss = 2951.0868
# Epoch 601: Train loss = 2955.3443, Test loss = 2951.6634
# Epoch 602: Train loss = 2942.2348, Test loss = 2938.2469
# Epoch 603: Train loss = 2946.4727, Test loss = 2942.3348
# Epoch 604: Train loss = 2943.8429, Test loss = 2940.0877
# Epoch 605: Train loss = 2926.1727, Test loss = 2922.2386
# Epoch 606: Train loss = 2967.7108, Test loss = 2963.7811
# Epoch 607: Train loss = 2947.5767, Test loss = 2943.3762
# Epoch 608: Train loss = 2946.0240, Test loss = 2942.1271
# Epoch 609: Train loss = 2945.1357, Test loss = 2940.8847
# Epoch 610: Train loss = 2934.0553, Test loss = 2930.0463
# Epoch 611: Train loss = 2928.2404, Test loss = 2924.0299
# Epoch 612: Train loss = 2937.2899, Test loss = 2933.6341
# Epoch 613: Train loss = 2935.6260, Test loss = 2931.7487
# Epoch 614: Train loss = 2942.7262, Test loss = 2938.8783
# Epoch 615: Train loss = 2939.8234, Test loss = 2935.8676
# Epoch 616: Train loss = 2944.4502, Test loss = 2940.4084
# Epoch 617: Train loss = 2947.2620, Test loss = 2943.1336
# Epoch 618: Train loss = 2928.7490, Test loss = 2925.2831
# Epoch 619: Train loss = 2943.5053, Test loss = 2939.4617
# Epoch 620: Train loss = 2938.0274, Test loss = 2934.3135
# Epoch 621: Train loss = 2938.6122, Test loss = 2934.6368
# Epoch 622: Train loss = 2951.5387, Test loss = 2947.7445
# Epoch 623: Train loss = 2956.1402, Test loss = 2951.7797
# Epoch 624: Train loss = 2950.1513, Test loss = 2946.0054
# Epoch 625: Train loss = 2921.9424, Test loss = 2917.9068
# Epoch 626: Train loss = 2945.9398, Test loss = 2941.7756
# Epoch 627: Train loss = 2939.2518, Test loss = 2935.3558
# Epoch 628: Train loss = 2954.6606, Test loss = 2950.6054
# Epoch 629: Train loss = 2953.1783, Test loss = 2949.2007
# Epoch 630: Train loss = 2954.5239, Test loss = 2950.4913
# Epoch 631: Train loss = 2937.1964, Test loss = 2933.1007
# Epoch 632: Train loss = 2948.5994, Test loss = 2944.7042
# Epoch 633: Train loss = 2927.0966, Test loss = 2923.1128
# Epoch 634: Train loss = 2933.3568, Test loss = 2929.3399
# Epoch 635: Train loss = 2942.5267, Test loss = 2938.5995
# Epoch 636: Train loss = 2946.2703, Test loss = 2942.5237
# Epoch 637: Train loss = 2936.4787, Test loss = 2932.4772
# Epoch 638: Train loss = 2949.8897, Test loss = 2945.9326
# Epoch 639: Train loss = 2944.7607, Test loss = 2941.0676
# Epoch 640: Train loss = 2951.1514, Test loss = 2947.1740
# Epoch 641: Train loss = 2947.0003, Test loss = 2943.4446
# Epoch 642: Train loss = 2957.2682, Test loss = 2953.1601
# Epoch 643: Train loss = 2932.8711, Test loss = 2928.7320
# Epoch 644: Train loss = 2948.9076, Test loss = 2944.7102
# Epoch 645: Train loss = 2943.2374, Test loss = 2939.2298
# Epoch 646: Train loss = 2936.9147, Test loss = 2933.1483
# Epoch 647: Train loss = 2949.8320, Test loss = 2946.0726
# Epoch 648: Train loss = 2935.8509, Test loss = 2932.0786
# Epoch 649: Train loss = 2940.0893, Test loss = 2936.3003
# Epoch 650: Train loss = 2941.1114, Test loss = 2937.5227
# Epoch 651: Train loss = 2929.8573, Test loss = 2926.2615
# Epoch 652: Train loss = 2932.7806, Test loss = 2929.1831
# Epoch 653: Train loss = 2929.7361, Test loss = 2926.2323
# Epoch 654: Train loss = 2943.3325, Test loss = 2939.3235
# Epoch 655: Train loss = 2924.8208, Test loss = 2920.9594
# Epoch 656: Train loss = 2950.4896, Test loss = 2946.4026
# Epoch 657: Train loss = 2945.6130, Test loss = 2941.9392
# Epoch 658: Train loss = 2935.5449, Test loss = 2931.4716
# Epoch 659: Train loss = 2952.9712, Test loss = 2949.0814
# Epoch 660: Train loss = 2956.2448, Test loss = 2952.2973
# Epoch 661: Train loss = 2943.1382, Test loss = 2939.8522
# Epoch 662: Train loss = 2943.4161, Test loss = 2939.6251
# Epoch 663: Train loss = 2946.7163, Test loss = 2942.4485
# Epoch 664: Train loss = 2940.0269, Test loss = 2936.0423
# Epoch 665: Train loss = 2927.8808, Test loss = 2923.8261
# Epoch 666: Train loss = 2953.5937, Test loss = 2949.5253
# Epoch 667: Train loss = 2948.0328, Test loss = 2944.1172
# Epoch 668: Train loss = 2946.0516, Test loss = 2942.1830
# Epoch 669: Train loss = 2946.3953, Test loss = 2942.4095
# Epoch 670: Train loss = 2940.0780, Test loss = 2936.2081
# Epoch 671: Train loss = 2951.4320, Test loss = 2947.4425
# Epoch 672: Train loss = 2927.9731, Test loss = 2924.1575
# Epoch 673: Train loss = 2928.0109, Test loss = 2924.2707
# Epoch 674: Train loss = 2944.7943, Test loss = 2940.9386
# Epoch 675: Train loss = 2949.8759, Test loss = 2945.8766
# Epoch 676: Train loss = 2951.7790, Test loss = 2948.2166
# Epoch 677: Train loss = 2928.8273, Test loss = 2924.9568
# Epoch 678: Train loss = 2932.0835, Test loss = 2928.3950
# Epoch 679: Train loss = 2958.1996, Test loss = 2954.3111
# Epoch 680: Train loss = 2946.6644, Test loss = 2942.9684
# Epoch 681: Train loss = 2942.0982, Test loss = 2938.1185
# Epoch 682: Train loss = 2942.7769, Test loss = 2938.8322
# Epoch 683: Train loss = 2935.2944, Test loss = 2931.4607
# Epoch 684: Train loss = 2932.3802, Test loss = 2928.8058
# Epoch 685: Train loss = 2940.8594, Test loss = 2937.0648
# Epoch 686: Train loss = 2925.1510, Test loss = 2921.2881
# Epoch 687: Train loss = 2943.6392, Test loss = 2939.7503
# Epoch 688: Train loss = 2919.8284, Test loss = 2916.0387
# Epoch 689: Train loss = 2930.7966, Test loss = 2927.4886
# Epoch 690: Train loss = 2949.1053, Test loss = 2945.3337
# Epoch 691: Train loss = 2934.3146, Test loss = 2930.7847
# Epoch 692: Train loss = 2947.0851, Test loss = 2943.5189
# Epoch 693: Train loss = 2936.5678, Test loss = 2932.4689
# Epoch 694: Train loss = 2924.1049, Test loss = 2920.2421
# Epoch 695: Train loss = 2942.4311, Test loss = 2939.0128
# Epoch 696: Train loss = 2927.0282, Test loss = 2923.7271
# Epoch 697: Train loss = 2939.7274, Test loss = 2936.0210
# Epoch 698: Train loss = 2959.2381, Test loss = 2955.3195
# Epoch 699: Train loss = 2939.1617, Test loss = 2935.5807
# Epoch 700: Train loss = 2930.4899, Test loss = 2926.6282
# Epoch 701: Train loss = 2943.7358, Test loss = 2940.0589
# Epoch 702: Train loss = 2927.3461, Test loss = 2923.8680
# Epoch 703: Train loss = 2930.3498, Test loss = 2926.6316
# Epoch 704: Train loss = 2943.4610, Test loss = 2939.6533
# Epoch 705: Train loss = 2937.0153, Test loss = 2933.4886
# Epoch 706: Train loss = 2948.1204, Test loss = 2944.6582
# Epoch 707: Train loss = 2943.5223, Test loss = 2940.1390
# Epoch 708: Train loss = 2941.2959, Test loss = 2937.8207
# Epoch 709: Train loss = 2931.6527, Test loss = 2927.7909
# Epoch 710: Train loss = 2930.9205, Test loss = 2927.1876
# Epoch 711: Train loss = 2940.4548, Test loss = 2936.7037
# Epoch 712: Train loss = 2938.0216, Test loss = 2934.4531
# Epoch 713: Train loss = 2941.3584, Test loss = 2937.7308
# Epoch 714: Train loss = 2920.0593, Test loss = 2916.0535
# Epoch 715: Train loss = 2939.9211, Test loss = 2936.2583
# Epoch 716: Train loss = 2927.1078, Test loss = 2923.3622
# Epoch 717: Train loss = 2948.3196, Test loss = 2944.3763
# Epoch 718: Train loss = 2936.1074, Test loss = 2932.6106
# Epoch 719: Train loss = 2946.5300, Test loss = 2942.9475
# Epoch 720: Train loss = 2957.2871, Test loss = 2953.6239
# Epoch 721: Train loss = 2930.9826, Test loss = 2927.7214
# Epoch 722: Train loss = 2948.1271, Test loss = 2944.3820
# Epoch 723: Train loss = 2938.5422, Test loss = 2935.1674
# Epoch 724: Train loss = 2959.8588, Test loss = 2956.2287
# Epoch 725: Train loss = 2940.9665, Test loss = 2937.0997
# Epoch 726: Train loss = 2959.8475, Test loss = 2955.7512
# Epoch 727: Train loss = 2944.3878, Test loss = 2940.8362
# Epoch 728: Train loss = 2956.8260, Test loss = 2953.5224
# Epoch 729: Train loss = 2944.5575, Test loss = 2941.1651
# Epoch 730: Train loss = 2928.1411, Test loss = 2924.2253
# Epoch 731: Train loss = 2938.0975, Test loss = 2934.2597
# Epoch 732: Train loss = 2948.0945, Test loss = 2944.1632
# Epoch 733: Train loss = 2944.8256, Test loss = 2941.0786
# Epoch 734: Train loss = 2921.8630, Test loss = 2918.1565
# Epoch 735: Train loss = 2933.1250, Test loss = 2929.4078
# Epoch 736: Train loss = 2935.8576, Test loss = 2932.0168
# Epoch 737: Train loss = 2956.3862, Test loss = 2952.5775
# Epoch 738: Train loss = 2940.9041, Test loss = 2937.0861
# Epoch 739: Train loss = 2913.2360, Test loss = 2909.3606
# Epoch 740: Train loss = 2948.9573, Test loss = 2945.5397
# Epoch 741: Train loss = 2928.1049, Test loss = 2924.5077
# Epoch 742: Train loss = 2938.0265, Test loss = 2934.4468
# Epoch 743: Train loss = 2944.0059, Test loss = 2940.7220
# Epoch 744: Train loss = 2946.5057, Test loss = 2942.5913
# Epoch 745: Train loss = 2953.9471, Test loss = 2950.2924
# Epoch 746: Train loss = 2942.7161, Test loss = 2939.0692
# Epoch 747: Train loss = 2955.9607, Test loss = 2952.3269
# Epoch 748: Train loss = 2943.1360, Test loss = 2939.3571
# Epoch 749: Train loss = 2937.1070, Test loss = 2933.7055
# Epoch 750: Train loss = 2937.2094, Test loss = 2933.5752
# Epoch 751: Train loss = 2948.0403, Test loss = 2944.3501
# Epoch 752: Train loss = 2951.1783, Test loss = 2947.7331
# Epoch 753: Train loss = 2930.7160, Test loss = 2926.7222
# Epoch 754: Train loss = 2952.3967, Test loss = 2948.5339
# Epoch 755: Train loss = 2925.8444, Test loss = 2922.4114
# Epoch 756: Train loss = 2924.7178, Test loss = 2921.2058
# Epoch 757: Train loss = 2937.8340, Test loss = 2934.2844
# Epoch 758: Train loss = 2949.8655, Test loss = 2946.2507
# Epoch 759: Train loss = 2959.5816, Test loss = 2956.1511
# Epoch 760: Train loss = 2935.8476, Test loss = 2932.0507
# Epoch 761: Train loss = 2928.6582, Test loss = 2924.7798
# Epoch 762: Train loss = 2938.5105, Test loss = 2934.9546
# Epoch 763: Train loss = 2945.1728, Test loss = 2941.4031
# Epoch 764: Train loss = 2941.2566, Test loss = 2937.4652
# Epoch 765: Train loss = 2943.6038, Test loss = 2939.7841
# Epoch 766: Train loss = 2939.0005, Test loss = 2935.1306
# Epoch 767: Train loss = 2944.8021, Test loss = 2940.9268
# Epoch 768: Train loss = 2938.4900, Test loss = 2935.0817
# Epoch 769: Train loss = 2937.7304, Test loss = 2934.1330
# Epoch 770: Train loss = 2930.4559, Test loss = 2926.6944
# Epoch 771: Train loss = 2938.8356, Test loss = 2935.2899
# Epoch 772: Train loss = 2930.4595, Test loss = 2926.7648
# Epoch 773: Train loss = 2943.5007, Test loss = 2939.9214
# Epoch 774: Train loss = 2942.8738, Test loss = 2939.2796
# Epoch 775: Train loss = 2935.2028, Test loss = 2930.9778
# Epoch 776: Train loss = 2951.1774, Test loss = 2947.7260
# Epoch 777: Train loss = 2943.1324, Test loss = 2939.3075
# Epoch 778: Train loss = 2939.2586, Test loss = 2935.8204
# Epoch 779: Train loss = 2946.7751, Test loss = 2943.0229
# Epoch 780: Train loss = 2933.0696, Test loss = 2929.5125
# Epoch 781: Train loss = 2932.0417, Test loss = 2928.4731
# Epoch 782: Train loss = 2931.4537, Test loss = 2927.8809
# Epoch 783: Train loss = 2933.9385, Test loss = 2930.4558
# Epoch 784: Train loss = 2944.9566, Test loss = 2941.5933
# Epoch 785: Train loss = 2924.0008, Test loss = 2920.2550
# Epoch 786: Train loss = 2933.5505, Test loss = 2929.8470
# Epoch 787: Train loss = 2928.8770, Test loss = 2925.1380
# Epoch 788: Train loss = 2942.1092, Test loss = 2938.6220
# Epoch 789: Train loss = 2947.1188, Test loss = 2943.8263
# Epoch 790: Train loss = 2934.6356, Test loss = 2931.0925
# Epoch 791: Train loss = 2930.1347, Test loss = 2927.0355
# Epoch 792: Train loss = 2939.1260, Test loss = 2935.7736
# Epoch 793: Train loss = 2922.4689, Test loss = 2918.8274
# Epoch 794: Train loss = 2924.9338, Test loss = 2920.9516
# Epoch 795: Train loss = 2938.5429, Test loss = 2934.8315
# Epoch 796: Train loss = 2924.9246, Test loss = 2921.4282
# Epoch 797: Train loss = 2925.7062, Test loss = 2922.2713
# Epoch 798: Train loss = 2932.2582, Test loss = 2928.7802
# Epoch 799: Train loss = 2929.3877, Test loss = 2925.6708

# %%
args["save_vae"]
# Out:
# False

# %%
start_ind = 20

plt.figure()
plt.plot(np.arange(len(loss_history_train[start_ind:])), loss_history_train[start_ind:], label="train loss")
plt.plot(np.arange(len(loss_history_test[start_ind:])), loss_history_test[start_ind:], label="test loss")
plt.xlabel("epochs")
plt.ylabel("train error")
plt.legend()
plt.title("Train and test losses, PriorCVAE")
plt.show()

# %%
model.state_dict()['encoder.linear.weight'] == best_model.state_dict()['encoder.linear.weight']

# %%
model = best_model
del best_model

# %%
###### Sampling draws from learnt model
model.eval() # model in eval mode

n_samps = 20
z = torch.randn(n_samps, z_dim).to(device) # random draw
c = torch.bernoulli(torch.ones(n_samps) * 0.5)

with torch.no_grad():
    c = c[:, None]
    sampled_y = model.decoder(z, c)

fig = plt.figure()
ax = fig.add_subplot(111)
for no, y in enumerate(sampled_y):
    if c[no] == 0:
        col = 'blue'  
    else:
        col = 'orange'
    ax.plot(train_ds.x[0], y.cpu().numpy(), color=col)

ax.set_xlabel('$x$')
ax.set_ylabel('$y=CVAE_f(x)$')
ax.set_title('realizations of PriorCVAE')
# Out:
# Text(0.5, 1.0, 'realizations of PriorCVAE')

# %%
import pickle

model_save_name = 'PriorCVAE_gp1d_n'+str(args["input_dim"])+'_h'+str(args["hidden_dim"])+'_z'+str(args["z_dim"])+'_epochs'+str(args["n_epochs"])+'_continuous.pt'
loss_train_name = 'CVAE_loss_train_gp1d_n'+str(args["input_dim"])+'_h'+str(args["hidden_dim"])+'_z'+str(args["z_dim"])+'_epochs'+str(args["n_epochs"])
loss_test_name = 'CVAE_loss_test_gp1d_n'+str(args["input_dim"])+'_h'+str(args["hidden_dim"])+'_z'+str(args["z_dim"])+'_epochs'+str(args["n_epochs"])
print(model_save_name) 
print(loss_train_name) 
print(loss_test_name) 

PATH = cwd + F"/trained_models/{model_save_name}" 

if args["save_vae"] == True:    
    print("CVAE model saved")
    torch.save(model.state_dict(), PATH)
    
    with open(loss_train_name, "wb") as fp:  
        pickle.dump(loss_history_train, fp)
    with open(loss_test_name, "wb") as fp:  
        pickle.dump(loss_history_test, fp)

elif args["load_vae"] == True:
    model.load_state_dict(torch.load(PATH))
    
    with open(loss_train_name, "rb") as fp:   
        loss_history_train = pickle.load(fp)
    with open(loss_test_name, "rb") as fp:   
        loss_history_test = pickle.load(fp)

    print("CVAE model loaded")
else:
    print("no model loaded")
# Out:
# PriorCVAE_gp1d_n80_h60_z40_epochs800_continuous.pt
# CVAE_loss_train_gp1d_n80_h60_z40_epochs800
# CVAE_loss_test_gp1d_n80_h60_z40_epochs800
# no model loaded

# %% [markdown]
# ## Visual diagnostics of how well we have learnt

# %%
def MMD(x, y, kernel="multiscale"):
    """Emprical maximum mean discrepancy. The lower the result, the more evidence that distributions are the same.

    Args:
        x: first sample, distribution P
        y: second sample, distribution Q
        kernel: kernel type such as "multiscale" or "rbf"
    """
    xx, yy, zz = torch.mm(x, x.t()), torch.mm(y, y.t()), torch.mm(x, y.t())
    rx = (xx.diag().unsqueeze(0).expand_as(xx))
    ry = (yy.diag().unsqueeze(0).expand_as(yy))
    
    dxx = rx.t() + rx - 2. * xx # Used for A in (1)
    dyy = ry.t() + ry - 2. * yy # Used for B in (1)
    dxy = rx.t() + ry - 2. * zz # Used for C in (1)
    
    XX, YY, XY = (torch.zeros(xx.shape).to(device),
                  torch.zeros(xx.shape).to(device),
                  torch.zeros(xx.shape).to(device))
    
    if kernel == "multiscale":
        
        bandwidth_range = [0.2, 0.5, 0.9, 1.3]
        for a in bandwidth_range:
            XX += a**2 * (a**2 + dxx)**-1
            YY += a**2 * (a**2 + dyy)**-1
            XY += a**2 * (a**2 + dxy)**-1
            
    if kernel == "rbf":
      
        bandwidth_range = [10, 15, 20, 50]
        for a in bandwidth_range:
            XX += torch.exp(-0.5*dxx/a)
            YY += torch.exp(-0.5*dyy/a)
            XY += torch.exp(-0.5*dxy/a)
      
    return torch.mean(XX + YY - 2. * XY)

# %%
def demo_plots(conditional =False, 
               ttl1="GP priors to encode",
               ttl2="Priors learnt by VAE", 
               ylbl1='$y=f_{GP}(x)$', 
               ylbl2='$y=f_{VAE}(x)$', 
               ls=None):

    n_samps = 100000
    if conditional == True:
        dataset = GP1D(n_dataPoints=args["input_dim"], n_samples=n_samps, ls=ls)
        ttl2="Priors learnt by CVAE"
        ylbl2='$y=f_{CVAE}(x)$'
    else:
        dataset = GP1D(n_dataPoints=args["input_dim"], n_samples=n_samps, ls=ls)    

    gp_draws = dataset.y
    x = dataset.x[0,:]
    gp_draws = gp_draws.transpose()

    model.eval() # model in eval mode
    z = torch.randn(n_samps, z_dim).to(device) # random draw

    if conditional == True:
        c = torch.ones(n_samps) * ls
        c = c[:, None]
        with torch.no_grad():
            vae_draws = model.decoder(z, c).numpy().transpose()
    else:
        with torch.no_grad():
            vae_draws = model.decoder(z, c=None).numpy().transpose()

    mean_gp = np.nanmean(gp_draws, axis=1)
    q025_gp = np.quantile(gp_draws, 0.025, axis=1)
    q975_gp = np.quantile(gp_draws, 0.975, axis=1)
    #print(mean_gp.shape)

    mean_vae = np.nanmean(vae_draws, axis=1)
    q025_vae = np.quantile(vae_draws, 0.025, axis=1)
    q975_vae = np.quantile(vae_draws, 0.975, axis=1)

    #print("q025: ")
    #print(q025_gp)
    #print(q025_vae)
    #print("q975: ")
    #print(q975_gp)
    #print(q975_vae)

    # plot results
    fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12,3))

    _min, _max = -3, 3
    lines_alpha_gp = 0.5
    lines_alpha_vae = 0.5
    N_lines = 20

    if ls==None:
        ttl = ttl1
    else:
        ttl = ttl1+ ", ls=" + str(ls)
    ylbl = ylbl1

    for j in range(N_lines):
        itr = int(gp_draws.shape[1]/N_lines)
        axs[0].plot(x, gp_draws[:,j*itr], alpha=lines_alpha_gp, label="")

    axs[0].plot(x, gp_draws[:,0], alpha=lines_alpha_gp, color="darkgreen", label="GP draws")  
    axs[0].fill_between(x, q025_gp[0], q975_gp[1], alpha=0.1, interpolate=True, label="95% BCI")
    axs[0].plot(x, mean_gp, label="mean")
    axs[0].legend(loc=4)
    axs[0].set_ylim([_min, _max])
    axs[0].set_xlabel('$x$')
    axs[0].set_ylabel(ylbl)
    axs[0].set_title(ttl)

    if ls==None:
        tt2 = ttl2
    else:
        tt2 = ttl2+ ", ls=" + str(ls)
    ylbl=ylbl2

    for j in range(N_lines):
        itr = int(vae_draws.shape[1]/N_lines)
        axs[1].plot(x, vae_draws[:,j*itr], alpha=lines_alpha_vae, label="")

    axs[1].plot(x, vae_draws[:,0], alpha=lines_alpha_vae, color="darkgreen", label="VAE draws")  
    axs[1].fill_between(x, q025_vae[0], q975_vae[1], alpha=0.1, interpolate=True, label="95% BCI")
    axs[1].plot(x, mean_vae, label="mean")
    axs[1].legend(loc=4)
    axs[1].set_ylim([_min, _max])
    axs[1].set_xlabel('$x$')
    axs[1].set_ylabel(ylbl)
    axs[1].set_title(tt2)

    axs[2].fill_between(x, q025_gp[0], q975_gp[1], alpha=0.1, interpolate=True, label="95% BCI")
    axs[2].plot(x, mean_gp, label="mean")
    axs[2].fill_between(x, q025_vae[0], q975_vae[1], alpha=0.1, interpolate=True, label="95% BCI")
    axs[2].plot(x, mean_vae, label="mean")
    axs[2].legend(loc=4)
    axs[2].set_ylim([_min, _max])

    plt.show()

    m_vae = np.cov((vae_draws))
    m_gp = np.cov((gp_draws))
    print('Frobenius norm = ' + str(np.linalg.norm(m_gp - m_vae,  'fro')))
    
    gg = torch.from_numpy(gp_draws)
    vv = torch.from_numpy(vae_draws)
    print('MMD, multiscale = ' + str(MMD(gg, vv)))
    print('MMD, rbf = ' + str(MMD(gg, vv, "rbf")))
    
    cmap_choice = 'inferno'
    
    gp_cm_ttl = 'GP covariance matrix'
    if ls is not None:
        gp_cm_ttl = gp_cm_ttl + ', c='+ str(ls)
    vae_cm_ttl = 'VAE covariance matrix'
    if ls is not None:
        vae_cm_ttl = vae_cm_ttl +', c='+ str(ls)


    #'plasma'
    #'inferno'
    fig, axs = plt.subplots(nrows=1, ncols=2, figsize = (8,4))
    axs[0].imshow(m_gp, cmap=cmap_choice)
    axs[0].axis('off')

    axs[0].set_title(gp_cm_ttl)
    #axs[0].set_title('GP covariance matrix, c=' + str(ls))

    axs[1].imshow(m_vae, cmap=cmap_choice)
    axs[1].axis('off')
    axs[1].set_title(vae_cm_ttl)

    plt.show()
    
    #return (gp_draws, vae_draws)

# %%
# 2).
demo_plots(conditional=True, ls=0.4)
# Out:
# Frobenius norm = 4.4176958976449265
# MMD, multiscale = tensor(0.1026)
# MMD, rbf = tensor(0.1326)

# %%
# 3).
demo_plots(conditional=True, ls=0.1)
# Out:
# Frobenius norm = 6.732076678218711
# MMD, multiscale = tensor(0.1002)
# MMD, rbf = tensor(0.1000)

# %%
# 4).
demo_plots(conditional=True, ls=0.9)
# Out:
# Frobenius norm = 3.2080858726526067
# MMD, multiscale = tensor(0.1112)
# MMD, rbf = tensor(0.2663)

# %% [markdown]
# # Inference

# %% [markdown]
# ## Generate data

# %%
x = train_ds[0][0]

rng_key_draw =  random.PRNGKey(1)
rng_key, rng_key_post, rng_key_preds, rng_key_draw = random.split(rng_key_draw, 4)

gp_predictive = Predictive(GP, num_samples=1)
draws = gp_predictive(rng_key_draw, x=x, jitter=1e-6, 
                      noise=True, length=args["true_ls"], var=1)

gp_draw = draws['f'].T
y_draw = draws['y'].T

obs_idx_lst = []
obs_idx_lst.append([10, 30, 54, 64]) # points correspond to n=80, ls=0.2, rng1
i = 0

# choose indices of data points for inference
obs_idx = jnp.array(obs_idx_lst[i])

y_obs = y_draw[obs_idx,0]
x_obs = x[np.array(obs_idx)]

args['y_obs'] = y_obs
args['obs_idx'] = obs_idx
args['x_obs'] = x_obs

plt.plot(x, gp_draw, label="ground truth", color="orange")
plt.scatter(x_obs, y_obs, color="red", label="observed data", s=60)
plt.title('Ground truth, corresponds to ls=' + str(args["true_ls"]))
# Out:
# Text(0.5, 1.0, 'Ground truth, corresponds to ls=0.2')

# %% [markdown]
# ## Numpyro model - PriorCVAE

# %%
# decoder parameters

model = model.to('cpu')
decoder_dict = model.decoder.state_dict()
decoder_dict.keys()

W1 = decoder_dict['linear.weight'].T.numpy()
B1 = decoder_dict['linear.bias'].numpy()
W2 = decoder_dict['out.weight'].T.numpy()
B2 = decoder_dict['out.bias'].T.numpy()

print(W1.shape)
print(B1.shape)
print(W2.shape)
print(B2.shape)
# Out:
# (41, 60)
# (60,)
# (60, 80)
# (80,)
# /var/folders/q3/n2z18__9281b8xfhctcpxfsr0000gn/T/ipykernel_54661/2358429211.py:10: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matricesor `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at  /Users/runner/work/_temp/anaconda/conda-bld/pytorch_1659484782168/work/aten/src/ATen/native/TensorShape.cpp:2985.)
#   B2 = decoder_dict['out.bias'].T.numpy()

# %%
def c_decoder_numpy(z, W1, B1, W2, B2, c=None):
   
    def linear(z, W, B):
        lin_out = jnp.matmul(z, W) + B
        return lin_out

    if c is not None:
        c = jnp.array(c).reshape(1)
        z = jnp.concatenate([z, c], axis=0)

    hidden = jax.nn.relu(linear(z, W1, B1))
    out = linear(hidden, W2, B2)
    return out

        
def numpyro_model(z_dim, conditional=False,  y=None, obs_idx=None, c=None,):
    
    if c is None and conditional==True:
        c = numpyro.sample("c", npdist.Uniform(0.01,0.99))

    z = numpyro.sample("z", npdist.Normal(jnp.zeros(z_dim), jnp.ones(z_dim))) 
    
    f = numpyro.deterministic("f", c_decoder_numpy(z, W1, B1, W2, B2, c))
    sigma = numpyro.sample("sigma", npdist.HalfNormal(0.1))

    if y is None: # durinig prediction
        y_pred = numpyro.sample("y_pred", npdist.Normal(f, sigma))
    else: # during inference
        y = numpyro.sample("y", npdist.Normal(f[obs_idx], sigma), obs=y)

# %%
def run_mcmc_vae(rng_key, numpyro_model, args, verbose=True, c=None, conditional=False):
    start = time.time()

    init_strategy = init_to_median(num_samples=10)
    kernel = NUTS(numpyro_model, init_strategy=init_strategy)
    mcmc = MCMC(
        kernel,
        num_warmup=args["num_warmup"],
        num_samples=args["num_samples"],
        num_chains=args["num_chains"],
        thinning=args["thinning"],
        progress_bar=False if "NUMPYRO_SPHINXBUILD" in os.environ else True,
    )
    start = time.time()
    mcmc.run(rng_key, args["z_dim"], conditional, args["y_obs"], args["obs_idx"], c )
    t_elapsed = time.time() - start
    if verbose:
        mcmc.print_summary(exclude_deterministic=False)
    
    print("\nMCMC elapsed time:", round(t_elapsed), "s")
    ss = numpyro.diagnostics.summary(mcmc.get_samples(group_by_chain=True))
    r = np.mean(ss['f']['n_eff'])
    print("Average ESS for all VAE-GP effects : " + str(round(r)))

    return (mcmc, mcmc.get_samples(), t_elapsed)

# %% [markdown]
# ## Inference on observed data - PriorCVAE

# %%
args.keys()
# Out:
# dict_keys(['seed', 'conditional', 'input_dim', 'hidden_dim', 'z_dim', 'new_data', 'save_data', 'batch_size', 'samples', 'vae_sd', 'n_epochs', 'learning_rate', 'train_vae', 'save_vae', 'load_vae', 'num_warmup', 'num_samples', 'num_chains', 'thinning', 'true_ls', 'y_obs', 'obs_idx', 'x_obs'])

# %%
rng_key, rng_key_prior, rng_key_post, rng_key_pred = random.split(rng_key, 4)

mcmc_vae, mcmc_vae_samples, t_elapsed = run_mcmc_vae(rng_key_post, numpyro_model, args, conditional=True)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#          c      0.20      0.16      0.17      0.01      0.31    760.08      1.01
#       f[0]      0.15      0.49      0.24     -0.66      0.87   1444.80      1.01
#       f[1]      0.15      0.50      0.24     -0.71      0.87   1254.74      1.01
#       f[2]      0.13      0.50      0.22     -0.69      0.88   1129.89      1.01
#       f[3]      0.12      0.48      0.20     -0.68      0.83   1050.37      1.01
#       f[4]      0.09      0.45      0.17     -0.63      0.77    968.12      1.01
#       f[5]      0.07      0.40      0.14     -0.60      0.64    921.15      1.01
#       f[6]      0.06      0.34      0.11     -0.54      0.53    922.80      1.01
#       f[7]      0.03      0.27      0.08     -0.44      0.44   1008.93      1.01
#       f[8]      0.01      0.21      0.05     -0.35      0.34   1365.15      1.01
#       f[9]     -0.02      0.16      0.01     -0.28      0.23   2608.80      1.01
#      f[10]     -0.05      0.13     -0.03     -0.25      0.17   2938.53      1.00
#      f[11]     -0.08      0.15     -0.08     -0.33      0.15   1800.24      1.01
#      f[12]     -0.11      0.19     -0.13     -0.43      0.19   1298.06      1.01
#      f[13]     -0.15      0.24     -0.18     -0.52      0.25   1983.02      1.01
#      f[14]     -0.18      0.30     -0.23     -0.62      0.32   2349.66      1.01
#      f[15]     -0.23      0.34     -0.29     -0.69      0.39   2761.34      1.00
#      f[16]     -0.27      0.38     -0.34     -0.83      0.38   3090.60      1.00
#      f[17]     -0.31      0.42     -0.38     -0.92      0.39   3148.32      1.00
#      f[18]     -0.36      0.44     -0.43     -1.00      0.37   3246.24      1.00
#      f[19]     -0.40      0.45     -0.47     -1.10      0.32   3218.26      1.00
#      f[20]     -0.45      0.45     -0.51     -1.16      0.28   3106.42      1.00
#      f[21]     -0.48      0.45     -0.55     -1.17      0.25   3009.06      1.00
#      f[22]     -0.52      0.44     -0.59     -1.19      0.20   2915.71      1.00
#      f[23]     -0.57      0.43     -0.64     -1.22      0.11   2783.05      1.00
#      f[24]     -0.63      0.40     -0.69     -1.21      0.02   2613.91      1.00
#      f[25]     -0.67      0.36     -0.72     -1.19     -0.07   2210.92      1.00
#      f[26]     -0.69      0.32     -0.74     -1.14     -0.15   1769.26      1.00
#      f[27]     -0.72      0.27     -0.76     -1.08     -0.23   1216.15      1.00
#      f[28]     -0.74      0.22     -0.78     -1.05     -0.34   1026.70      1.01
#      f[29]     -0.75      0.18     -0.79     -1.03     -0.47   1084.04      1.01
#      f[30]     -0.74      0.15     -0.78     -0.97     -0.49   1280.86      1.01
#      f[31]     -0.74      0.17     -0.76     -1.04     -0.47   1624.54      1.01
#      f[32]     -0.73      0.21     -0.75     -1.09     -0.36   1713.95      1.01
#      f[33]     -0.70      0.26     -0.72     -1.10     -0.27   1109.43      1.01
#      f[34]     -0.66      0.30     -0.68     -1.13     -0.17    650.79      1.01
#      f[35]     -0.62      0.35     -0.64     -1.18     -0.08    479.58      1.01
#      f[36]     -0.57      0.39     -0.60     -1.17      0.07    400.38      1.01
#      f[37]     -0.53      0.42     -0.57     -1.18      0.18    364.29      1.01
#      f[38]     -0.49      0.45     -0.53     -1.17      0.30    344.96      1.01
#      f[39]     -0.44      0.47     -0.49     -1.09      0.46    331.00      1.01
#      f[40]     -0.39      0.49     -0.45     -1.05      0.54    317.56      1.01
#      f[41]     -0.35      0.49     -0.41     -1.01      0.59    312.36      1.01
#      f[42]     -0.31      0.49     -0.37     -0.97      0.60    320.82      1.01
#      f[43]     -0.27      0.48     -0.33     -0.93      0.60    344.90      1.01
#      f[44]     -0.24      0.47     -0.29     -0.90      0.58    386.69      1.01
#      f[45]     -0.21      0.45     -0.26     -0.87      0.54    458.88      1.01
#      f[46]     -0.19      0.43     -0.22     -0.84      0.49    571.15      1.01
#      f[47]     -0.18      0.40     -0.20     -0.78      0.45    734.52      1.01
#      f[48]     -0.17      0.36     -0.17     -0.73      0.38   1007.36      1.01
#      f[49]     -0.15      0.32     -0.15     -0.64      0.35   1532.37      1.00
#      f[50]     -0.14      0.27     -0.13     -0.57      0.28   2171.69      1.00
#      f[51]     -0.12      0.22     -0.11     -0.48      0.25   2605.49      1.00
#      f[52]     -0.10      0.18     -0.08     -0.42      0.17   2644.14      1.00
#      f[53]     -0.10      0.14     -0.07     -0.34      0.12   2358.66      1.00
#      f[54]     -0.09      0.12     -0.07     -0.31      0.09   2301.71      1.01
#      f[55]     -0.09      0.13     -0.08     -0.32      0.11   2820.92      1.00
#      f[56]     -0.11      0.15     -0.09     -0.36      0.13   3868.49      1.00
#      f[57]     -0.13      0.17     -0.12     -0.41      0.13   5230.74      1.00
#      f[58]     -0.15      0.18     -0.13     -0.46      0.11   5522.59      1.00
#      f[59]     -0.17      0.19     -0.15     -0.46      0.13   5570.66      1.00
#      f[60]     -0.19      0.19     -0.17     -0.47      0.11   5535.23      1.00
#      f[61]     -0.20      0.17     -0.19     -0.47      0.07   5849.68      1.00
#      f[62]     -0.21      0.15     -0.21     -0.45      0.04   6570.32      1.00
#      f[63]     -0.23      0.12     -0.23     -0.43     -0.02   8122.65      1.00
#      f[64]     -0.25      0.11     -0.26     -0.42     -0.05   8790.23      1.00
#      f[65]     -0.28      0.14     -0.29     -0.50     -0.05   5602.02      1.00
#      f[66]     -0.30      0.19     -0.32     -0.60      0.02   4746.50      1.00
#      f[67]     -0.31      0.25     -0.33     -0.68      0.11   4369.93      1.00
#      f[68]     -0.32      0.31     -0.35     -0.79      0.18   4004.76      1.00
#      f[69]     -0.32      0.36     -0.37     -0.87      0.26   3656.39      1.00
#      f[70]     -0.32      0.41     -0.37     -0.94      0.35   3342.95      1.00
#      f[71]     -0.32      0.46     -0.38     -1.03      0.41   2954.09      1.00
#      f[72]     -0.32      0.50     -0.38     -1.10      0.48   2253.80      1.00
#      f[73]     -0.31      0.54     -0.39     -1.15      0.55   1786.50      1.01
#      f[74]     -0.32      0.57     -0.40     -1.23      0.58   1461.24      1.01
#      f[75]     -0.34      0.59     -0.41     -1.27      0.62   1313.60      1.01
#      f[76]     -0.33      0.61     -0.41     -1.30      0.66   1244.16      1.01
#      f[77]     -0.32      0.62     -0.41     -1.34      0.65   1203.14      1.01
#      f[78]     -0.32      0.62     -0.40     -1.27      0.70   1174.37      1.01
#      f[79]     -0.31      0.60     -0.40     -1.23      0.67   1157.97      1.01
#      sigma      0.10      0.07      0.08      0.00      0.20    610.19      1.01
#       z[0]     -0.02      0.97     -0.04     -1.63      1.60  11395.06      1.00
#       z[1]     -0.54      0.28     -0.52     -0.99     -0.13   1444.97      1.00
#       z[2]      0.01      0.99      0.01     -1.56      1.68   3283.51      1.00
#       z[3]     -0.02      1.00      0.01     -1.65      1.61   3142.69      1.00
#       z[4]      0.03      0.97      0.06     -1.54      1.63   3243.39      1.00
#       z[5]     -0.06      1.02     -0.03     -1.73      1.50    359.95      1.01
#       z[6]     -0.00      0.99      0.00     -1.65      1.59   1366.02      1.01
#       z[7]      0.02      1.00      0.05     -1.64      1.61   1032.98      1.01
#       z[8]     -0.03      0.97     -0.07     -1.63      1.56   4498.19      1.00
#       z[9]      0.01      0.98      0.02     -1.65      1.53   2011.33      1.00
#      z[10]      0.06      0.98      0.08     -1.57      1.63   5569.05      1.00
#      z[11]      0.01      0.98     -0.02     -1.57      1.65   6314.75      1.00
#      z[12]     -0.01      0.27      0.02     -0.46      0.41   1007.33      1.01
#      z[13]     -0.01      0.99      0.00     -1.63      1.56   1279.02      1.01
#      z[14]     -0.00      0.97     -0.01     -1.68      1.53   4654.82      1.00
#      z[15]     -0.00      0.99     -0.04     -1.55      1.71   2953.50      1.00
#      z[16]     -0.01      0.98      0.01     -1.65      1.63   7977.43      1.00
#      z[17]      0.07      1.00      0.05     -1.54      1.67    368.62      1.01
#      z[18]     -0.01      0.99      0.04     -1.60      1.64   1789.80      1.00
#      z[19]     -0.22      0.97     -0.24     -1.78      1.36   1581.73      1.01
#      z[20]     -0.01      0.99     -0.03     -1.59      1.66   2290.97      1.00
#      z[21]     -0.18      1.05     -0.15     -1.82      1.69    129.36      1.03
#      z[22]     -0.05      0.98     -0.06     -1.74      1.52   6877.98      1.00
#      z[23]     -0.04      0.99     -0.06     -1.80      1.47   2552.68      1.00
#      z[24]     -0.00      0.97     -0.01     -1.67      1.57   9259.90      1.00
#      z[25]      0.00      0.98      0.00     -1.70      1.55  11028.96      1.00
#      z[26]     -0.01      0.98     -0.04     -1.58      1.64   4396.25      1.00
#      z[27]      0.00      0.98     -0.01     -1.60      1.62   4930.62      1.00
#      z[28]     -0.03      0.98     -0.05     -1.66      1.57   4026.58      1.00
#      z[29]     -0.04      0.99     -0.07     -1.63      1.61   1825.33      1.00
#      z[30]      0.16      0.47      0.12     -0.52      0.97   3285.84      1.00
#      z[31]     -0.01      0.99     -0.02     -1.64      1.59   5686.22      1.00
#      z[32]      0.03      0.99      0.04     -1.68      1.59   2682.10      1.00
#      z[33]      0.03      0.92      0.05     -1.51      1.50   1597.89      1.00
#      z[34]      0.04      0.97      0.07     -1.67      1.59   2737.67      1.00
#      z[35]      0.84      0.76      0.91     -0.42      2.04   2413.90      1.01
#      z[36]     -0.02      0.98     -0.05     -1.63      1.62   3725.25      1.00
#      z[37]      0.01      0.97      0.01     -1.58      1.60   2775.94      1.00
#      z[38]      0.01      0.99      0.01     -1.71      1.59   2255.82      1.00
#      z[39]      0.00      1.00     -0.02     -1.61      1.67   3586.13      1.00
#
# Number of divergences: 1074
#
# MCMC elapsed time: 9 s
# Average ESS for all VAE-GP effects : 2310

# %%
predictive = Predictive(numpyro_model, mcmc_vae_samples)
predictions_vae = predictive(rng_key_pred,  args["z_dim"], True, args["y_obs"], args["obs_idx"] )["f"]

mean_post_pred_vae = jnp.mean(predictions_vae, axis=0)
hpdi_post_pred_vae = hpdi(predictions_vae, 0.9)
percentiles_vae = np.percentile(predictions_vae, [5.0, 95.0], axis=0)

N_lines = 10
plt.plot(x, gp_draw, label="ground truth", color="orange")
plt.scatter(x_obs, y_obs, color="red", label="observed data", s=60)
plt.plot(x, mean_post_pred_vae, label="predicted mean VAE")

plt.fill_between(x, percentiles_vae[0, :], percentiles_vae[1, :], alpha=0.3, interpolate=True, label="VAE posterior: 90% BCI")
#for j in range(N_lines):
#    itr = int(predictions_vae.shape[0]/N_lines)
#    plt.plot(x, predictions_vae[j* itr,:], alpha=0.2, color="darkgreen", label="")


plt.title('PriorCVAE inference')
plt.ylim([-2, 1])
# Out:
# (-2.0, 1.0)

# %%
c_samps = mcmc_vae_samples['c']
plt.hist(c_samps, density=True, label = 'posterior samples', bins=20)
plt.axvline(x = args["true_ls"], color = 'red', label = 'true lengthscale')
plt.xlim(0,1)
plt.title('ls - posterior samples')
plt.legend()

# %%
import arviz as az
az_data = az.from_numpyro(mcmc_vae)
az.plot_trace(az_data, var_names=('c'), filter_vars="like")
# Out:
# array([[<AxesSubplot: title={'center': 'c'}>,
#         <AxesSubplot: title={'center': 'c'}>]], dtype=object)
